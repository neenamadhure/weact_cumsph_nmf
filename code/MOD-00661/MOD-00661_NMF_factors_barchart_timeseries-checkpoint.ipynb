# %% [markdown]
# # Factor Bar Chart and Timeseries Figures

# %%
import numpy as np
import seaborn as sns
import joblib
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.dates as mdates
import matplotlib.ticker as mticker
from matplotlib.ticker import FuncFormatter

# %%
# force the math text to look normal
mpl.rcParams['mathtext.default'] = 'regular'

def major_ticks(x, pos=None):
    """Set the major ticks according
    to this custom style
    """
    x = mdates.num2date(x)
    if pos == 0:
        fmt = "%-d\n%b %Y\n%I %p"
    else:
        fmt = "%-d"
    return x.strftime(fmt)

# set the default seaborn params
sns.set("paper", "ticks", color_codes=True, palette='colorblind')

# %% [markdown]
# ## Loading Data

# %%
#load in the comp data
comp = pd.read_csv('/content/MOD-00661_factor_resid.csv')
comp.rename(columns={'Unnamed: 0':'species'},inplace=True)
comp
# Out:
#   species  Factor 1  Factor 2  Factor 3  Factor 4  Residual
# 0      co  0.575781  0.263101  0.137004  0.003134  0.020980
# 1      no  0.656573  0.223098  0.115064  0.000000  0.005265
# 2     no2  0.967336  0.000000  0.036763  0.004079 -0.008177
# 3      o3  0.084249  0.925065  0.000000  0.000000 -0.009314
# 4    bin0  0.000000  0.285488  0.736395  0.000000 -0.021883
# 5    bin1  0.000000  0.000000  0.841953  0.273176 -0.115130
# 6    bin2  0.000000  0.000000  0.551470  0.530243 -0.081713
# 7    bin3  0.032545  0.000000  0.298009  0.678156 -0.008710
# 8    bin4  0.082158  0.167409  0.073820  0.673633  0.002980
# 9    bin5  0.168843  0.246498  0.000000  0.580956  0.003703

# %%
comp2 = pd.melt(comp,id_vars='species', value_vars=['Factor 1','Factor 2','Factor 3','Residual'])
comp2
# Out:
#    species  variable     value
# 0       co  Factor 1  0.575781
# 1       no  Factor 1  0.656573
# 2      no2  Factor 1  0.967336
# 3       o3  Factor 1  0.084249
# 4     bin0  Factor 1  0.000000
# 5     bin1  Factor 1  0.000000
# 6     bin2  Factor 1  0.000000
# 7     bin3  Factor 1  0.032545
# 8     bin4  Factor 1  0.082158
# 9     bin5  Factor 1  0.168843
# 10      co  Factor 2  0.263101
# 11      no  Factor 2  0.223098
# 12     no2  Factor 2  0.000000
# 13      o3  Factor 2  0.925065
# 14    bin0  Factor 2  0.285488
# 15    bin1  Factor 2  0.000000
# 16    bin2  Factor 2  0.000000
# 17    bin3  Factor 2  0.000000
# 18    bin4  Factor 2  0.167409
# 19    bin5  Factor 2  0.246498
# 20      co  Factor 3  0.137004
# 21      no  Factor 3  0.115064
# 22     no2  Factor 3  0.036763
# 23      o3  Factor 3  0.000000
# 24    bin0  Factor 3  0.736395
# 25    bin1  Factor 3  0.841953
# 26    bin2  Factor 3  0.551470
# 27    bin3  Factor 3  0.298009
# 28    bin4  Factor 3  0.073820
# 29    bin5  Factor 3  0.000000
# 30      co  Residual  0.020980
# 31      no  Residual  0.005265
# 32     no2  Residual -0.008177
# 33      o3  Residual -0.009314
# 34    bin0  Residual -0.021883
# 35    bin1  Residual -0.115130
# 36    bin2  Residual -0.081713
# 37    bin3  Residual -0.008710
# 38    bin4  Residual  0.002980
# 39    bin5  Residual  0.003703

# %%
#load in the timeseries data
ts = pd.read_csv('/content/MOD-00661_timeseries_hourly_scaled.csv').reset_index()
results = pd.read_csv('/content/MOD-00661_factor_results.csv')

ts = pd.concat([ts,results['Factor 1'],results['Factor 2'], results['Factor 3']], axis = 1)
cols_reordered = ['timestamp_local','bin0','bin1','bin2','bin3','bin4','bin5','co','o3','no','no2','Factor 1','Factor 2','Factor 3']
ts = ts[cols_reordered]
ts.head()
# Out:
#        timestamp_local      bin0      bin1      bin2      bin3      bin4  \
# 0  2025-03-31 20:00:00  0.284851  0.092237  0.094921  0.134111  0.234432
# 1  2025-03-31 21:00:00  0.369729  0.173328  0.132390  0.160350  0.267399
# 2  2025-03-31 22:00:00  0.350364  0.246349  0.159867  0.160350  0.238095
# 3  2025-03-31 23:00:00  0.214668  0.136818  0.089092  0.081633  0.109890
# 4  2025-04-01 00:00:00  0.197363  0.112990  0.069942  0.061224  0.080586
#
#        bin5        co        o3        no       no2  Factor 1  Factor 2  \
# 0  0.345070  0.415279  0.235785  0.014742  0.581095  0.053343  0.027070
# 1  0.394366  0.468730  0.219384  0.021843  0.673271  0.060173  0.023778
# 2  0.338028  0.533077  0.259940  0.025008  0.679819  0.061862  0.028881
# 3  0.133803  0.406249  0.386382  0.022229  0.536434  0.049072  0.043697
# 4  0.098592  0.370681  0.426640  0.021843  0.480020  0.043512  0.048707
#
#    Factor 3
# 0  0.050140
# 1  0.074744
# 2  0.081564
# 3  0.041815
# 4  0.034856

# %%
ts['timestamp_local'] = pd.to_datetime(ts['timestamp_local']) #convert timestamp column to pandas timestamp format
ts = ts.set_index('timestamp_local',append=False) #setindex as local time
ts
# Out:
#                          bin0      bin1      bin2      bin3      bin4  \
# timestamp_local
# 2025-03-31 20:00:00  0.284851  0.092237  0.094921  0.134111  0.234432
# 2025-03-31 21:00:00  0.369729  0.173328  0.132390  0.160350  0.267399
# 2025-03-31 22:00:00  0.350364  0.246349  0.159867  0.160350  0.238095
# 2025-03-31 23:00:00  0.214668  0.136818  0.089092  0.081633  0.109890
# 2025-04-01 00:00:00  0.197363  0.112990  0.069942  0.061224  0.080586
# ...                       ...       ...       ...       ...       ...
# 2025-12-30 22:00:00  0.019228  0.006533  0.004996  0.005831  0.007326
# 2025-12-30 23:00:00  0.018404  0.006149  0.004996  0.002915  0.003663
# 2025-12-31 00:00:00  0.018404  0.006149  0.004996  0.002915  0.003663
# 2025-12-31 01:00:00  0.017992  0.005380  0.004163  0.002915  0.003663
# 2025-12-31 03:00:00  0.021288  0.004996  0.004163  0.002915  0.003663
#
#                          bin5        co        o3        no       no2  \
# timestamp_local
# 2025-03-31 20:00:00  0.345070  0.415279  0.235785  0.014742  0.581095
# 2025-03-31 21:00:00  0.394366  0.468730  0.219384  0.021843  0.673271
# 2025-03-31 22:00:00  0.338028  0.533077  0.259940  0.025008  0.679819
# 2025-03-31 23:00:00  0.133803  0.406249  0.386382  0.022229  0.536434
# 2025-04-01 00:00:00  0.098592  0.370681  0.426640  0.021843  0.480020
# ...                       ...       ...       ...       ...       ...
# 2025-12-30 22:00:00  0.007042  0.360855  0.199901  0.014665  0.584621
# 2025-12-30 23:00:00  0.007042  0.351371  0.197714  0.013662  0.582270
# 2025-12-31 00:00:00  0.007042  0.350599  0.188966  0.013739  0.595702
# 2025-12-31 01:00:00  0.007042  0.346785  0.189563  0.014048  0.589825
# 2025-12-31 03:00:00  0.007042  0.350637  0.184493  0.014356  0.593855
#
#                      Factor 1  Factor 2  Factor 3
# timestamp_local
# 2025-03-31 20:00:00  0.053343  0.027070  0.050140
# 2025-03-31 21:00:00  0.060173  0.023778  0.074744
# 2025-03-31 22:00:00  0.061862  0.028881  0.081564
# 2025-03-31 23:00:00  0.049072  0.043697  0.041815
# 2025-04-01 00:00:00  0.043512  0.048707  0.034856
# ...                       ...       ...       ...
# 2025-12-30 22:00:00  0.059431  0.021396  0.000343
# 2025-12-30 23:00:00  0.058965  0.020914  0.000000
# 2025-12-31 00:00:00  0.060186  0.019623  0.000000
# 2025-12-31 01:00:00  0.059550  0.019690  0.000000
# 2025-12-31 03:00:00  0.060031  0.019163  0.000492
#
# [6353 rows x 13 columns]

# %%
#taking daily average of ts. round to floor of the day
ts = ts.reset_index()

ts_day = ts.groupby(ts['timestamp_local'].dt.floor('d')).agg(bin0 = ('bin0','mean'),
                                                  bin1 = ('bin1','mean'),
                                                  bin2 = ('bin2','mean'),
                                                  bin3 = ('bin3','mean'),
                                                  bin4 = ('bin4','mean'),
                                                  bin5 = ('bin5','mean'),
                                                  co = ('co','mean'),
                                                  o3 = ('o3','mean'),
                                                  no = ('no','mean'),
                                                  no2 = ('no2','mean'),
                                                  factor1 = ('Factor 1','mean'),
                                                  factor2 = ('Factor 2','mean'),
                                                  factor3 = ('Factor 3','mean')).reset_index()

ts_day = ts_day.set_index('timestamp_local')
ts_day.head()
# Out:
#                      bin0      bin1      bin2      bin3      bin4      bin5  \
# timestamp_local
# 2025-03-31       0.304903  0.162183  0.119067  0.134111  0.212454  0.302817
# 2025-04-01       0.064832  0.026470  0.016861  0.014699  0.017857  0.019953
# 2025-04-02       0.048797  0.023107  0.027234  0.041910  0.073107  0.100352
# 2025-04-03       0.260181  0.118162  0.087219  0.112731  0.207723  0.319542
# 2025-04-04       0.072077  0.021954  0.017867  0.019801  0.030220  0.040786
#
#                        co        o3        no       no2   factor1   factor2  \
# timestamp_local
# 2025-03-31       0.455834  0.275373  0.020956  0.617654  0.056112  0.030857
# 2025-04-01       0.333627  0.333611  0.018299  0.393805  0.039507  0.039408
# 2025-04-02       0.349363  0.357294  0.016633  0.529774  0.051934  0.040462
# 2025-04-03       0.420580  0.276582  0.020103  0.511921  0.047388  0.032860
# 2025-04-04       0.369377  0.346993  0.017791  0.342631  0.035972  0.043126
#
#                   factor3
# timestamp_local
# 2025-03-31       0.062066
# 2025-04-01       0.009437
# 2025-04-02       0.000235
# 2025-04-03       0.049761
# 2025-04-04       0.011556

# %% [markdown]
# ## Setting Up Barchart and 6-month Figures

# %%
# set up the figure
fig = plt.figure(figsize=(9, 8))

ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

# %%
cols = ['bin0', 'bin1', 'bin2','bin3','bin4','bin5','co', 'o3','no', 'no2']

pal = sns.color_palette()

colors = [pal[3], pal[2], pal[4], pal[5]]
colors += sns.color_palette("Blues", 6)
colors.reverse()

# %%
ax1 = sns.barplot(x='variable',y='value',
        data=comp2,
        ax=ax1, hue='species',hue_order=cols,
        palette=colors, saturation=1, edgecolor='black', linewidth=0.25,
        errwidth=.75)
# Out:
# /tmp/ipykernel_685/2976516543.py:1: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 0.75}` instead.
#
#   ax1 = sns.barplot(x='variable',y='value',

# %%
ax1.set_ylim(-0.2, 1)
ax1.set_xlabel("")
ax1.set_ylabel("Percent of Species Signal\nDescribed by Factor", fontsize=14)
ax1.set(yticks=np.linspace(-0.2, 1, 13), yticklabels=["","","0","","","","","50","","","","","100"])
ax1.tick_params(axis='both', which='major', labelsize=14)
ax1.axhline(y=0, color='black', linestyle='-', lw =0.5)

# %%
handles, _ = ax1.get_legend_handles_labels()
labels = ["Bin 0", "Bin 1", "Bin 2", "Bin 3","Bin 4","Bin 5","CO","$O_3$","$NO$", "$NO_2$"]
ax1.legend(handles, labels)

# %%
ax2.plot(ts_day.index, ts_day["factor1"], label="Factor 1 ", lw=1, color=sns.xkcd_rgb['slate blue'])
ax2.plot(ts_day.index, ts_day["factor2"], label="Factor 2", lw=1, color=sns.xkcd_rgb['dull green'])
ax2.plot(ts_day.index, ts_day["factor3"], label="Factor 3", lw=1, color=sns.xkcd_rgb['dark lavender'])

ax2.set_ylabel("Factor Intensity (a.u.)", fontsize=14)

#last 6 months
ax2.set_xlim(ts_day.index[-180], ts_day.index[-1])
#ax2.set_xlim(ts_day.index[0], ts_day.index[-1])

ax2.legend(loc='upper right',fontsize=10)
ax2.tick_params(axis='both', which='major', labelsize=14)

# %%
ax1.set_title('(a)',fontsize=14)
ax2.set_title('(b)',fontsize=14)
# Out:
# Text(0.5, 1.0, '(b)')

# %%
plt.gcf().text(0.09, 0.9, "(a)", fontsize=12)
plt.gcf().text(0.5, 0.9, "(b)", fontsize=12)
plt.gcf().text(0.09,0.9,'MOD-00397',fontsize=12)

plt.tight_layout()

# %%
fig.savefig('time_barchart_MOD-00661_3_factor.png')

# %%
fig

# %% [markdown]
# ## Setting Up Diurnal Figure

# %%
ts.head()
# Out:
#       timestamp_local      bin0      bin1      bin2      bin3      bin4  \
# 0 2025-03-31 20:00:00  0.284851  0.092237  0.094921  0.134111  0.234432
# 1 2025-03-31 21:00:00  0.369729  0.173328  0.132390  0.160350  0.267399
# 2 2025-03-31 22:00:00  0.350364  0.246349  0.159867  0.160350  0.238095
# 3 2025-03-31 23:00:00  0.214668  0.136818  0.089092  0.081633  0.109890
# 4 2025-04-01 00:00:00  0.197363  0.112990  0.069942  0.061224  0.080586
#
#        bin5        co        o3        no       no2  Factor 1  Factor 2  \
# 0  0.345070  0.415279  0.235785  0.014742  0.581095  0.053343  0.027070
# 1  0.394366  0.468730  0.219384  0.021843  0.673271  0.060173  0.023778
# 2  0.338028  0.533077  0.259940  0.025008  0.679819  0.061862  0.028881
# 3  0.133803  0.406249  0.386382  0.022229  0.536434  0.049072  0.043697
# 4  0.098592  0.370681  0.426640  0.021843  0.480020  0.043512  0.048707
#
#    Factor 3
# 0  0.050140
# 1  0.074744
# 2  0.081564
# 3  0.041815
# 4  0.034856

# %%
#prepping data
ts = ts.set_index('timestamp_local')
ts['Hour'] = ts.index.hour
ts.head()
# Out:
#                          bin0      bin1      bin2      bin3      bin4  \
# timestamp_local
# 2025-03-31 20:00:00  0.284851  0.092237  0.094921  0.134111  0.234432
# 2025-03-31 21:00:00  0.369729  0.173328  0.132390  0.160350  0.267399
# 2025-03-31 22:00:00  0.350364  0.246349  0.159867  0.160350  0.238095
# 2025-03-31 23:00:00  0.214668  0.136818  0.089092  0.081633  0.109890
# 2025-04-01 00:00:00  0.197363  0.112990  0.069942  0.061224  0.080586
#
#                          bin5        co        o3        no       no2  \
# timestamp_local
# 2025-03-31 20:00:00  0.345070  0.415279  0.235785  0.014742  0.581095
# 2025-03-31 21:00:00  0.394366  0.468730  0.219384  0.021843  0.673271
# 2025-03-31 22:00:00  0.338028  0.533077  0.259940  0.025008  0.679819
# 2025-03-31 23:00:00  0.133803  0.406249  0.386382  0.022229  0.536434
# 2025-04-01 00:00:00  0.098592  0.370681  0.426640  0.021843  0.480020
#
#                      Factor 1  Factor 2  Factor 3  Hour
# timestamp_local
# 2025-03-31 20:00:00  0.053343  0.027070  0.050140    20
# 2025-03-31 21:00:00  0.060173  0.023778  0.074744    21
# 2025-03-31 22:00:00  0.061862  0.028881  0.081564    22
# 2025-03-31 23:00:00  0.049072  0.043697  0.041815    23
# 2025-04-01 00:00:00  0.043512  0.048707  0.034856     0

# %%
#grouping by hour and calculate the mean
diurnal_data = ts.groupby('Hour')[['Factor 1','Factor 2','Factor 3']].mean()
diurnal_data.index = diurnal_data.index.map(lambda x: "{:02d}:00".format(x))
diurnal_data
# Out:
#        Factor 1  Factor 2  Factor 3
# Hour
# 00:00  0.048689  0.026640  0.030729
# 01:00  0.048467  0.025419  0.030784
# 02:00  0.048172  0.024420  0.030663
# 03:00  0.047775  0.022817  0.031794
# 04:00  0.047624  0.021559  0.032095
# 05:00  0.048640  0.019825  0.034163
# 06:00  0.050421  0.019009  0.035343
# 07:00  0.047716  0.021783  0.036010
# 08:00  0.041872  0.026280  0.034574
# 09:00  0.036549  0.030729  0.031827
# 10:00  0.031877  0.036070  0.028926
# 11:00  0.030180  0.040874  0.026313
# 12:00  0.030316  0.044393  0.023815
# 13:00  0.033372  0.045971  0.021515
# 14:00  0.035799  0.047201  0.020759
# 15:00  0.037493  0.047170  0.020832
# 16:00  0.040160  0.046163  0.019762
# 17:00  0.046041  0.042975  0.019281
# 18:00  0.050934  0.038915  0.020999
# 19:00  0.053787  0.035412  0.023300
# 20:00  0.053352  0.032693  0.026593
# 21:00  0.051501  0.030680  0.029536
# 22:00  0.049897  0.029227  0.031389
# 23:00  0.049369  0.027835  0.030451

# %%
# set up the figure
plt.figure(figsize=(10, 6))

plt.plot(diurnal_data.index, diurnal_data['Factor 1'], label='Factor 1', lw = 2, color=sns.xkcd_rgb['slate blue'])
plt.plot(diurnal_data.index, diurnal_data['Factor 2'], label='Factor 2', lw = 2, color=sns.xkcd_rgb['dull green'])
plt.plot(diurnal_data.index, diurnal_data['Factor 3'], label='Factor 3', lw = 2, color=sns.xkcd_rgb['dark lavender'])

plt.ylabel('Factor Intensity (a.u.)', fontsize = 14)
plt.legend(loc='upper right',fontsize=14)
plt.xticks(range(0, 24))
plt.xticks(rotation=45)

plt.tick_params(labelsize=14)

plt.savefig('diurnal_MOD-00661_3_factor.png')
plt.show()
