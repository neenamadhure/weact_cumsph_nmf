# %% [markdown]
# # Factor Bar Chart and Timeseries Figures

# %%
import numpy as np
import seaborn as sns
import joblib
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.dates as mdates
import matplotlib.ticker as mticker
from matplotlib.ticker import FuncFormatter

# %%
# force the math text to look normal
mpl.rcParams['mathtext.default'] = 'regular'

def major_ticks(x, pos=None):
    """Set the major ticks according
    to this custom style
    """
    x = mdates.num2date(x)
    if pos == 0:
        fmt = "%-d\n%b %Y\n%I %p"
    else:
        fmt = "%-d"
    return x.strftime(fmt)

# set the default seaborn params
sns.set("paper", "ticks", color_codes=True, palette='colorblind')

# %% [markdown]
# ## Loading Data

# %%
#load in the comp data
comp = pd.read_csv('/content/MOD-00684_factor_resid (1).csv')
comp.rename(columns={'Unnamed: 0':'species'},inplace=True)
comp
# Out:
#   species  Factor 1  Factor 2  Factor 3  Factor 4  Residual
# 0      co  0.416061  0.031645  0.131897  0.420050  0.000348
# 1      no  0.394218  0.022351  0.144318  0.443209 -0.004095
# 2     no2  0.932155  0.009079  0.000000  0.059125 -0.000359
# 3      o3  0.346461  0.000000  0.652893  0.000000  0.000646
# 4    bin0  0.000000  0.589236  0.249531  0.175145 -0.013911
# 5    bin1  0.000000  1.075442  0.000000  0.000000 -0.075442
# 6    bin2  0.000000  1.058876  0.000000  0.000000 -0.058876
# 7    bin3  0.032619  0.945181  0.000000  0.000000  0.022200
# 8    bin4  0.098377  0.641756  0.000000  0.227621  0.032246
# 9    bin5  0.127380  0.447172  0.000000  0.391867  0.033581

# %%
comp2 = pd.melt(comp,id_vars='species', value_vars=['Factor 1','Factor 2','Factor 3','Residual'])
comp2
# Out:
#    species  variable     value
# 0       co  Factor 1  0.416061
# 1       no  Factor 1  0.394218
# 2      no2  Factor 1  0.932155
# 3       o3  Factor 1  0.346461
# 4     bin0  Factor 1  0.000000
# 5     bin1  Factor 1  0.000000
# 6     bin2  Factor 1  0.000000
# 7     bin3  Factor 1  0.032619
# 8     bin4  Factor 1  0.098377
# 9     bin5  Factor 1  0.127380
# 10      co  Factor 2  0.031645
# 11      no  Factor 2  0.022351
# 12     no2  Factor 2  0.009079
# 13      o3  Factor 2  0.000000
# 14    bin0  Factor 2  0.589236
# 15    bin1  Factor 2  1.075442
# 16    bin2  Factor 2  1.058876
# 17    bin3  Factor 2  0.945181
# 18    bin4  Factor 2  0.641756
# 19    bin5  Factor 2  0.447172
# 20      co  Factor 3  0.131897
# 21      no  Factor 3  0.144318
# 22     no2  Factor 3  0.000000
# 23      o3  Factor 3  0.652893
# 24    bin0  Factor 3  0.249531
# 25    bin1  Factor 3  0.000000
# 26    bin2  Factor 3  0.000000
# 27    bin3  Factor 3  0.000000
# 28    bin4  Factor 3  0.000000
# 29    bin5  Factor 3  0.000000
# 30      co  Residual  0.000348
# 31      no  Residual -0.004095
# 32     no2  Residual -0.000359
# 33      o3  Residual  0.000646
# 34    bin0  Residual -0.013911
# 35    bin1  Residual -0.075442
# 36    bin2  Residual -0.058876
# 37    bin3  Residual  0.022200
# 38    bin4  Residual  0.032246
# 39    bin5  Residual  0.033581

# %%
#load in the timeseries data
ts = pd.read_csv('/content/MOD-00684_timeseries_hourly_scaled.csv').reset_index()
results = pd.read_csv('/content/MOD-00684_factor_results (1).csv')

ts = pd.concat([ts,results['Factor 1'],results['Factor 2'], results['Factor 3']], axis = 1)
cols_reordered = ['timestamp_local','bin0','bin1','bin2','bin3','bin4','bin5','co','o3','no','no2','Factor 1','Factor 2','Factor 3']
ts = ts[cols_reordered]
ts.head()
# Out:
#        timestamp_local      bin0      bin1      bin2      bin3      bin4  \
# 0  2025-05-01 09:00:00  0.043202  0.014219  0.009703  0.008969  0.014749
# 1  2025-05-01 10:00:00  0.041017  0.013929  0.010274  0.008969  0.017699
# 2  2025-05-01 11:00:00  0.040123  0.012768  0.009703  0.008969  0.017699
# 3  2025-05-01 12:00:00  0.036349  0.011027  0.008562  0.008969  0.014749
# 4  2025-05-01 13:00:00  0.039527  0.011027  0.008562  0.008969  0.014749
#
#        bin5        co        o3        no       no2  Factor 1  Factor 2  \
# 0  0.019512  0.501834  0.488311  0.035096  0.183910  0.015334       0.0
# 1  0.019512  0.466209  0.521108  0.037218  0.123767  0.009434       0.0
# 2  0.019512  0.439626  0.577054  0.039830  0.152002  0.013162       0.0
# 3  0.014634  0.417050  0.611439  0.039993  0.173661  0.016068       0.0
# 4  0.014634  0.429084  0.627326  0.039993  0.177142  0.016332       0.0
#
#    Factor 3
# 0  0.135044
# 1  0.150216
# 2  0.164143
# 3  0.172125
# 4  0.176807

# %%
ts['timestamp_local'] = pd.to_datetime(ts['timestamp_local']) #convert timestamp column to pandas timestamp format
ts = ts.set_index('timestamp_local',append=False) #setindex as local time
ts
# Out:
#                          bin0      bin1      bin2      bin3      bin4  \
# timestamp_local
# 2025-05-01 09:00:00  0.043202  0.014219  0.009703  0.008969  0.014749
# 2025-05-01 10:00:00  0.041017  0.013929  0.010274  0.008969  0.017699
# 2025-05-01 11:00:00  0.040123  0.012768  0.009703  0.008969  0.017699
# 2025-05-01 12:00:00  0.036349  0.011027  0.008562  0.008969  0.014749
# 2025-05-01 13:00:00  0.039527  0.011027  0.008562  0.008969  0.014749
# ...                       ...       ...       ...       ...       ...
# 2025-12-31 14:00:00  0.117688  0.023506  0.012557  0.008969  0.011799
# 2025-12-31 15:00:00  0.106664  0.023215  0.012557  0.006726  0.011799
# 2025-12-31 16:00:00  0.116893  0.027568  0.015411  0.008969  0.011799
# 2025-12-31 17:00:00  0.108551  0.033372  0.017123  0.011211  0.014749
# 2025-12-31 18:00:00  0.098322  0.029019  0.014840  0.008969  0.011799
#
#                          bin5        co        o3        no       no2  \
# timestamp_local
# 2025-05-01 09:00:00  0.019512  0.501834  0.488311  0.035096  0.183910
# 2025-05-01 10:00:00  0.019512  0.466209  0.521108  0.037218  0.123767
# 2025-05-01 11:00:00  0.019512  0.439626  0.577054  0.039830  0.152002
# 2025-05-01 12:00:00  0.014634  0.417050  0.611439  0.039993  0.173661
# 2025-05-01 13:00:00  0.014634  0.429084  0.627326  0.039993  0.177142
# ...                       ...       ...       ...       ...       ...
# 2025-12-31 14:00:00  0.009756  0.475404  0.367907  0.031832  0.611294
# 2025-12-31 15:00:00  0.009756  0.483166  0.359737  0.030036  0.625798
# 2025-12-31 16:00:00  0.009756  0.484088  0.339650  0.038361  0.634693
# 2025-12-31 17:00:00  0.014634  0.520735  0.288811  0.039667  0.658673
# 2025-12-31 18:00:00  0.009756  0.567698  0.286655  0.046523  0.657513
#
#                      Factor 1  Factor 2  Factor 3
# timestamp_local
# 2025-05-01 09:00:00  0.015334  0.000000  0.135044
# 2025-05-01 10:00:00  0.009434  0.000000  0.150216
# 2025-05-01 11:00:00  0.013162  0.000000  0.164143
# 2025-05-01 12:00:00  0.016068  0.000000  0.172125
# 2025-05-01 13:00:00  0.016332  0.000000  0.176807
# ...                       ...       ...       ...
# 2025-12-31 14:00:00  0.061334  0.016826  0.059588
# 2025-12-31 15:00:00  0.062844  0.014775  0.055581
# 2025-12-31 16:00:00  0.063668  0.018163  0.048746
# 2025-12-31 17:00:00  0.065621  0.018178  0.031059
# 2025-12-31 18:00:00  0.064847  0.013505  0.031034
#
# [5818 rows x 13 columns]

# %%
#taking daily average of ts. round to floor of the day
ts = ts.reset_index()

ts_day = ts.groupby(ts['timestamp_local'].dt.floor('d')).agg(bin0 = ('bin0','mean'),
                                                  bin1 = ('bin1','mean'),
                                                  bin2 = ('bin2','mean'),
                                                  bin3 = ('bin3','mean'),
                                                  bin4 = ('bin4','mean'),
                                                  bin5 = ('bin5','mean'),
                                                  co = ('co','mean'),
                                                  o3 = ('o3','mean'),
                                                  no = ('no','mean'),
                                                  no2 = ('no2','mean'),
                                                  factor1 = ('Factor 1','mean'),
                                                  factor2 = ('Factor 2','mean'),
                                                  factor3 = ('Factor 3','mean')).reset_index()

ts_day = ts_day.set_index('timestamp_local')
ts_day.head()
# Out:
#                      bin0      bin1      bin2      bin3      bin4      bin5  \
# timestamp_local
# 2025-05-01       0.046810  0.016231  0.012671  0.013004  0.022812  0.028293
# 2025-05-02       0.223740  0.102788  0.075818  0.081465  0.140364  0.199187
# 2025-05-03       0.174227  0.057821  0.058742  0.071188  0.124385  0.149593
# 2025-05-04       0.206682  0.146994  0.103429  0.121357  0.209562  0.307317
# 2025-05-05       0.270653  0.239130  0.173183  0.134903  0.148476  0.151626
#
#                        co        o3        no       no2   factor1   factor2  \
# timestamp_local
# 2025-05-01       0.484700  0.588939  0.037817  0.379566  0.037390  0.001560
# 2025-05-02       0.569166  0.468358  0.045169  0.652130  0.064490  0.062986
# 2025-05-03       0.540094  0.492539  0.043660  0.522795  0.050975  0.041240
# 2025-05-04       0.492751  0.385142  0.033450  0.521635  0.051110  0.077577
# 2025-05-05       0.461547  0.354167  0.044911  0.355275  0.033624  0.097027
#
#                   factor3
# timestamp_local
# 2025-05-01       0.146635
# 2025-05-02       0.084525
# 2025-05-03       0.104563
# 2025-05-04       0.068027
# 2025-05-05       0.075289

# %% [markdown]
# ## Setting Up Barchart and 6-month Figures

# %%
# set up the figure
fig = plt.figure(figsize=(9, 8))

ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

# %%
cols = ['bin0', 'bin1', 'bin2','bin3','bin4','bin5','co', 'o3','no', 'no2']

pal = sns.color_palette()

colors = [pal[3], pal[2], pal[4], pal[5]]
colors += sns.color_palette("Blues", 6)
colors.reverse()

# %%
ax1 = sns.barplot(x='variable',y='value',
        data=comp2,
        ax=ax1, hue='species',hue_order=cols,
        palette=colors, saturation=1, edgecolor='black', linewidth=0.25,
        errwidth=.75)
# Out:
# /tmp/ipykernel_447/2976516543.py:1: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 0.75}` instead.
#
#   ax1 = sns.barplot(x='variable',y='value',

# %%
ax1.set_ylim(-0.2, 1)
ax1.set_xlabel("")
ax1.set_ylabel("Percent of Species Signal\nDescribed by Factor", fontsize=14)
ax1.set(yticks=np.linspace(-0.2, 1, 13), yticklabels=["","","0","","","","","50","","","","","100"])
ax1.tick_params(axis='both', which='major', labelsize=14)
ax1.axhline(y=0, color='black', linestyle='-', lw =0.5)

# %%
handles, _ = ax1.get_legend_handles_labels()
labels = ["Bin 0", "Bin 1", "Bin 2", "Bin 3","Bin 4","Bin 5","CO","$O_3$","$NO$", "$NO_2$"]
ax1.legend(handles, labels)

# %%
ax2.plot(ts_day.index, ts_day["factor1"], label="Factor 1 ", lw=1, color=sns.xkcd_rgb['slate blue'])
ax2.plot(ts_day.index, ts_day["factor2"], label="Factor 2", lw=1, color=sns.xkcd_rgb['dull green'])
ax2.plot(ts_day.index, ts_day["factor3"], label="Factor 3", lw=1, color=sns.xkcd_rgb['dark lavender'])

ax2.set_ylabel("Factor Intensity (a.u.)", fontsize=14)

#last 6 months
ax2.set_xlim(ts_day.index[-180], ts_day.index[-1])
#ax2.set_xlim(ts_day.index[0], ts_day.index[-1])

ax2.legend(loc='upper right',fontsize=10)
ax2.tick_params(axis='both', which='major', labelsize=14)

# %%
ax1.set_title('(a)',fontsize=14)
ax2.set_title('(b)',fontsize=14)
# Out:
# Text(0.5, 1.0, '(b)')

# %%
plt.gcf().text(0.09, 0.9, "(a)", fontsize=12)
plt.gcf().text(0.5, 0.9, "(b)", fontsize=12)
plt.gcf().text(0.09,0.9,'MOD-00397',fontsize=12)

plt.tight_layout()

# %%
fig.savefig('time_barchart_MOD-00684_3_factor.png')

# %%
fig

# %% [markdown]
# ## Setting Up Diurnal Figure

# %%
ts.head()
# Out:
#       timestamp_local      bin0      bin1      bin2      bin3      bin4  \
# 0 2025-05-01 09:00:00  0.043202  0.014219  0.009703  0.008969  0.014749
# 1 2025-05-01 10:00:00  0.041017  0.013929  0.010274  0.008969  0.017699
# 2 2025-05-01 11:00:00  0.040123  0.012768  0.009703  0.008969  0.017699
# 3 2025-05-01 12:00:00  0.036349  0.011027  0.008562  0.008969  0.014749
# 4 2025-05-01 13:00:00  0.039527  0.011027  0.008562  0.008969  0.014749
#
#        bin5        co        o3        no       no2  Factor 1  Factor 2  \
# 0  0.019512  0.501834  0.488311  0.035096  0.183910  0.015334       0.0
# 1  0.019512  0.466209  0.521108  0.037218  0.123767  0.009434       0.0
# 2  0.019512  0.439626  0.577054  0.039830  0.152002  0.013162       0.0
# 3  0.014634  0.417050  0.611439  0.039993  0.173661  0.016068       0.0
# 4  0.014634  0.429084  0.627326  0.039993  0.177142  0.016332       0.0
#
#    Factor 3
# 0  0.135044
# 1  0.150216
# 2  0.164143
# 3  0.172125
# 4  0.176807

# %%
#prepping data
ts = ts.set_index('timestamp_local')
ts['Hour'] = ts.index.hour
ts.head()
# Out:
#                          bin0      bin1      bin2      bin3      bin4  \
# timestamp_local
# 2025-05-01 09:00:00  0.043202  0.014219  0.009703  0.008969  0.014749
# 2025-05-01 10:00:00  0.041017  0.013929  0.010274  0.008969  0.017699
# 2025-05-01 11:00:00  0.040123  0.012768  0.009703  0.008969  0.017699
# 2025-05-01 12:00:00  0.036349  0.011027  0.008562  0.008969  0.014749
# 2025-05-01 13:00:00  0.039527  0.011027  0.008562  0.008969  0.014749
#
#                          bin5        co        o3        no       no2  \
# timestamp_local
# 2025-05-01 09:00:00  0.019512  0.501834  0.488311  0.035096  0.183910
# 2025-05-01 10:00:00  0.019512  0.466209  0.521108  0.037218  0.123767
# 2025-05-01 11:00:00  0.019512  0.439626  0.577054  0.039830  0.152002
# 2025-05-01 12:00:00  0.014634  0.417050  0.611439  0.039993  0.173661
# 2025-05-01 13:00:00  0.014634  0.429084  0.627326  0.039993  0.177142
#
#                      Factor 1  Factor 2  Factor 3  Hour
# timestamp_local
# 2025-05-01 09:00:00  0.015334       0.0  0.135044     9
# 2025-05-01 10:00:00  0.009434       0.0  0.150216    10
# 2025-05-01 11:00:00  0.013162       0.0  0.164143    11
# 2025-05-01 12:00:00  0.016068       0.0  0.172125    12
# 2025-05-01 13:00:00  0.016332       0.0  0.176807    13

# %%
#grouping by hour and calculate the mean
diurnal_data = ts.groupby('Hour')[['Factor 1','Factor 2','Factor 3']].mean()
diurnal_data.index = diurnal_data.index.map(lambda x: "{:02d}:00".format(x))
diurnal_data
# Out:
#        Factor 1  Factor 2  Factor 3
# Hour
# 00:00  0.051005  0.034097  0.069504
# 01:00  0.051049  0.034516  0.066765
# 02:00  0.051554  0.034881  0.063448
# 03:00  0.051261  0.035510  0.061049
# 04:00  0.049898  0.036385  0.059007
# 05:00  0.050667  0.037938  0.053476
# 06:00  0.051207  0.037779  0.048912
# 07:00  0.047094  0.036136  0.052599
# 08:00  0.042065  0.032786  0.062235
# 09:00  0.038961  0.030334  0.074534
# 10:00  0.036570  0.028646  0.088486
# 11:00  0.038473  0.027238  0.099127
# 12:00  0.041178  0.026818  0.107253
# 13:00  0.043581  0.025280  0.112751
# 14:00  0.043900  0.024555  0.116724
# 15:00  0.046316  0.024578  0.116226
# 16:00  0.048860  0.023435  0.113157
# 17:00  0.053207  0.022895  0.106228
# 18:00  0.056213  0.023905  0.097597
# 19:00  0.057551  0.027153  0.089759
# 20:00  0.056843  0.029952  0.082593
# 21:00  0.054926  0.032540  0.076807
# 22:00  0.052638  0.033044  0.073924
# 23:00  0.051147  0.033005  0.071719

# %%
# set up the figure
plt.figure(figsize=(10, 6))

plt.plot(diurnal_data.index, diurnal_data['Factor 1'], label='Factor 1', lw = 2, color=sns.xkcd_rgb['slate blue'])
plt.plot(diurnal_data.index, diurnal_data['Factor 2'], label='Factor 2', lw = 2, color=sns.xkcd_rgb['dull green'])
plt.plot(diurnal_data.index, diurnal_data['Factor 3'], label='Factor 3', lw = 2, color=sns.xkcd_rgb['dark lavender'])

plt.ylabel('Factor Intensity (a.u.)', fontsize = 14)
plt.legend(loc='upper right',fontsize=14)
plt.xticks(range(0, 24))
plt.xticks(rotation=45)

plt.tick_params(labelsize=14)

plt.savefig('diurnal_MOD-00684_3_factor.png')
plt.show()
