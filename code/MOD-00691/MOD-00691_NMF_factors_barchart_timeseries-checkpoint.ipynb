# %% [markdown]
# # Factor Bar Chart and Timeseries Figures

# %%
import numpy as np
import seaborn as sns
import joblib
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.dates as mdates
import matplotlib.ticker as mticker
from matplotlib.ticker import FuncFormatter

# %%
# force the math text to look normal
mpl.rcParams['mathtext.default'] = 'regular'

def major_ticks(x, pos=None):
    """Set the major ticks according
    to this custom style
    """
    x = mdates.num2date(x)
    if pos == 0:
        fmt = "%-d\n%b %Y\n%I %p"
    else:
        fmt = "%-d"
    return x.strftime(fmt)

# set the default seaborn params
sns.set("paper", "ticks", color_codes=True, palette='colorblind')

# %% [markdown]
# ## Loading Data

# %%
#load in the comp data
comp = pd.read_csv('MOD-00691_4_factor_resid.csv')
comp.rename(columns={'Unnamed: 0':'species'},inplace=True)
comp
# Out:
#   species  Factor 1  Factor 2  Factor 3  Factor 4  Residual
# 0      co  0.552402  0.126984  0.006827  0.294700  0.019086
# 1      no  0.508925  0.080755  0.011035  0.374868  0.024416
# 2     no2  0.965897  0.023315  0.013670  0.000000 -0.002882
# 3      o3  0.299065  0.004684  0.002463  0.698139 -0.004350
# 4    bin0  0.047610  0.816019  0.000000  0.144891 -0.008519
# 5    bin1  0.000000  0.802041  0.307140  0.000000 -0.109181
# 6    bin2  0.000000  0.477608  0.579312  0.000000 -0.056920
# 7    bin3  0.045825  0.207704  0.720059  0.030702 -0.004289
# 8    bin4  0.130712  0.032162  0.649123  0.181546  0.006457
# 9    bin5  0.225994  0.000000  0.523619  0.237222  0.013165

# %%
comp2 = pd.melt(comp,id_vars='species', value_vars=['Factor 1','Factor 2','Factor 3','Residual'])
comp2
# Out:
#    species  variable     value
# 0       co  Factor 1  0.552402
# 1       no  Factor 1  0.508925
# 2      no2  Factor 1  0.965897
# 3       o3  Factor 1  0.299065
# 4     bin0  Factor 1  0.047610
# 5     bin1  Factor 1  0.000000
# 6     bin2  Factor 1  0.000000
# 7     bin3  Factor 1  0.045825
# 8     bin4  Factor 1  0.130712
# 9     bin5  Factor 1  0.225994
# 10      co  Factor 2  0.126984
# 11      no  Factor 2  0.080755
# 12     no2  Factor 2  0.023315
# 13      o3  Factor 2  0.004684
# 14    bin0  Factor 2  0.816019
# 15    bin1  Factor 2  0.802041
# 16    bin2  Factor 2  0.477608
# 17    bin3  Factor 2  0.207704
# 18    bin4  Factor 2  0.032162
# 19    bin5  Factor 2  0.000000
# 20      co  Factor 3  0.006827
# 21      no  Factor 3  0.011035
# 22     no2  Factor 3  0.013670
# 23      o3  Factor 3  0.002463
# 24    bin0  Factor 3  0.000000
# 25    bin1  Factor 3  0.307140
# 26    bin2  Factor 3  0.579312
# 27    bin3  Factor 3  0.720059
# 28    bin4  Factor 3  0.649123
# 29    bin5  Factor 3  0.523619
# 30      co  Residual  0.019086
# 31      no  Residual  0.024416
# 32     no2  Residual -0.002882
# 33      o3  Residual -0.004350
# 34    bin0  Residual -0.008519
# 35    bin1  Residual -0.109181
# 36    bin2  Residual -0.056920
# 37    bin3  Residual -0.004289
# 38    bin4  Residual  0.006457
# 39    bin5  Residual  0.013165

# %%
#load in the timeseries data
ts = pd.read_csv('MOD-00691_timeseries_hourly_scaled.csv').reset_index()
results = pd.read_csv('MOD-00691_4_factor_results.csv')

ts = pd.concat([ts,results['Factor 1'],results['Factor 2'], results['Factor 3']], axis = 1)
cols_reordered = ['timestamp_local','bin0','bin1','bin2','bin3','bin4','bin5','co','o3','no','no2','Factor 1','Factor 2','Factor 3']
ts = ts[cols_reordered]
ts.head()
# Out:
#        timestamp_local      bin0      bin1      bin2      bin3      bin4  \
# 0  2025-03-31 20:00:00  0.324559  0.086090  0.090480  0.119048  0.190909
# 1  2025-03-31 21:00:00  0.448298  0.175738  0.133753  0.142857  0.224242
# 2  2025-03-31 22:00:00  0.380517  0.193881  0.130606  0.121693  0.175758
# 3  2025-03-31 23:00:00  0.262137  0.178940  0.110936  0.084656  0.096970
# 4  2025-04-01 00:00:00  0.257566  0.133760  0.084186  0.063492  0.075758
#
#       bin5        co        o3        no       no2  Factor 1  Factor 2  \
# 0  0.33125  0.336376  0.314695  0.053379  0.704723  0.052674  0.056134
# 1  0.39375  0.365083  0.295907  0.069945  0.771077  0.055748  0.084044
# 2  0.28750  0.437714  0.355961  0.073363  0.695550  0.052232  0.077420
# 3  0.12500  0.397106  0.476292  0.073363  0.417642  0.031850  0.056461
# 4  0.09375  0.446590  0.505927  0.071785  0.497658  0.039923  0.054699
#
#    Factor 3
# 0  0.104755
# 1  0.132464
# 2  0.106289
# 3  0.061587
# 4  0.041140

# %%
ts['timestamp_local'] = pd.to_datetime(ts['timestamp_local']) #convert timestamp column to pandas timestamp format
ts = ts.set_index('timestamp_local',append=False) #setindex as local time
ts
# Out:
#                          bin0      bin1      bin2      bin3      bin4  \
# timestamp_local
# 2025-03-31 20:00:00  0.324559  0.086090  0.090480  0.119048  0.190909
# 2025-03-31 21:00:00  0.448298  0.175738  0.133753  0.142857  0.224242
# 2025-03-31 22:00:00  0.380517  0.193881  0.130606  0.121693  0.175758
# 2025-03-31 23:00:00  0.262137  0.178940  0.110936  0.084656  0.096970
# 2025-04-01 00:00:00  0.257566  0.133760  0.084186  0.063492  0.075758
# ...                       ...       ...       ...       ...       ...
# 2025-12-31 14:00:00  0.107346  0.021700  0.014162  0.007937  0.009091
# 2025-12-31 15:00:00  0.098834  0.021700  0.013375  0.007937  0.009091
# 2025-12-31 16:00:00  0.116173  0.028460  0.017309  0.010582  0.009091
# 2025-12-31 17:00:00  0.125158  0.033084  0.020456  0.013228  0.012121
# 2025-12-31 18:00:00  0.111286  0.032017  0.019670  0.013228  0.012121
#
#                         bin5        co        o3        no       no2  \
# timestamp_local
# 2025-03-31 20:00:00  0.33125  0.336376  0.314695  0.053379  0.704723
# 2025-03-31 21:00:00  0.39375  0.365083  0.295907  0.069945  0.771077
# 2025-03-31 22:00:00  0.28750  0.437714  0.355961  0.073363  0.695550
# 2025-03-31 23:00:00  0.12500  0.397106  0.476292  0.073363  0.417642
# 2025-04-01 00:00:00  0.09375  0.446590  0.505927  0.071785  0.497658
# ...                      ...       ...       ...       ...       ...
# 2025-12-31 14:00:00  0.01250  0.418723  0.365578  0.053642  0.688720
# 2025-12-31 15:00:00  0.01250  0.358284  0.367032  0.052327  0.690476
# 2025-12-31 16:00:00  0.01250  0.357811  0.338739  0.058375  0.707650
# 2025-12-31 17:00:00  0.01250  0.331530  0.291769  0.053116  0.729118
# 2025-12-31 18:00:00  0.01250  0.339863  0.263811  0.064423  0.742779
#
#                      Factor 1  Factor 2  Factor 3
# timestamp_local
# 2025-03-31 20:00:00  0.052674  0.056134  0.104755
# 2025-03-31 21:00:00  0.055748  0.084044  0.132464
# 2025-03-31 22:00:00  0.052232  0.077420  0.106289
# 2025-03-31 23:00:00  0.031850  0.056461  0.061587
# 2025-04-01 00:00:00  0.039923  0.054699  0.041140
# ...                       ...       ...       ...
# 2025-12-31 14:00:00  0.059069  0.022828  0.000000
# 2025-12-31 15:00:00  0.058351  0.018641  0.000000
# 2025-12-31 16:00:00  0.059623  0.023003  0.000000
# 2025-12-31 17:00:00  0.060972  0.024962  0.000357
# 2025-12-31 18:00:00  0.062490  0.023260  0.000810
#
# [6499 rows x 13 columns]

# %%
#taking daily average of ts. round to floor of the day
ts = ts.reset_index()

ts_day = ts.groupby(ts['timestamp_local'].dt.floor('d')).agg(bin0 = ('bin0','mean'),
                                                  bin1 = ('bin1','mean'),
                                                  bin2 = ('bin2','mean'),
                                                  bin3 = ('bin3','mean'),
                                                  bin4 = ('bin4','mean'),
                                                  bin5 = ('bin5','mean'),
                                                  co = ('co','mean'),
                                                  o3 = ('o3','mean'),
                                                  no = ('no','mean'),
                                                  no2 = ('no2','mean'),
                                                  factor1 = ('Factor 1','mean'),
                                                  factor2 = ('Factor 2','mean'),
                                                  factor3 = ('Factor 3','mean')).reset_index()

ts_day = ts_day.set_index('timestamp_local')
ts_day.head()
# Out:
#                      bin0      bin1      bin2      bin3      bin4      bin5  \
# timestamp_local
# 2025-03-31       0.353878  0.158662  0.116444  0.117063  0.171970  0.284375
# 2025-04-01       0.075169  0.036375  0.025636  0.018188  0.019192  0.019792
# 2025-04-02       0.049489  0.021715  0.027603  0.034502  0.054924  0.094010
# 2025-04-03       0.290268  0.102529  0.079432  0.096340  0.162753  0.288542
# 2025-04-04       0.070500  0.019522  0.016490  0.016093  0.023990  0.035156
#
#                        co        o3        no       no2   factor1   factor2  \
# timestamp_local
# 2025-03-31       0.384070  0.360713  0.067512  0.647248  0.048126  0.068515
# 2025-04-01       0.296575  0.483589  0.057816  0.472775  0.039318  0.011323
# 2025-04-02       0.273713  0.548530  0.053423  0.587440  0.047438  0.000948
# 2025-04-03       0.353140  0.329834  0.060303  0.547082  0.041077  0.054306
# 2025-04-04       0.321580  0.432934  0.057159  0.387759  0.033299  0.012180
#
#                   factor3
# timestamp_local
# 2025-03-31       0.101274
# 2025-04-01       0.008892
# 2025-04-02       0.028871
# 2025-04-03       0.090903
# 2025-04-04       0.007969

# %% [markdown]
# ## Setting Up Barchart and 6-month Figures

# %%
# set up the figure
fig = plt.figure(figsize=(9, 8))

ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

# %%
cols = ['bin0', 'bin1', 'bin2','bin3','bin4','bin5','co', 'o3','no', 'no2']

pal = sns.color_palette()

colors = [pal[3], pal[2], pal[4], pal[5]]
colors += sns.color_palette("Blues", 6)
colors.reverse()

# %%
ax1 = sns.barplot(x='variable',y='value',
        data=comp2,
        ax=ax1, hue='species',hue_order=cols,
        palette=colors, saturation=1, edgecolor='black', linewidth=0.25,
        errwidth=.75)
# Out:
# /tmp/ipykernel_6496/2976516543.py:1: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 0.75}` instead.
#
#   ax1 = sns.barplot(x='variable',y='value',

# %%
ax1.set_ylim(-0.2, 1)
ax1.set_xlabel("")
ax1.set_ylabel("Percent of Species Signal\nDescribed by Factor", fontsize=14)
ax1.set(yticks=np.linspace(-0.2, 1, 13), yticklabels=["","","0","","","","","50","","","","","100"])
ax1.tick_params(axis='both', which='major', labelsize=14)
ax1.axhline(y=0, color='black', linestyle='-', lw =0.5)

# %%
handles, _ = ax1.get_legend_handles_labels()
labels = ["Bin 0", "Bin 1", "Bin 2", "Bin 3","Bin 4","Bin 5","CO","$O_3$","$NO$", "$NO_2$"]
ax1.legend(handles, labels)

# %%
ax2.clear()

# %%
ax2.plot(ts_day.index, ts_day["factor1"], label="Factor 1 ", lw=1.5, color=sns.xkcd_rgb['slate blue'])
ax2.plot(ts_day.index, ts_day["factor2"], label="Factor 2", lw=1.5, color=sns.xkcd_rgb['dull green'])
ax2.plot(ts_day.index, ts_day["factor3"], label="Factor 3", lw=1.5, color=sns.xkcd_rgb['dark lavender'])

ax2.set_ylabel("Factor Intensity (a.u.)", fontsize=14)

#last 6 months
ax2.set_xlim(ts_day.index[-180], ts_day.index[-1])
# ax2.set_xlim(ts_day.index[0], ts_day.index[-1])

ax2.legend(loc='upper right',fontsize=10)
ax2.tick_params(axis='both', which='major', labelsize=14)
ax2.tick_params(axis='x', rotation=45)

# %%
ax1.set_title('(a)',fontsize=14)
ax2.set_title('(b)',fontsize=14)
# Out:
# Text(0.5, 1.0, '(b)')

# %%
plt.gcf().text(0.09, 0.9, "(a)", fontsize=12)
plt.gcf().text(0.5, 0.9, "(b)", fontsize=12)
plt.gcf().text(0.09,0.9,'MOD-00397',fontsize=12)

plt.tight_layout()

# %%
#fig.savefig('time_barchart_MOD-00691_3_factor.png')

# %%
fig

# %% [markdown]
# ## Setting Up Diurnal Figure

# %%
ts.head()
# Out:
#       timestamp_local      bin0      bin1      bin2      bin3      bin4  \
# 0 2025-03-31 20:00:00  0.324559  0.086090  0.090480  0.119048  0.190909
# 1 2025-03-31 21:00:00  0.448298  0.175738  0.133753  0.142857  0.224242
# 2 2025-03-31 22:00:00  0.380517  0.193881  0.130606  0.121693  0.175758
# 3 2025-03-31 23:00:00  0.262137  0.178940  0.110936  0.084656  0.096970
# 4 2025-04-01 00:00:00  0.257566  0.133760  0.084186  0.063492  0.075758
#
#       bin5        co        o3        no       no2  Factor 1  Factor 2  \
# 0  0.33125  0.336376  0.314695  0.053379  0.704723  0.052674  0.056134
# 1  0.39375  0.365083  0.295907  0.069945  0.771077  0.055748  0.084044
# 2  0.28750  0.437714  0.355961  0.073363  0.695550  0.052232  0.077420
# 3  0.12500  0.397106  0.476292  0.073363  0.417642  0.031850  0.056461
# 4  0.09375  0.446590  0.505927  0.071785  0.497658  0.039923  0.054699
#
#    Factor 3
# 0  0.104755
# 1  0.132464
# 2  0.106289
# 3  0.061587
# 4  0.041140

# %%
#prepping data
ts = ts.set_index('timestamp_local')
ts['Hour'] = ts.index.hour
ts.head()
# Out:
#                          bin0      bin1      bin2      bin3      bin4  \
# timestamp_local
# 2025-03-31 20:00:00  0.324559  0.086090  0.090480  0.119048  0.190909
# 2025-03-31 21:00:00  0.448298  0.175738  0.133753  0.142857  0.224242
# 2025-03-31 22:00:00  0.380517  0.193881  0.130606  0.121693  0.175758
# 2025-03-31 23:00:00  0.262137  0.178940  0.110936  0.084656  0.096970
# 2025-04-01 00:00:00  0.257566  0.133760  0.084186  0.063492  0.075758
#
#                         bin5        co        o3        no       no2  \
# timestamp_local
# 2025-03-31 20:00:00  0.33125  0.336376  0.314695  0.053379  0.704723
# 2025-03-31 21:00:00  0.39375  0.365083  0.295907  0.069945  0.771077
# 2025-03-31 22:00:00  0.28750  0.437714  0.355961  0.073363  0.695550
# 2025-03-31 23:00:00  0.12500  0.397106  0.476292  0.073363  0.417642
# 2025-04-01 00:00:00  0.09375  0.446590  0.505927  0.071785  0.497658
#
#                      Factor 1  Factor 2  Factor 3  Hour
# timestamp_local
# 2025-03-31 20:00:00  0.052674  0.056134  0.104755    20
# 2025-03-31 21:00:00  0.055748  0.084044  0.132464    21
# 2025-03-31 22:00:00  0.052232  0.077420  0.106289    22
# 2025-03-31 23:00:00  0.031850  0.056461  0.061587    23
# 2025-04-01 00:00:00  0.039923  0.054699  0.041140     0

# %%
#grouping by hour and calculate the mean
diurnal_data = ts.groupby('Hour')[['Factor 1','Factor 2','Factor 3']].mean()
diurnal_data.index = diurnal_data.index.map(lambda x: "{:02d}:00".format(x))
diurnal_data
# Out:
#        Factor 1  Factor 2  Factor 3
# Hour
# 00:00  0.045902  0.028896  0.020058
# 01:00  0.045782  0.029544  0.017549
# 02:00  0.045598  0.030003  0.017210
# 03:00  0.044798  0.030631  0.017402
# 04:00  0.044942  0.032488  0.019107
# 05:00  0.046684  0.033750  0.019874
# 06:00  0.047830  0.034684  0.019627
# 07:00  0.045346  0.033240  0.017984
# 08:00  0.040319  0.031764  0.015575
# 09:00  0.036768  0.028993  0.014281
# 10:00  0.033213  0.026411  0.011748
# 11:00  0.032019  0.024512  0.009703
# 12:00  0.032080  0.022502  0.008894
# 13:00  0.033955  0.020998  0.008461
# 14:00  0.034427  0.020373  0.008154
# 15:00  0.036004  0.020693  0.008189
# 16:00  0.038856  0.019874  0.008206
# 17:00  0.043757  0.019933  0.008583
# 18:00  0.046936  0.021157  0.009976
# 19:00  0.050322  0.023081  0.012833
# 20:00  0.049575  0.025910  0.014184
# 21:00  0.048356  0.028075  0.015725
# 22:00  0.046542  0.029373  0.016275
# 23:00  0.046325  0.029141  0.017709

# %%
# set up the figure
plt.figure(figsize=(10, 6))

plt.plot(diurnal_data.index, diurnal_data['Factor 1'], label='Factor 1', lw = 2, color=sns.xkcd_rgb['slate blue'])
plt.plot(diurnal_data.index, diurnal_data['Factor 2'], label='Factor 2', lw = 2, color=sns.xkcd_rgb['dull green'])
plt.plot(diurnal_data.index, diurnal_data['Factor 3'], label='Factor 3', lw = 2, color=sns.xkcd_rgb['dark lavender'])

plt.ylabel('Factor Intensity (a.u.)', fontsize = 14)
plt.legend(loc='upper right',fontsize=14)
plt.xticks(range(0, 24))
plt.xticks(rotation=45)

plt.tick_params(labelsize=14)

# plt.savefig('diurnal_MOD-00691_3_factor.png')
plt.show()
