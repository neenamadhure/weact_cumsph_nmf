# %% [markdown]
# # Factor Bar Chart and Timeseries Figures

# %%
import numpy as np
import seaborn as sns
import joblib
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.dates as mdates
import matplotlib.ticker as mticker
from matplotlib.ticker import FuncFormatter

# %%
# force the math text to look normal
mpl.rcParams['mathtext.default'] = 'regular'

def major_ticks(x, pos=None):
    """Set the major ticks according
    to this custom style
    """
    x = mdates.num2date(x)
    if pos == 0:
        fmt = "%-d\n%b %Y\n%I %p"
    else:
        fmt = "%-d"
    return x.strftime(fmt)

# set the default seaborn params
sns.set("paper", "ticks", color_codes=True, palette='colorblind')

# %% [markdown]
# ## Loading Data

# %%
#load in the comp data
comp = pd.read_csv('4_factor_resid.csv')
comp.rename(columns={'Unnamed: 0':'species'},inplace=True)
comp
# Out:
#   species  Factor 1  Factor 2  Factor 3  Factor 4  Residual
# 0      co  0.560682  0.124961  0.286146  0.006121  0.022089
# 1      no  0.670094  0.111437  0.177592  0.016334  0.024543
# 2     no2  0.135402  0.024485  0.839267  0.003553 -0.002707
# 3      o3  0.896494  0.106935  0.000000  0.000000 -0.003429
# 4    bin0  0.181395  0.772507  0.049446  0.000000 -0.003348
# 5    bin1  0.000000  0.765307  0.000000  0.332359 -0.097666
# 6    bin2  0.000000  0.417252  0.000000  0.618201 -0.035453
# 7    bin3  0.126145  0.124247  0.009769  0.744133 -0.004295
# 8    bin4  0.365185  0.000000  0.001142  0.633710 -0.000038
# 9    bin5  0.464131  0.000000  0.000000  0.547029 -0.011160

# %%
comp2 = pd.melt(comp,id_vars='species', value_vars=['Factor 1','Factor 2','Factor 3','Residual'])
comp2
# Out:
#    species  variable     value
# 0       co  Factor 1  0.560682
# 1       no  Factor 1  0.670094
# 2      no2  Factor 1  0.135402
# 3       o3  Factor 1  0.896494
# 4     bin0  Factor 1  0.181395
# 5     bin1  Factor 1  0.000000
# 6     bin2  Factor 1  0.000000
# 7     bin3  Factor 1  0.126145
# 8     bin4  Factor 1  0.365185
# 9     bin5  Factor 1  0.464131
# 10      co  Factor 2  0.124961
# 11      no  Factor 2  0.111437
# 12     no2  Factor 2  0.024485
# 13      o3  Factor 2  0.106935
# 14    bin0  Factor 2  0.772507
# 15    bin1  Factor 2  0.765307
# 16    bin2  Factor 2  0.417252
# 17    bin3  Factor 2  0.124247
# 18    bin4  Factor 2  0.000000
# 19    bin5  Factor 2  0.000000
# 20      co  Factor 3  0.286146
# 21      no  Factor 3  0.177592
# 22     no2  Factor 3  0.839267
# 23      o3  Factor 3  0.000000
# 24    bin0  Factor 3  0.049446
# 25    bin1  Factor 3  0.000000
# 26    bin2  Factor 3  0.000000
# 27    bin3  Factor 3  0.009769
# 28    bin4  Factor 3  0.001142
# 29    bin5  Factor 3  0.000000
# 30      co  Residual  0.022089
# 31      no  Residual  0.024543
# 32     no2  Residual -0.002707
# 33      o3  Residual -0.003429
# 34    bin0  Residual -0.003348
# 35    bin1  Residual -0.097666
# 36    bin2  Residual -0.035453
# 37    bin3  Residual -0.004295
# 38    bin4  Residual -0.000038
# 39    bin5  Residual -0.011160

# %%
#load in the timeseries data
ts = pd.read_csv('MOD-00678_timeseries_hourly_scaled.csv').reset_index()
results = pd.read_csv('4_factor_results.csv')

ts = pd.concat([ts,results['Factor 1'],results['Factor 2'], results['Factor 3']], axis = 1)
cols_reordered = ['timestamp_local','bin0','bin1','bin2','bin3','bin4','bin5','co','o3','no','no2','Factor 1','Factor 2', 'Factor 3']
ts = ts[cols_reordered]
ts.head()
# Out:
#        timestamp_local      bin0      bin1      bin2      bin3      bin4  \
# 0  2025-04-15 14:00:00  0.048617  0.013971  0.009901  0.010661  0.018135
# 1  2025-04-15 15:00:00  0.028296  0.010245  0.008154  0.010661  0.020725
# 2  2025-04-15 16:00:00  0.023666  0.008693  0.007571  0.010661  0.018135
# 3  2025-04-15 17:00:00  0.028810  0.009314  0.006989  0.008529  0.012953
# 4  2025-04-15 18:00:00  0.025723  0.007762  0.005242  0.004264  0.007772
#
#        bin5        co        o3        no       no2  Factor 1  Factor 2  \
# 0  0.024490  0.280959  0.758663  0.080952  0.192808  0.079037  0.000482
# 1  0.024490  0.249577  0.754359  0.088095  0.181331  0.077917  0.000000
# 2  0.020408  0.239531  0.722688  0.063333  0.399133  0.073224  0.000000
# 3  0.016327  0.243084  0.697859  0.062857  0.251977  0.071805  0.000000
# 4  0.008163  0.257694  0.701721  0.063810  0.287427  0.072314  0.000000
#
#    Factor 3
# 0  0.017322
# 1  0.014681
# 2  0.052671
# 3  0.028350
# 4  0.034710

# %%
ts['timestamp_local'] = pd.to_datetime(ts['timestamp_local']) #convert timestamp column to pandas timestamp format
ts = ts.set_index('timestamp_local',append=False) #setindex as local time
ts
# Out:
#                          bin0      bin1      bin2      bin3      bin4  \
# timestamp_local
# 2025-04-15 14:00:00  0.048617  0.013971  0.009901  0.010661  0.018135
# 2025-04-15 15:00:00  0.028296  0.010245  0.008154  0.010661  0.020725
# 2025-04-15 16:00:00  0.023666  0.008693  0.007571  0.010661  0.018135
# 2025-04-15 17:00:00  0.028810  0.009314  0.006989  0.008529  0.012953
# 2025-04-15 18:00:00  0.025723  0.007762  0.005242  0.004264  0.007772
# ...                       ...       ...       ...       ...       ...
# 2025-12-31 14:00:00  0.123215  0.040050  0.025626  0.027719  0.051813
# 2025-12-31 15:00:00  0.114984  0.036014  0.022132  0.021322  0.036269
# 2025-12-31 16:00:00  0.113055  0.026700  0.013395  0.008529  0.010363
# 2025-12-31 17:00:00  0.102894  0.024216  0.009901  0.004264  0.007772
# 2025-12-31 18:00:00  0.097749  0.025147  0.009901  0.004264  0.005181
#
#                          bin5        co        o3        no       no2  \
# timestamp_local
# 2025-04-15 14:00:00  0.024490  0.280959  0.758663  0.080952  0.192808
# 2025-04-15 15:00:00  0.024490  0.249577  0.754359  0.088095  0.181331
# 2025-04-15 16:00:00  0.020408  0.239531  0.722688  0.063333  0.399133
# 2025-04-15 17:00:00  0.016327  0.243084  0.697859  0.062857  0.251977
# 2025-04-15 18:00:00  0.008163  0.257694  0.701721  0.063810  0.287427
# ...                       ...       ...       ...       ...       ...
# 2025-12-31 14:00:00  0.065306  0.221726  0.464467  0.048333  0.602142
# 2025-12-31 15:00:00  0.040816  0.223029  0.459281  0.044762  0.623565
# 2025-12-31 16:00:00  0.008163  0.228715  0.443280  0.052381  0.639888
# 2025-12-31 17:00:00  0.004082  0.233243  0.409623  0.049524  0.671767
# 2025-12-31 18:00:00  0.004082  0.233739  0.391304  0.057619  0.689875
#
#                      Factor 1  Factor 2  Factor 3
# timestamp_local
# 2025-04-15 14:00:00  0.079037  0.000482  0.017322
# 2025-04-15 15:00:00  0.077917  0.000000  0.014681
# 2025-04-15 16:00:00  0.073224  0.000000  0.052671
# 2025-04-15 17:00:00  0.071805  0.000000  0.028350
# 2025-04-15 18:00:00  0.072314  0.000000  0.034710
# ...                       ...       ...       ...
# 2025-12-31 14:00:00  0.043747  0.017674  0.093780
# 2025-12-31 15:00:00  0.043325  0.016510  0.097872
# 2025-12-31 16:00:00  0.041725  0.017289  0.101622
# 2025-12-31 17:00:00  0.038807  0.015356  0.108301
# 2025-12-31 18:00:00  0.037190  0.014505  0.112017
#
# [6146 rows x 13 columns]

# %%
#taking daily average of ts. round to floor of the day
ts = ts.reset_index()

ts_day = ts.groupby(ts['timestamp_local'].dt.floor('d')).agg(bin0 = ('bin0','mean'),
                                                  bin1 = ('bin1','mean'),
                                                  bin2 = ('bin2','mean'),
                                                  bin3 = ('bin3','mean'),
                                                  bin4 = ('bin4','mean'),
                                                  bin5 = ('bin5','mean'),
                                                  co = ('co','mean'),
                                                  o3 = ('o3','mean'),
                                                  no = ('no','mean'),
                                                  no2 = ('no2','mean'),
                                                  factor1 = ('Factor 1','mean'),
                                                  factor2 = ('Factor 2','mean'),
                                                  factor3 = ('Factor 3', 'mean')).reset_index()

ts_day = ts_day.set_index('timestamp_local')
ts_day.head()
# Out:
#                      bin0      bin1      bin2      bin3      bin4      bin5  \
# timestamp_local
# 2025-04-15       0.026405  0.008320  0.005941  0.006183  0.010363  0.012245
# 2025-04-16       0.020565  0.005670  0.003740  0.002581  0.004091  0.004511
# 2025-04-17       0.041484  0.010556  0.006868  0.005864  0.008744  0.008333
# 2025-04-18       0.086897  0.032275  0.026815  0.029318  0.046524  0.055442
# 2025-04-19       0.167674  0.038963  0.031911  0.036869  0.063040  0.079422
#
#                        co        o3        no       no2   factor1   factor2  \
# timestamp_local
# 2025-04-15       0.250206  0.683911  0.065238  0.327621  0.070215  0.000048
# 2025-04-16       0.240660  0.630017  0.049386  0.293306  0.064883  0.000000
# 2025-04-17       0.245989  0.649824  0.048790  0.345660  0.066596  0.000659
# 2025-04-18       0.285218  0.632794  0.090149  0.529223  0.063768  0.008891
# 2025-04-19       0.264903  0.649507  0.064901  0.494655  0.061756  0.025421
#
#                   factor3
# timestamp_local
# 2025-04-15       0.041918
# 2025-04-16       0.037424
# 2025-04-17       0.045917
# 2025-04-18       0.078250
# 2025-04-19       0.070588

# %% [markdown]
# ## Setting Up Barchart and 6-month Figures

# %%
# set up the figure
fig = plt.figure(figsize=(9,8))

ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

# %%
cols = ['bin0', 'bin1', 'bin2','bin3','bin4','bin5','co', 'o3','no', 'no2']

pal = sns.color_palette()

colors = [pal[3], pal[2], pal[4], pal[5]]
colors += sns.color_palette("Blues", 6)
colors.reverse()

# %%
ax1 = sns.barplot(x='variable',y='value',
        data=comp2,
        ax=ax1, hue='species',hue_order=cols,
        palette=colors, saturation=1, edgecolor='black', linewidth=0.25,
        errwidth=.75)
# Out:
# /tmp/ipykernel_1307/2976516543.py:1: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 0.75}` instead.
#
#   ax1 = sns.barplot(x='variable',y='value',

# %%
ax1.set_ylim(-0.2, 1)
ax1.set_xlabel("")
ax1.set_ylabel("Percent of Species Signal\nDescribed by Factor", fontsize=14)
ax1.set(yticks=np.linspace(-0.2, 1, 13), yticklabels=["","","0","","","","","50","","","","","100"])
ax1.tick_params(axis='both', which='major', labelsize=14)
ax1.axhline(y=0, color='black', linestyle='-', lw =0.5)

# %%
handles, _ = ax1.get_legend_handles_labels()
labels = ["Bin 0", "Bin 1", "Bin 2", "Bin 3","Bin 4","Bin 5","CO","$O_3$","$NO$", "$NO_2$"]
ax1.legend(handles, labels)

# %%
len(ts_day)
# Out:
# 261

# %%
ax2.plot(ts_day.index, ts_day["factor1"], label="Factor 1 ", lw=1, color=sns.xkcd_rgb['slate blue'])
ax2.plot(ts_day.index, ts_day["factor2"], label="Factor 2", lw=1, color=sns.xkcd_rgb['dull green'])
ax2.plot(ts_day.index, ts_day["factor3"], label="Factor 3", lw=1, color=sns.xkcd_rgb['deep purple'])

ax2.set_ylabel("Factor Intensity (a.u.)", fontsize=14)

#last 6 months
ax2.set_xlim(ts_day.index[-180], ts_day.index[-1])
#ax2.set_xlim(ts_day.index[0], ts_day.index[-1])

ax2.legend(loc='upper right',fontsize=10)
ax2.tick_params(axis='both', which='major', labelsize=14)

# %%
ax1.set_title('(a)',fontsize=14)
ax2.set_title('(b)',fontsize=14)
# Out:
# Text(0.5, 1.0, '(b)')

# %%
plt.gcf().text(0.09, 0.9, "(a)", fontsize=12)
plt.gcf().text(0.5, 0.9, "(b)", fontsize=12)
plt.gcf().text(0.09,0.9,'MOD-00397',fontsize=12)

plt.tight_layout()

# %%
fig.savefig('time_barchart_MOD-00678_4_factor.png')

# %%
fig

# %% [markdown]
# ## Setting Up Diurnal Figure

# %%
ts.head()
# Out:
#    index     timestamp_local      bin0      bin1      bin2      bin3  \
# 0      0 2025-04-15 14:00:00  0.048617  0.013971  0.009901  0.010661
# 1      1 2025-04-15 15:00:00  0.028296  0.010245  0.008154  0.010661
# 2      2 2025-04-15 16:00:00  0.023666  0.008693  0.007571  0.010661
# 3      3 2025-04-15 17:00:00  0.028810  0.009314  0.006989  0.008529
# 4      4 2025-04-15 18:00:00  0.025723  0.007762  0.005242  0.004264
#
#        bin4      bin5        co        o3        no       no2  Factor 1  \
# 0  0.018135  0.024490  0.280959  0.758663  0.080952  0.192808  0.079037
# 1  0.020725  0.024490  0.249577  0.754359  0.088095  0.181331  0.077917
# 2  0.018135  0.020408  0.239531  0.722688  0.063333  0.399133  0.073224
# 3  0.012953  0.016327  0.243084  0.697859  0.062857  0.251977  0.071805
# 4  0.007772  0.008163  0.257694  0.701721  0.063810  0.287427  0.072314
#
#    Factor 2  Factor 3
# 0  0.000482  0.017322
# 1  0.000000  0.014681
# 2  0.000000  0.052671
# 3  0.000000  0.028350
# 4  0.000000  0.034710

# %%
#prepping data
ts = ts.set_index('timestamp_local')
ts['Hour'] = ts.index.hour
ts.head()
# Out:
#                      index      bin0      bin1      bin2      bin3      bin4  \
# timestamp_local
# 2025-04-15 14:00:00      0  0.048617  0.013971  0.009901  0.010661  0.018135
# 2025-04-15 15:00:00      1  0.028296  0.010245  0.008154  0.010661  0.020725
# 2025-04-15 16:00:00      2  0.023666  0.008693  0.007571  0.010661  0.018135
# 2025-04-15 17:00:00      3  0.028810  0.009314  0.006989  0.008529  0.012953
# 2025-04-15 18:00:00      4  0.025723  0.007762  0.005242  0.004264  0.007772
#
#                          bin5        co        o3        no       no2  \
# timestamp_local
# 2025-04-15 14:00:00  0.024490  0.280959  0.758663  0.080952  0.192808
# 2025-04-15 15:00:00  0.024490  0.249577  0.754359  0.088095  0.181331
# 2025-04-15 16:00:00  0.020408  0.239531  0.722688  0.063333  0.399133
# 2025-04-15 17:00:00  0.016327  0.243084  0.697859  0.062857  0.251977
# 2025-04-15 18:00:00  0.008163  0.257694  0.701721  0.063810  0.287427
#
#                      Factor 1  Factor 2  Factor 3  Hour
# timestamp_local
# 2025-04-15 14:00:00  0.079037  0.000482  0.017322    14
# 2025-04-15 15:00:00  0.077917  0.000000  0.014681    15
# 2025-04-15 16:00:00  0.073224  0.000000  0.052671    16
# 2025-04-15 17:00:00  0.071805  0.000000  0.028350    17
# 2025-04-15 18:00:00  0.072314  0.000000  0.034710    18

# %%
#grouping by hour and calculate the mean
diurnal_data = ts.groupby('Hour')[['Factor 1','Factor 2', 'Factor 3']].mean()
diurnal_data.index = diurnal_data.index.map(lambda x: "{:02d}:00".format(x))
diurnal_data
# Out:
#        Factor 1  Factor 2  Factor 3
# Hour
# 00:00  0.043358  0.031971  0.067741
# 01:00  0.042524  0.032790  0.066684
# 02:00  0.041900  0.031708  0.065644
# 03:00  0.040808  0.032309  0.063883
# 04:00  0.039560  0.033004  0.065329
# 05:00  0.038002  0.034325  0.069665
# 06:00  0.036942  0.034131  0.071893
# 07:00  0.036771  0.033388  0.065952
# 08:00  0.037766  0.033012  0.055623
# 09:00  0.040199  0.031250  0.044469
# 10:00  0.043148  0.029739  0.043291
# 11:00  0.046630  0.028374  0.043670
# 12:00  0.049770  0.027525  0.045679
# 13:00  0.051997  0.026335  0.047978
# 14:00  0.053760  0.025045  0.051407
# 15:00  0.053984  0.025577  0.058496
# 16:00  0.054070  0.024851  0.063522
# 17:00  0.053457  0.024700  0.068499
# 18:00  0.051981  0.025147  0.071433
# 19:00  0.050503  0.025764  0.074666
# 20:00  0.048533  0.028489  0.074143
# 21:00  0.046773  0.030412  0.071209
# 22:00  0.045276  0.031645  0.070481
# 23:00  0.044251  0.031644  0.068356

# %%
# set up the figure
plt.figure(figsize=(10, 6))

plt.plot(diurnal_data.index, diurnal_data['Factor 1'], label='Factor 1', lw = 2, color=sns.xkcd_rgb['slate blue'])
plt.plot(diurnal_data.index, diurnal_data['Factor 2'], label='Factor 2', lw = 2, color=sns.xkcd_rgb['dull green'])
plt.plot(diurnal_data.index, diurnal_data['Factor 3'], label='Factor 3', lw = 2, color=sns.xkcd_rgb['deep purple'])

plt.ylabel('Factor Intensity (a.u.)', fontsize = 14)
plt.legend(loc='upper right',fontsize=14)
plt.xticks(range(0, 24))
plt.xticks(rotation=45)

plt.tick_params(labelsize=14)

plt.savefig('diurnal_MOD-00678_4_factor.png')
plt.show()
