# %% [markdown]
# # Factor Bar Chart and Timeseries Figures

# %%
import numpy as np
import seaborn as sns
import joblib
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.dates as mdates
import matplotlib.ticker as mticker
from matplotlib.ticker import FuncFormatter

# %%
# force the math text to look normal
mpl.rcParams['mathtext.default'] = 'regular'

def major_ticks(x, pos=None):
    """Set the major ticks according
    to this custom style
    """
    x = mdates.num2date(x)
    if pos == 0:
        fmt = "%-d\n%b %Y\n%I %p"
    else:
        fmt = "%-d"
    return x.strftime(fmt)

# set the default seaborn params
sns.set("paper", "ticks", color_codes=True, palette='colorblind')

# %% [markdown]
# ## Loading Data

# %%
#load in the comp data
comp = pd.read_csv('/content/MOD-00688_factor_resid.csv')
comp.rename(columns={'Unnamed: 0':'species'},inplace=True)
comp
# Out:
#   species  Factor 1  Factor 2  Factor 3  Factor 4  Residual
# 0      co  0.497234  0.174371  0.313198  0.006249  0.008948
# 1      no  0.495194  0.153145  0.341790  0.000000  0.009870
# 2     no2  0.092160  0.012187  0.888721  0.011844 -0.004913
# 3      o3  0.918173  0.084831  0.000000  0.000000 -0.003004
# 4    bin0  0.147913  0.865274  0.000000  0.000000 -0.013187
# 5    bin1  0.000000  0.752591  0.000000  0.384169 -0.136759
# 6    bin2  0.000000  0.414201  0.000000  0.668536 -0.082737
# 7    bin3  0.023413  0.152399  0.013941  0.815352 -0.005105
# 8    bin4  0.254949  0.000000  0.010632  0.734582 -0.000164
# 9    bin5  0.386592  0.000000  0.098972  0.511948  0.002489

# %%
comp2 = pd.melt(comp,id_vars='species', value_vars=['Factor 1','Factor 2','Factor 3','Residual'])
comp2
# Out:
#    species  variable     value
# 0       co  Factor 1  0.497234
# 1       no  Factor 1  0.495194
# 2      no2  Factor 1  0.092160
# 3       o3  Factor 1  0.918173
# 4     bin0  Factor 1  0.147913
# 5     bin1  Factor 1  0.000000
# 6     bin2  Factor 1  0.000000
# 7     bin3  Factor 1  0.023413
# 8     bin4  Factor 1  0.254949
# 9     bin5  Factor 1  0.386592
# 10      co  Factor 2  0.174371
# 11      no  Factor 2  0.153145
# 12     no2  Factor 2  0.012187
# 13      o3  Factor 2  0.084831
# 14    bin0  Factor 2  0.865274
# 15    bin1  Factor 2  0.752591
# 16    bin2  Factor 2  0.414201
# 17    bin3  Factor 2  0.152399
# 18    bin4  Factor 2  0.000000
# 19    bin5  Factor 2  0.000000
# 20      co  Factor 3  0.313198
# 21      no  Factor 3  0.341790
# 22     no2  Factor 3  0.888721
# 23      o3  Factor 3  0.000000
# 24    bin0  Factor 3  0.000000
# 25    bin1  Factor 3  0.000000
# 26    bin2  Factor 3  0.000000
# 27    bin3  Factor 3  0.013941
# 28    bin4  Factor 3  0.010632
# 29    bin5  Factor 3  0.098972
# 30      co  Residual  0.008948
# 31      no  Residual  0.009870
# 32     no2  Residual -0.004913
# 33      o3  Residual -0.003004
# 34    bin0  Residual -0.013187
# 35    bin1  Residual -0.136759
# 36    bin2  Residual -0.082737
# 37    bin3  Residual -0.005105
# 38    bin4  Residual -0.000164
# 39    bin5  Residual  0.002489

# %%
#load in the timeseries data
ts = pd.read_csv('/content/MOD-00688_timeseries_hourly_scaled.csv').reset_index()
results = pd.read_csv('/content/MOD-00688_factor_results.csv')

ts = pd.concat([ts,results['Factor 1'],results['Factor 2'], results['Factor 3']], axis = 1)
cols_reordered = ['timestamp_local','bin0','bin1','bin2','bin3','bin4','bin5','co','o3','no','no2','Factor 1','Factor 2','Factor 3']
ts = ts[cols_reordered]
ts.head()
# Out:
#        timestamp_local      bin0      bin1      bin2      bin3      bin4  \
# 0  2025-03-31 20:00:00  0.255770  0.076895  0.068148  0.082960  0.136247
# 1  2025-03-31 21:00:00  0.335293  0.155275  0.098519  0.098655  0.156812
# 2  2025-03-31 22:00:00  0.321035  0.216568  0.119259  0.105381  0.149100
# 3  2025-03-31 23:00:00  0.132736  0.073923  0.042963  0.035874  0.048843
# 4  2025-04-01 00:00:00  0.155667  0.082095  0.045926  0.038117  0.051414
#
#        bin5        co        o3        no       no2  Factor 1  Factor 2  \
# 0  0.314516  0.487293  0.425632  0.031461  0.473713  0.037878  0.053050
# 1  0.395161  0.476431  0.449958  0.044147  0.397914  0.036727  0.072836
# 2  0.322581  0.519584  0.429626  0.048038  0.462448  0.033991  0.077439
# 3  0.096774  0.390167  0.686797  0.046685  0.214882  0.068195  0.025440
# 4  0.104839  0.363358  0.696236  0.046685  0.284840  0.067184  0.025991
#
#    Factor 3
# 0  0.108573
# 1  0.084562
# 2  0.102970
# 3  0.038721
# 4  0.051518

# %%
ts['timestamp_local'] = pd.to_datetime(ts['timestamp_local']) #convert timestamp column to pandas timestamp format
ts = ts.set_index('timestamp_local',append=False) #setindex as local time
ts
# Out:
#                          bin0      bin1      bin2      bin3      bin4  \
# timestamp_local
# 2025-03-31 20:00:00  0.255770  0.076895  0.068148  0.082960  0.136247
# 2025-03-31 21:00:00  0.335293  0.155275  0.098519  0.098655  0.156812
# 2025-03-31 22:00:00  0.321035  0.216568  0.119259  0.105381  0.149100
# 2025-03-31 23:00:00  0.132736  0.073923  0.042963  0.035874  0.048843
# 2025-04-01 00:00:00  0.155667  0.082095  0.045926  0.038117  0.051414
# ...                       ...       ...       ...       ...       ...
# 2025-12-30 19:00:00  0.016904  0.005572  0.004444  0.002242  0.002571
# 2025-12-30 20:00:00  0.014552  0.005201  0.003704  0.002242  0.002571
# 2025-12-30 21:00:00  0.014405  0.004458  0.002963  0.002242  0.002571
# 2025-12-30 22:00:00  0.014552  0.004458  0.002963  0.002242  0.002571
# 2025-12-31 00:00:00  0.016904  0.005572  0.003704  0.002242  0.002571
#
#                          bin5        co        o3        no       no2  \
# timestamp_local
# 2025-03-31 20:00:00  0.314516  0.487293  0.425632  0.031461  0.473713
# 2025-03-31 21:00:00  0.395161  0.476431  0.449958  0.044147  0.397914
# 2025-03-31 22:00:00  0.322581  0.519584  0.429626  0.048038  0.462448
# 2025-03-31 23:00:00  0.096774  0.390167  0.686797  0.046685  0.214882
# 2025-04-01 00:00:00  0.104839  0.363358  0.696236  0.046685  0.284840
# ...                       ...       ...       ...       ...       ...
# 2025-12-30 19:00:00  0.008065  0.372724  0.466901  0.028078  0.508484
# 2025-12-30 20:00:00  0.008065  0.364817  0.476824  0.030108  0.501252
# 2025-12-30 21:00:00  0.008065  0.364812  0.480576  0.029939  0.498053
# 2025-12-30 22:00:00  0.008065  0.357079  0.486506  0.030108  0.491099
# 2025-12-31 00:00:00  0.008065  0.356323  0.474162  0.031292  0.491794
#
#                      Factor 1  Factor 2  Factor 3
# timestamp_local
# 2025-03-31 20:00:00  0.037878  0.053050  0.108573
# 2025-03-31 21:00:00  0.036727  0.072836  0.084562
# 2025-03-31 22:00:00  0.033991  0.077439  0.102970
# 2025-03-31 23:00:00  0.068195  0.025440  0.038721
# 2025-04-01 00:00:00  0.067184  0.025991  0.051518
# ...                       ...       ...       ...
# 2025-12-30 19:00:00  0.048282  0.000000  0.119876
# 2025-12-30 20:00:00  0.049050  0.000000  0.117182
# 2025-12-30 21:00:00  0.049442  0.000000  0.116280
# 2025-12-30 22:00:00  0.049844  0.000000  0.113837
# 2025-12-31 00:00:00  0.048677  0.000000  0.114547
#
# [5739 rows x 13 columns]

# %%
#taking daily average of ts. round to floor of the day
ts = ts.reset_index()

ts_day = ts.groupby(ts['timestamp_local'].dt.floor('d')).agg(bin0 = ('bin0','mean'),
                                                  bin1 = ('bin1','mean'),
                                                  bin2 = ('bin2','mean'),
                                                  bin3 = ('bin3','mean'),
                                                  bin4 = ('bin4','mean'),
                                                  bin5 = ('bin5','mean'),
                                                  co = ('co','mean'),
                                                  o3 = ('o3','mean'),
                                                  no = ('no','mean'),
                                                  no2 = ('no2','mean'),
                                                  factor1 = ('Factor 1','mean'),
                                                  factor2 = ('Factor 2','mean'),
                                                  factor3 = ('Factor 3','mean')).reset_index()

ts_day = ts_day.set_index('timestamp_local')
ts_day.head()
# Out:
#                      bin0      bin1      bin2      bin3      bin4      bin5  \
# timestamp_local
# 2025-03-31       0.261208  0.130665  0.082222  0.080717  0.122751  0.282258
# 2025-04-01       0.047363  0.019533  0.011265  0.008688  0.010283  0.021169
# 2025-04-02       0.039284  0.018991  0.019537  0.024944  0.039417  0.091734
# 2025-04-03       0.227044  0.100792  0.061759  0.066517  0.111932  0.273858
# 2025-04-04       0.044821  0.013543  0.010741  0.010744  0.015531  0.033266
#
#                        co        o3        no       no2   factor1   factor2  \
# timestamp_local
# 2025-03-31       0.468369  0.498003  0.042583  0.387239  0.044197  0.057191
# 2025-04-01       0.343253  0.621642  0.039355  0.244529  0.064137  0.006398
# 2025-04-02       0.381853  0.643027  0.035049  0.376895  0.066770  0.001026
# 2025-04-03       0.461272  0.428976  0.040863  0.384116  0.038765  0.051730
# 2025-04-04       0.378839  0.561217  0.036888  0.232986  0.059176  0.009421
#
#                   factor3
# timestamp_local
# 2025-03-31       0.083706
# 2025-04-01       0.049639
# 2025-04-02       0.080650
# 2025-04-03       0.087387
# 2025-04-04       0.052278

# %% [markdown]
# ## Setting Up Barchart and 6-month Figures

# %%
# set up the figure
fig = plt.figure(figsize=(9, 8))

ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

# %%
cols = ['bin0', 'bin1', 'bin2','bin3','bin4','bin5','co', 'o3','no', 'no2']

pal = sns.color_palette()

colors = [pal[3], pal[2], pal[4], pal[5]]
colors += sns.color_palette("Blues", 6)
colors.reverse()

# %%
ax1 = sns.barplot(x='variable',y='value',
        data=comp2,
        ax=ax1, hue='species',hue_order=cols,
        palette=colors, saturation=1, edgecolor='black', linewidth=0.25,
        errwidth=.75)
# Out:
# /tmp/ipykernel_768/2976516543.py:1: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 0.75}` instead.
#
#   ax1 = sns.barplot(x='variable',y='value',

# %%
ax1.set_ylim(-0.2, 1)
ax1.set_xlabel("")
ax1.set_ylabel("Percent of Species Signal\nDescribed by Factor", fontsize=14)
ax1.set(yticks=np.linspace(-0.2, 1, 13), yticklabels=["","","0","","","","","50","","","","","100"])
ax1.tick_params(axis='both', which='major', labelsize=14)
ax1.axhline(y=0, color='black', linestyle='-', lw =0.5)

# %%
handles, _ = ax1.get_legend_handles_labels()
labels = ["Bin 0", "Bin 1", "Bin 2", "Bin 3","Bin 4","Bin 5","CO","$O_3$","$NO$", "$NO_2$"]
ax1.legend(handles, labels)

# %%
ax2.plot(ts_day.index, ts_day["factor1"], label="Factor 1 ", lw=1, color=sns.xkcd_rgb['slate blue'])
ax2.plot(ts_day.index, ts_day["factor2"], label="Factor 2", lw=1, color=sns.xkcd_rgb['dull green'])
ax2.plot(ts_day.index, ts_day["factor3"], label="Factor 3", lw=1, color=sns.xkcd_rgb['dark lavender'])

ax2.set_ylabel("Factor Intensity (a.u.)", fontsize=14)

#last 6 months
ax2.set_xlim(ts_day.index[-180], ts_day.index[-1])
#ax2.set_xlim(ts_day.index[0], ts_day.index[-1])

ax2.legend(loc='upper right',fontsize=10)
ax2.tick_params(axis='both', which='major', labelsize=14)

# %%
ax1.set_title('(a)',fontsize=14)
ax2.set_title('(b)',fontsize=14)
# Out:
# Text(0.5, 1.0, '(b)')

# %%
plt.gcf().text(0.09, 0.9, "(a)", fontsize=12)
plt.gcf().text(0.5, 0.9, "(b)", fontsize=12)
plt.gcf().text(0.09,0.9,'MOD-00397',fontsize=12)

plt.tight_layout()

# %%
fig.savefig('time_barchart_MOD-00688_3_factor.png')

# %%
fig

# %% [markdown]
# ## Setting Up Diurnal Figure

# %%
ts.head()
# Out:
#       timestamp_local      bin0      bin1      bin2      bin3      bin4  \
# 0 2025-03-31 20:00:00  0.255770  0.076895  0.068148  0.082960  0.136247
# 1 2025-03-31 21:00:00  0.335293  0.155275  0.098519  0.098655  0.156812
# 2 2025-03-31 22:00:00  0.321035  0.216568  0.119259  0.105381  0.149100
# 3 2025-03-31 23:00:00  0.132736  0.073923  0.042963  0.035874  0.048843
# 4 2025-04-01 00:00:00  0.155667  0.082095  0.045926  0.038117  0.051414
#
#        bin5        co        o3        no       no2  Factor 1  Factor 2  \
# 0  0.314516  0.487293  0.425632  0.031461  0.473713  0.037878  0.053050
# 1  0.395161  0.476431  0.449958  0.044147  0.397914  0.036727  0.072836
# 2  0.322581  0.519584  0.429626  0.048038  0.462448  0.033991  0.077439
# 3  0.096774  0.390167  0.686797  0.046685  0.214882  0.068195  0.025440
# 4  0.104839  0.363358  0.696236  0.046685  0.284840  0.067184  0.025991
#
#    Factor 3
# 0  0.108573
# 1  0.084562
# 2  0.102970
# 3  0.038721
# 4  0.051518

# %%
#prepping data
ts = ts.set_index('timestamp_local')
ts['Hour'] = ts.index.hour
ts.head()
# Out:
#                          bin0      bin1      bin2      bin3      bin4  \
# timestamp_local
# 2025-03-31 20:00:00  0.255770  0.076895  0.068148  0.082960  0.136247
# 2025-03-31 21:00:00  0.335293  0.155275  0.098519  0.098655  0.156812
# 2025-03-31 22:00:00  0.321035  0.216568  0.119259  0.105381  0.149100
# 2025-03-31 23:00:00  0.132736  0.073923  0.042963  0.035874  0.048843
# 2025-04-01 00:00:00  0.155667  0.082095  0.045926  0.038117  0.051414
#
#                          bin5        co        o3        no       no2  \
# timestamp_local
# 2025-03-31 20:00:00  0.314516  0.487293  0.425632  0.031461  0.473713
# 2025-03-31 21:00:00  0.395161  0.476431  0.449958  0.044147  0.397914
# 2025-03-31 22:00:00  0.322581  0.519584  0.429626  0.048038  0.462448
# 2025-03-31 23:00:00  0.096774  0.390167  0.686797  0.046685  0.214882
# 2025-04-01 00:00:00  0.104839  0.363358  0.696236  0.046685  0.284840
#
#                      Factor 1  Factor 2  Factor 3  Hour
# timestamp_local
# 2025-03-31 20:00:00  0.037878  0.053050  0.108573    20
# 2025-03-31 21:00:00  0.036727  0.072836  0.084562    21
# 2025-03-31 22:00:00  0.033991  0.077439  0.102970    22
# 2025-03-31 23:00:00  0.068195  0.025440  0.038721    23
# 2025-04-01 00:00:00  0.067184  0.025991  0.051518     0

# %%
#grouping by hour and calculate the mean
diurnal_data = ts.groupby('Hour')[['Factor 1','Factor 2','Factor 3']].mean()
diurnal_data.index = diurnal_data.index.map(lambda x: "{:02d}:00".format(x))
diurnal_data
# Out:
#        Factor 1  Factor 2  Factor 3
# Hour
# 00:00  0.046065  0.029821  0.084173
# 01:00  0.044860  0.030045  0.082837
# 02:00  0.044003  0.030705  0.079749
# 03:00  0.042787  0.030752  0.078731
# 04:00  0.041371  0.032381  0.079177
# 05:00  0.039270  0.034045  0.080670
# 06:00  0.037880  0.035315  0.082327
# 07:00  0.037943  0.035998  0.083742
# 08:00  0.039390  0.034398  0.075897
# 09:00  0.042054  0.031673  0.066682
# 10:00  0.044933  0.029002  0.058037
# 11:00  0.049074  0.026704  0.053512
# 12:00  0.052936  0.025366  0.053320
# 13:00  0.055994  0.023159  0.056111
# 14:00  0.057868  0.022334  0.057736
# 15:00  0.057985  0.023303  0.060587
# 16:00  0.058073  0.023199  0.063992
# 17:00  0.057853  0.022920  0.072937
# 18:00  0.056530  0.023653  0.083267
# 19:00  0.054549  0.025662  0.090567
# 20:00  0.052062  0.028725  0.093457
# 21:00  0.049901  0.029953  0.091055
# 22:00  0.048244  0.031254  0.087339
# 23:00  0.047262  0.030885  0.085011

# %%
# set up the figure
plt.figure(figsize=(10, 6))

plt.plot(diurnal_data.index, diurnal_data['Factor 1'], label='Factor 1', lw = 2, color=sns.xkcd_rgb['slate blue'])
plt.plot(diurnal_data.index, diurnal_data['Factor 2'], label='Factor 2', lw = 2, color=sns.xkcd_rgb['dull green'])
plt.plot(diurnal_data.index, diurnal_data['Factor 3'], label='Factor 3', lw = 2, color=sns.xkcd_rgb['dark lavender'])

plt.ylabel('Factor Intensity (a.u.)', fontsize = 14)
plt.legend(loc='upper right',fontsize=14)
plt.xticks(range(0, 24))
plt.xticks(rotation=45)

plt.tick_params(labelsize=14)

plt.savefig('diurnal_MOD-00688_3_factor.png')
plt.show()
