# %% [markdown]
# # Factor Bar Chart and Timeseries Figures

# %%
import numpy as np
import seaborn as sns
import joblib
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.dates as mdates
import matplotlib.ticker as mticker
from matplotlib.ticker import FuncFormatter

# %%
# force the math text to look normal
mpl.rcParams['mathtext.default'] = 'regular'

def major_ticks(x, pos=None):
    """Set the major ticks according
    to this custom style
    """
    x = mdates.num2date(x)
    if pos == 0:
        fmt = "%-d\n%b %Y\n%I %p"
    else:
        fmt = "%-d"
    return x.strftime(fmt)

# set the default seaborn params
sns.set("paper", "ticks", color_codes=True, palette='colorblind')

# %% [markdown]
# ## Loading Data

# %%
#load in the comp data
comp = pd.read_csv('MOD-00691_4_factor_resid.csv')
comp.rename(columns={'Unnamed: 0':'species'},inplace=True)
comp
# Out:
#   species  Factor 1  Factor 2  Factor 3  Factor 4  Residual
# 0      co  0.689739  0.102636  0.207209  0.000000  0.000417
# 1      no  0.661910  0.100550  0.193407  0.038746  0.005386
# 2     no2  0.738112  0.065239  0.175735  0.021169 -0.000254
# 3      o3  0.348256  0.000000  0.647737  0.004002  0.000005
# 4    bin0  0.257171  0.744596  0.000000  0.000000 -0.001767
# 5    bin1  0.000000  0.933986  0.001934  0.088549 -0.024468
# 6    bin2  0.016594  0.689392  0.049089  0.248334 -0.003410
# 7    bin3  0.092128  0.379334  0.003992  0.522894  0.001652
# 8    bin4  0.080671  0.073957  0.000000  0.845125  0.000246
# 9    bin5  0.000000  0.000000  0.000000  1.099089 -0.099089

# %%
comp2 = pd.melt(comp,id_vars='species', value_vars=['Factor 1','Factor 2','Factor 3','Residual'])
comp2
# Out:
#    species  variable     value
# 0       co  Factor 1  0.689739
# 1       no  Factor 1  0.661910
# 2      no2  Factor 1  0.738112
# 3       o3  Factor 1  0.348256
# 4     bin0  Factor 1  0.257171
# 5     bin1  Factor 1  0.000000
# 6     bin2  Factor 1  0.016594
# 7     bin3  Factor 1  0.092128
# 8     bin4  Factor 1  0.080671
# 9     bin5  Factor 1  0.000000
# 10      co  Factor 2  0.102636
# 11      no  Factor 2  0.100550
# 12     no2  Factor 2  0.065239
# 13      o3  Factor 2  0.000000
# 14    bin0  Factor 2  0.744596
# 15    bin1  Factor 2  0.933986
# 16    bin2  Factor 2  0.689392
# 17    bin3  Factor 2  0.379334
# 18    bin4  Factor 2  0.073957
# 19    bin5  Factor 2  0.000000
# 20      co  Factor 3  0.207209
# 21      no  Factor 3  0.193407
# 22     no2  Factor 3  0.175735
# 23      o3  Factor 3  0.647737
# 24    bin0  Factor 3  0.000000
# 25    bin1  Factor 3  0.001934
# 26    bin2  Factor 3  0.049089
# 27    bin3  Factor 3  0.003992
# 28    bin4  Factor 3  0.000000
# 29    bin5  Factor 3  0.000000
# 30      co  Residual  0.000417
# 31      no  Residual  0.005386
# 32     no2  Residual -0.000254
# 33      o3  Residual  0.000005
# 34    bin0  Residual -0.001767
# 35    bin1  Residual -0.024468
# 36    bin2  Residual -0.003410
# 37    bin3  Residual  0.001652
# 38    bin4  Residual  0.000246
# 39    bin5  Residual -0.099089

# %%
#load in the timeseries data
ts = pd.read_csv('MOD-00691_timeseries_hourly_scaled.csv').reset_index()
results = pd.read_csv('MOD-00691_4_factor_results.csv')

ts = pd.concat([ts,results['Factor 1'],results['Factor 2'], results['Factor 3']], axis = 1)
cols_reordered = ['timestamp_local','bin0','bin1','bin2','bin3','bin4','bin5','co','o3','no','no2','Factor 1','Factor 2','Factor 3']
ts = ts[cols_reordered]
ts.head()
# Out:
#        timestamp_local      bin0      bin1      bin2      bin3      bin4  \
# 0  2025-11-22 21:00:00  0.133198  0.045455  0.050420  0.033333  0.012821
# 1  2025-11-22 22:00:00  0.069028  0.033291  0.050420  0.044444  0.012821
# 2  2025-11-22 23:00:00  0.055061  0.023047  0.033613  0.022222  0.012821
# 3  2025-11-23 00:00:00  0.056883  0.021767  0.028011  0.011111  0.006410
# 4  2025-11-23 01:00:00  0.068219  0.024968  0.033613  0.022222  0.012821
#
#       bin5        co        o3        no       no2  Factor 1  Factor 2  \
# 0  0.00625  0.312510  0.675247  0.087633  0.826160  0.095264  0.028270
# 1  0.00625  0.299997  0.705316  0.086814  0.798183  0.090687  0.011366
# 2  0.00625  0.291081  0.735867  0.084767  0.784075  0.087812  0.005218
# 3  0.00625  0.309422  0.657686  0.088862  0.823769  0.100756  0.003924
# 4  0.00625  0.351337  0.596103  0.098280  0.848637  0.110194  0.007429
#
#    Factor 3
# 0  0.155352
# 1  0.169545
# 2  0.182541
# 3  0.145119
# 4  0.116488

# %%
ts['timestamp_local'] = pd.to_datetime(ts['timestamp_local']) #convert timestamp column to pandas timestamp format
ts = ts.set_index('timestamp_local',append=False) #setindex as local time
ts
# Out:
#                          bin0      bin1      bin2      bin3      bin4  \
# timestamp_local
# 2025-11-22 21:00:00  0.133198  0.045455  0.050420  0.033333  0.012821
# 2025-11-22 22:00:00  0.069028  0.033291  0.050420  0.044444  0.012821
# 2025-11-22 23:00:00  0.055061  0.023047  0.033613  0.022222  0.012821
# 2025-11-23 00:00:00  0.056883  0.021767  0.028011  0.011111  0.006410
# 2025-11-23 01:00:00  0.068219  0.024968  0.033613  0.022222  0.012821
# ...                       ...       ...       ...       ...       ...
# 2025-12-31 14:00:00  0.137854  0.039052  0.050420  0.033333  0.019231
# 2025-12-31 15:00:00  0.126923  0.039052  0.047619  0.033333  0.019231
# 2025-12-31 16:00:00  0.149190  0.051216  0.061625  0.044444  0.019231
# 2025-12-31 17:00:00  0.160729  0.059539  0.072829  0.055556  0.025641
# 2025-12-31 18:00:00  0.142915  0.057618  0.070028  0.055556  0.025641
#
#                         bin5        co        o3        no       no2  \
# timestamp_local
# 2025-11-22 21:00:00  0.00625  0.312510  0.675247  0.087633  0.826160
# 2025-11-22 22:00:00  0.00625  0.299997  0.705316  0.086814  0.798183
# 2025-11-22 23:00:00  0.00625  0.291081  0.735867  0.084767  0.784075
# 2025-11-23 00:00:00  0.00625  0.309422  0.657686  0.088862  0.823769
# 2025-11-23 01:00:00  0.00625  0.351337  0.596103  0.098280  0.848637
# ...                      ...       ...       ...       ...       ...
# 2025-12-31 14:00:00  0.01250  0.483335  0.786384  0.083538  0.843855
# 2025-12-31 15:00:00  0.01250  0.413569  0.789512  0.081491  0.846007
# 2025-12-31 16:00:00  0.01250  0.413024  0.728650  0.090909  0.867049
# 2025-12-31 17:00:00  0.01250  0.382688  0.627616  0.082719  0.893352
# 2025-12-31 18:00:00  0.01250  0.392306  0.567477  0.100328  0.910091
#
#                      Factor 1  Factor 2  Factor 3
# timestamp_local
# 2025-11-22 21:00:00  0.095264  0.028270  0.155352
# 2025-11-22 22:00:00  0.090687  0.011366  0.169545
# 2025-11-22 23:00:00  0.087812  0.005218  0.182541
# 2025-11-23 00:00:00  0.100756  0.003924  0.145119
# 2025-11-23 01:00:00  0.110194  0.007429  0.116488
# ...                       ...       ...       ...
# 2025-12-31 14:00:00  0.100181  0.032465  0.192145
# 2025-12-31 15:00:00  0.096866  0.027614  0.194872
# 2025-12-31 16:00:00  0.102353  0.035174  0.169156
# 2025-12-31 17:00:00  0.109955  0.037795  0.127250
# 2025-12-31 18:00:00  0.118133  0.032207  0.099920
#
# [894 rows x 13 columns]

# %%
#taking daily average of ts. round to floor of the day
ts = ts.reset_index()

ts_day = ts.groupby(ts['timestamp_local'].dt.floor('d')).agg(bin0 = ('bin0','mean'),
                                                  bin1 = ('bin1','mean'),
                                                  bin2 = ('bin2','mean'),
                                                  bin3 = ('bin3','mean'),
                                                  bin4 = ('bin4','mean'),
                                                  bin5 = ('bin5','mean'),
                                                  co = ('co','mean'),
                                                  o3 = ('o3','mean'),
                                                  no = ('no','mean'),
                                                  no2 = ('no2','mean'),
                                                  factor1 = ('Factor 1','mean'),
                                                  factor2 = ('Factor 2','mean'),
                                                  factor3 = ('Factor 3','mean')).reset_index()

ts_day = ts_day.set_index('timestamp_local')
ts_day.head()
# Out:
#                      bin0      bin1      bin2      bin3      bin4      bin5  \
# timestamp_local
# 2025-11-22       0.085762  0.033931  0.044818  0.033333  0.012821  0.006250
# 2025-11-23       0.170572  0.062873  0.067460  0.041667  0.018697  0.010156
# 2025-11-24       0.073035  0.032037  0.043534  0.032407  0.017094  0.009635
# 2025-11-25       0.172934  0.060846  0.093954  0.109722  0.083868  0.067969
# 2025-11-26       0.487163  0.283531  0.313842  0.221759  0.097756  0.056510
#
#                        co        o3        no       no2   factor1   factor2  \
# timestamp_local
# 2025-11-22       0.301196  0.705477  0.086405  0.802806  0.091254  0.014951
# 2025-11-23       0.400258  0.610907  0.090244  0.825034  0.101431  0.042940
# 2025-11-24       0.386750  0.666827  0.096915  0.791238  0.097409  0.013530
# 2025-11-25       0.358186  0.584516  0.118584  0.844462  0.100737  0.039393
# 2025-11-26       0.336111  0.472135  0.095397  0.760980  0.064686  0.170980
#
#                   factor3
# timestamp_local
# 2025-11-22       0.169146
# 2025-11-23       0.129228
# 2025-11-24       0.152147
# 2025-11-25       0.118582
# 2025-11-26       0.108602

# %% [markdown]
# ## Setting Up Barchart and 6-month Figures

# %%
# set up the figure
fig = plt.figure(figsize=(9, 8))

ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

# %%
cols = ['bin0', 'bin1', 'bin2','bin3','bin4','bin5','co', 'o3','no', 'no2']

pal = sns.color_palette()

colors = [pal[3], pal[2], pal[4], pal[5]]
colors += sns.color_palette("Blues", 6)
colors.reverse()

# %%
ax1 = sns.barplot(x='variable',y='value',
        data=comp2,
        ax=ax1, hue='species',hue_order=cols,
        palette=colors, saturation=1, edgecolor='black', linewidth=0.25,
        errwidth=.75)
# Out:
# /tmp/ipykernel_815/2976516543.py:1: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 0.75}` instead.
#
#   ax1 = sns.barplot(x='variable',y='value',

# %%
ax1.set_ylim(-0.2, 1)
ax1.set_xlabel("")
ax1.set_ylabel("Percent of Species Signal\nDescribed by Factor", fontsize=14)
ax1.set(yticks=np.linspace(-0.2, 1, 13), yticklabels=["","","0","","","","","50","","","","","100"])
ax1.tick_params(axis='both', which='major', labelsize=14)
ax1.axhline(y=0, color='black', linestyle='-', lw =0.5)

# %%
handles, _ = ax1.get_legend_handles_labels()
labels = ["Bin 0", "Bin 1", "Bin 2", "Bin 3","Bin 4","Bin 5","CO","$O_3$","$NO$", "$NO_2$"]
ax1.legend(handles, labels)

# %%
ax2.clear()

# %%
ax2.plot(ts_day.index, ts_day["factor1"], label="Factor 1 ", lw=1.5, color=sns.xkcd_rgb['slate blue'])
ax2.plot(ts_day.index, ts_day["factor2"], label="Factor 2", lw=1.5, color=sns.xkcd_rgb['dull green'])
ax2.plot(ts_day.index, ts_day["factor3"], label="Factor 3", lw=1.5, color=sns.xkcd_rgb['dark lavender'])

ax2.set_ylabel("Factor Intensity (a.u.)", fontsize=14)

#last 6 months
ax2.set_xlim(ts_day.index[-180], ts_day.index[-1])
# ax2.set_xlim(ts_day.index[0], ts_day.index[-1])

ax2.legend(loc='upper right',fontsize=10)
ax2.tick_params(axis='both', which='major', labelsize=14)
ax2.tick_params(axis='x', rotation=45)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_815/2222878929.py in <cell line: 0>()
#       6
#       7 #last 6 months
# ----> 8 ax2.set_xlim(ts_day.index[-180], ts_day.index[-1])
#       9 # ax2.set_xlim(ts_day.index[0], ts_day.index[-1])
#      10
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    5387             # GH#44051 exclude bool, which would return a 2d ndarray
#    5388             key = com.cast_scalar_indexer(key)
# -> 5389             return getitem(key)
#    5390
#    5391         if isinstance(key, slice):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arrays/datetimelike.py in __getitem__(self, key)
#     379         # but skip evaluating the Union at runtime for performance
#     380         # (see https://github.com/pandas-dev/pandas/pull/44624)
# --> 381         result = cast("Union[Self, DTScalarOrNaT]", super().__getitem__(key))
#     382         if lib.is_scalar(result):
#     383             return result
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arrays/_mixins.py in __getitem__(self, key)
#     282         if lib.is_integer(key):
#     283             # fast-path
# --> 284             result = self._ndarray[key]
#     285             if self.ndim == 1:
#     286                 return self._box_func(result)
#
# IndexError: index -180 is out of bounds for axis 0 with size 40

# %%
ax1.set_title('(a)',fontsize=14)
ax2.set_title('(b)',fontsize=14)
# Out:
# Text(0.5, 1.0, '(b)')

# %%
plt.gcf().text(0.09, 0.9, "(a)", fontsize=12)
plt.gcf().text(0.5, 0.9, "(b)", fontsize=12)
plt.gcf().text(0.09,0.9,'MOD-00397',fontsize=12)

plt.tight_layout()

# %%
# fig.savefig('C:/Users/alexa/Jupyter Notebook/MOD-00683/time_barchart_MOD-00068_4_factor.png')

# %%
fig

# %% [markdown]
# ## Setting Up Diurnal Figure

# %%
ts.head()
# Out:
#       timestamp_local      bin0      bin1      bin2      bin3      bin4  \
# 0 2025-11-22 21:00:00  0.133198  0.045455  0.050420  0.033333  0.012821
# 1 2025-11-22 22:00:00  0.069028  0.033291  0.050420  0.044444  0.012821
# 2 2025-11-22 23:00:00  0.055061  0.023047  0.033613  0.022222  0.012821
# 3 2025-11-23 00:00:00  0.056883  0.021767  0.028011  0.011111  0.006410
# 4 2025-11-23 01:00:00  0.068219  0.024968  0.033613  0.022222  0.012821
#
#       bin5        co        o3        no       no2  Factor 1  Factor 2  \
# 0  0.00625  0.312510  0.675247  0.087633  0.826160  0.095264  0.028270
# 1  0.00625  0.299997  0.705316  0.086814  0.798183  0.090687  0.011366
# 2  0.00625  0.291081  0.735867  0.084767  0.784075  0.087812  0.005218
# 3  0.00625  0.309422  0.657686  0.088862  0.823769  0.100756  0.003924
# 4  0.00625  0.351337  0.596103  0.098280  0.848637  0.110194  0.007429
#
#    Factor 3
# 0  0.155352
# 1  0.169545
# 2  0.182541
# 3  0.145119
# 4  0.116488

# %%
#prepping data
ts = ts.set_index('timestamp_local')
ts['Hour'] = ts.index.hour
ts.head()
# Out:
#                          bin0      bin1      bin2      bin3      bin4  \
# timestamp_local
# 2025-11-22 21:00:00  0.133198  0.045455  0.050420  0.033333  0.012821
# 2025-11-22 22:00:00  0.069028  0.033291  0.050420  0.044444  0.012821
# 2025-11-22 23:00:00  0.055061  0.023047  0.033613  0.022222  0.012821
# 2025-11-23 00:00:00  0.056883  0.021767  0.028011  0.011111  0.006410
# 2025-11-23 01:00:00  0.068219  0.024968  0.033613  0.022222  0.012821
#
#                         bin5        co        o3        no       no2  \
# timestamp_local
# 2025-11-22 21:00:00  0.00625  0.312510  0.675247  0.087633  0.826160
# 2025-11-22 22:00:00  0.00625  0.299997  0.705316  0.086814  0.798183
# 2025-11-22 23:00:00  0.00625  0.291081  0.735867  0.084767  0.784075
# 2025-11-23 00:00:00  0.00625  0.309422  0.657686  0.088862  0.823769
# 2025-11-23 01:00:00  0.00625  0.351337  0.596103  0.098280  0.848637
#
#                      Factor 1  Factor 2  Factor 3  Hour
# timestamp_local
# 2025-11-22 21:00:00  0.095264  0.028270  0.155352    21
# 2025-11-22 22:00:00  0.090687  0.011366  0.169545    22
# 2025-11-22 23:00:00  0.087812  0.005218  0.182541    23
# 2025-11-23 00:00:00  0.100756  0.003924  0.145119     0
# 2025-11-23 01:00:00  0.110194  0.007429  0.116488     1

# %%
#grouping by hour and calculate the mean
diurnal_data = ts.groupby('Hour')[['Factor 1','Factor 2','Factor 3']].mean()
diurnal_data.index = diurnal_data.index.map(lambda x: "{:02d}:00".format(x))
diurnal_data
# Out:
#        Factor 1  Factor 2  Factor 3
# Hour
# 00:00  0.091743  0.063836  0.132691
# 01:00  0.093048  0.063848  0.130922
# 02:00  0.093991  0.059331  0.131089
# 03:00  0.094825  0.058872  0.126327
# 04:00  0.096455  0.059634  0.119631
# 05:00  0.104210  0.053194  0.103645
# 06:00  0.106721  0.049425  0.096205
# 07:00  0.106231  0.047043  0.097514
# 08:00  0.100322  0.046090  0.119042
# 09:00  0.088885  0.044197  0.150488
# 10:00  0.076922  0.039998  0.176688
# 11:00  0.075283  0.040196  0.186689
# 12:00  0.074718  0.039338  0.193657
# 13:00  0.077892  0.037180  0.195994
# 14:00  0.079505  0.037042  0.195041
# 15:00  0.092944  0.041869  0.168597
# 16:00  0.099803  0.044324  0.151306
# 17:00  0.101615  0.047864  0.139993
# 18:00  0.103895  0.056327  0.127472
# 19:00  0.101135  0.060788  0.127646
# 20:00  0.100963  0.057992  0.124946
# 21:00  0.098328  0.056144  0.130931
# 22:00  0.093043  0.060992  0.134872
# 23:00  0.091609  0.062360  0.134547

# %%
# set up the figure
plt.figure(figsize=(10, 6))

plt.plot(diurnal_data.index, diurnal_data['Factor 1'], label='Factor 1', lw = 2, color=sns.xkcd_rgb['slate blue'])
plt.plot(diurnal_data.index, diurnal_data['Factor 2'], label='Factor 2', lw = 2, color=sns.xkcd_rgb['dull green'])
plt.plot(diurnal_data.index, diurnal_data['Factor 3'], label='Factor 3', lw = 2, color=sns.xkcd_rgb['dark lavender'])

plt.ylabel('Factor Intensity (a.u.)', fontsize = 14)
plt.legend(loc='upper right',fontsize=14)
plt.xticks(range(0, 24))
plt.xticks(rotation=45)

plt.tick_params(labelsize=14)

# plt.savefig('diurnal_MOD-00691_4_factor.png')
plt.show()
