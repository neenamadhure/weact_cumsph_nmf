# %% [markdown]
# # Factor Bar Chart and Timeseries Figures

# %%
import numpy as np
import seaborn as sns
import joblib
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.dates as mdates
import matplotlib.ticker as mticker
from matplotlib.ticker import FuncFormatter

# %%
# force the math text to look normal
mpl.rcParams['mathtext.default'] = 'regular'

def major_ticks(x, pos=None):
    """Set the major ticks according
    to this custom style
    """
    x = mdates.num2date(x)
    if pos == 0:
        fmt = "%-d\n%b %Y\n%I %p"
    else:
        fmt = "%-d"
    return x.strftime(fmt)

# set the default seaborn params
sns.set("paper", "ticks", color_codes=True, palette='colorblind')

# %% [markdown]
# ## Loading Data

# %%
#load in the comp data
comp = pd.read_csv('MOD-00682_4_factor_resid.csv')
comp.rename(columns={'Unnamed: 0':'species'},inplace=True)
comp
# Out:
#   species  Factor 1  Factor 2  Factor 3  Factor 4  Residual
# 0      co  0.592770  0.195745  0.175009  0.018237  0.018239
# 1      no  0.554070  0.311847  0.089623  0.022158  0.022302
# 2     no2  0.980288  0.004439  0.001646  0.021066 -0.007440
# 3      o3  0.007311  1.002057  0.000000  0.000000 -0.009368
# 4    bin0  0.000000  0.173552  0.861032  0.000000 -0.034583
# 5    bin1  0.000000  0.000000  0.846830  0.293467 -0.140297
# 6    bin2  0.000000  0.000000  0.476565  0.602168 -0.078733
# 7    bin3  0.014441  0.030724  0.201769  0.766708 -0.013642
# 8    bin4  0.083657  0.139728  0.065714  0.708524  0.002377
# 9    bin5  0.175231  0.116006  0.000000  0.698369  0.010394

# %%
comp2 = pd.melt(comp,id_vars='species', value_vars=['Factor 1','Factor 2','Factor 3','Residual'])
comp2
# Out:
#    species  variable     value
# 0       co  Factor 1  0.592770
# 1       no  Factor 1  0.554070
# 2      no2  Factor 1  0.980288
# 3       o3  Factor 1  0.007311
# 4     bin0  Factor 1  0.000000
# 5     bin1  Factor 1  0.000000
# 6     bin2  Factor 1  0.000000
# 7     bin3  Factor 1  0.014441
# 8     bin4  Factor 1  0.083657
# 9     bin5  Factor 1  0.175231
# 10      co  Factor 2  0.195745
# 11      no  Factor 2  0.311847
# 12     no2  Factor 2  0.004439
# 13      o3  Factor 2  1.002057
# 14    bin0  Factor 2  0.173552
# 15    bin1  Factor 2  0.000000
# 16    bin2  Factor 2  0.000000
# 17    bin3  Factor 2  0.030724
# 18    bin4  Factor 2  0.139728
# 19    bin5  Factor 2  0.116006
# 20      co  Factor 3  0.175009
# 21      no  Factor 3  0.089623
# 22     no2  Factor 3  0.001646
# 23      o3  Factor 3  0.000000
# 24    bin0  Factor 3  0.861032
# 25    bin1  Factor 3  0.846830
# 26    bin2  Factor 3  0.476565
# 27    bin3  Factor 3  0.201769
# 28    bin4  Factor 3  0.065714
# 29    bin5  Factor 3  0.000000
# 30      co  Residual  0.018239
# 31      no  Residual  0.022302
# 32     no2  Residual -0.007440
# 33      o3  Residual -0.009368
# 34    bin0  Residual -0.034583
# 35    bin1  Residual -0.140297
# 36    bin2  Residual -0.078733
# 37    bin3  Residual -0.013642
# 38    bin4  Residual  0.002377
# 39    bin5  Residual  0.010394

# %%
#load in the timeseries data
ts = pd.read_csv('MOD-00682_timeseries_hourly_scaled.csv').reset_index()
results = pd.read_csv('MOD-00682_4_factor_results.csv')

ts = pd.concat([ts,results['Factor 1'],results['Factor 2'], results['Factor 3']], axis = 1)
cols_reordered = ['timestamp_local','bin0','bin1','bin2','bin3','bin4','bin5','co','o3','no','no2','Factor 1','Factor 2','Factor 3']
ts = ts[cols_reordered]
ts.head()
# Out:
#        timestamp_local      bin0      bin1      bin2      bin3      bin4  \
# 0  2025-03-31 20:00:00  0.283419  0.085351  0.082972  0.121762  0.251880
# 1  2025-03-31 21:00:00  0.385293  0.163320  0.118266  0.152850  0.312030
# 2  2025-03-31 22:00:00  0.408949  0.287064  0.160372  0.165803  0.304511
# 3  2025-03-31 23:00:00  0.247155  0.168340  0.090402  0.085492  0.135338
# 4  2025-04-01 00:00:00  0.195380  0.105434  0.058824  0.054404  0.090226
#
#        bin5        co        o3        no       no2  Factor 1  Factor 2  \
# 0  0.327778  0.465949  0.142622  0.045652  0.625486  0.052428  0.022757
# 1  0.422222  0.487476  0.119254  0.057749  0.667399  0.052253  0.017063
# 2  0.383333  0.571831  0.129457  0.064597  0.698327  0.055833  0.018701
# 3  0.150000  0.444234  0.277016  0.063456  0.534392  0.046327  0.044164
# 4  0.094444  0.384054  0.342951  0.057293  0.501437  0.044237  0.054822
#
#    Factor 3
# 0  0.060371
# 1  0.084240
# 2  0.104139
# 3  0.059636
# 4  0.039559

# %%
ts['timestamp_local'] = pd.to_datetime(ts['timestamp_local']) #convert timestamp column to pandas timestamp format
ts = ts.set_index('timestamp_local',append=False) #setindex as local time
ts
# Out:
#                          bin0      bin1      bin2      bin3      bin4  \
# timestamp_local
# 2025-03-31 20:00:00  0.283419  0.085351  0.082972  0.121762  0.251880
# 2025-03-31 21:00:00  0.385293  0.163320  0.118266  0.152850  0.312030
# 2025-03-31 22:00:00  0.408949  0.287064  0.160372  0.165803  0.304511
# 2025-03-31 23:00:00  0.247155  0.168340  0.090402  0.085492  0.135338
# 2025-04-01 00:00:00  0.195380  0.105434  0.058824  0.054404  0.090226
# ...                       ...       ...       ...       ...       ...
# 2025-12-28 09:00:00  0.104553  0.036621  0.019195  0.015544  0.018797
# 2025-12-28 10:00:00  0.133229  0.041347  0.021672  0.015544  0.018797
# 2025-12-28 11:00:00  0.158782  0.039279  0.019814  0.012953  0.015038
# 2025-12-28 12:00:00  0.205981  0.040165  0.018576  0.012953  0.015038
# 2025-12-28 13:00:00  0.326043  0.043119  0.016099  0.010363  0.011278
#
#                          bin5        co        o3        no       no2  \
# timestamp_local
# 2025-03-31 20:00:00  0.327778  0.465949  0.142622  0.045652  0.625486
# 2025-03-31 21:00:00  0.422222  0.487476  0.119254  0.057749  0.667399
# 2025-03-31 22:00:00  0.383333  0.571831  0.129457  0.064597  0.698327
# 2025-03-31 23:00:00  0.150000  0.444234  0.277016  0.063456  0.534392
# 2025-04-01 00:00:00  0.094444  0.384054  0.342951  0.057293  0.501437
# ...                       ...       ...       ...       ...       ...
# 2025-12-28 09:00:00  0.011111  0.432259  0.023697  0.047249  0.567348
# 2025-12-28 10:00:00  0.011111  0.463242  0.024465  0.059347  0.582559
# 2025-12-28 11:00:00  0.011111  0.440889  0.017773  0.055010  0.592361
# 2025-12-28 12:00:00  0.011111  0.453674  0.009764  0.054554  0.601487
# 2025-12-28 13:00:00  0.011111  0.439517  0.008118  0.060945  0.610782
#
#                      Factor 1  Factor 2  Factor 3
# timestamp_local
# 2025-03-31 20:00:00  0.052428  0.022757  0.060371
# 2025-03-31 21:00:00  0.052253  0.017063  0.084240
# 2025-03-31 22:00:00  0.055833  0.018701  0.104139
# 2025-03-31 23:00:00  0.046327  0.044164  0.059636
# 2025-04-01 00:00:00  0.044237  0.054822  0.039559
# ...                       ...       ...       ...
# 2025-12-28 09:00:00  0.058487  0.005768  0.036565
# 2025-12-28 10:00:00  0.060222  0.006145  0.044828
# 2025-12-28 11:00:00  0.060172  0.003960  0.047580
# 2025-12-28 12:00:00  0.060614  0.002208  0.058106
# 2025-12-28 13:00:00  0.058939  0.000000  0.080012
#
# [5765 rows x 13 columns]

# %%
#taking daily average of ts. round to floor of the day
ts = ts.reset_index()

ts_day = ts.groupby(ts['timestamp_local'].dt.floor('d')).agg(bin0 = ('bin0','mean'),
                                                  bin1 = ('bin1','mean'),
                                                  bin2 = ('bin2','mean'),
                                                  bin3 = ('bin3','mean'),
                                                  bin4 = ('bin4','mean'),
                                                  bin5 = ('bin5','mean'),
                                                  co = ('co','mean'),
                                                  o3 = ('o3','mean'),
                                                  no = ('no','mean'),
                                                  no2 = ('no2','mean'),
                                                  factor1 = ('Factor 1','mean'),
                                                  factor2 = ('Factor 2','mean'),
                                                  factor3 = ('Factor 3','mean')).reset_index()

ts_day = ts_day.set_index('timestamp_local')
ts_day.head()
# Out:
#                      bin0      bin1      bin2      bin3      bin4      bin5  \
# timestamp_local
# 2025-03-31       0.331204  0.176019  0.113003  0.131477  0.250940  0.320833
# 2025-04-01       0.061068  0.027085  0.016073  0.013385  0.019893  0.018519
# 2025-04-02       0.042211  0.019726  0.022988  0.035838  0.072995  0.089120
# 2025-04-03       0.247066  0.100943  0.071646  0.101576  0.218985  0.287269
# 2025-04-04       0.056377  0.017585  0.013390  0.015220  0.030232  0.031944
#
#                        co        o3        no       no2   factor1   factor2  \
# timestamp_local
# 2025-03-31       0.492372  0.167087  0.057864  0.631401  0.051710  0.025671
# 2025-04-01       0.349405  0.293879  0.049485  0.472114  0.046098  0.048762
# 2025-04-02       0.375871  0.291987  0.044957  0.569700  0.054027  0.048387
# 2025-04-03       0.476000  0.197481  0.050692  0.487198  0.041890  0.034037
# 2025-04-04       0.392662  0.341502  0.047525  0.346579  0.036201  0.059702
#
#                   factor3
# timestamp_local
# 2025-03-31       0.077096
# 2025-04-01       0.011688
# 2025-04-02       0.002938
# 2025-04-03       0.060313
# 2025-04-04       0.016235

# %% [markdown]
# ## Setting Up Barchart and 6-month Figures

# %%
# set up the figure
fig = plt.figure(figsize=(9, 8))

ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

# %%
cols = ['bin0', 'bin1', 'bin2','bin3','bin4','bin5','co', 'o3','no', 'no2']

pal = sns.color_palette()

colors = [pal[3], pal[2], pal[4], pal[5]]
colors += sns.color_palette("Blues", 6)
colors.reverse()

# %%
ax1 = sns.barplot(x='variable',y='value',
        data=comp2,
        ax=ax1, hue='species',hue_order=cols,
        palette=colors, saturation=1, edgecolor='black', linewidth=0.25,
        errwidth=.75)
# Out:
# /tmp/ipykernel_1025/2976516543.py:1: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 0.75}` instead.
#
#   ax1 = sns.barplot(x='variable',y='value',

# %%
ax1.set_ylim(-0.2, 1)
ax1.set_xlabel("")
ax1.set_ylabel("Percent of Species Signal\nDescribed by Factor", fontsize=14)
ax1.set(yticks=np.linspace(-0.2, 1, 13), yticklabels=["","","0","","","","","50","","","","","100"])
ax1.tick_params(axis='both', which='major', labelsize=14)
ax1.axhline(y=0, color='black', linestyle='-', lw =0.5)

# %%
handles, _ = ax1.get_legend_handles_labels()
labels = ["Bin 0", "Bin 1", "Bin 2", "Bin 3","Bin 4","Bin 5","CO","$O_3$","$NO$", "$NO_2$"]
ax1.legend(handles, labels)

# %%
ax2.plot(ts_day.index, ts_day["factor1"], label="Factor 1 ", lw=1, color=sns.xkcd_rgb['slate blue'])
ax2.plot(ts_day.index, ts_day["factor2"], label="Factor 2", lw=1, color=sns.xkcd_rgb['dull green'])
ax2.plot(ts_day.index, ts_day["factor3"], label="Factor 3", lw=1, color=sns.xkcd_rgb['dark lavender'])

ax2.set_ylabel("Factor Intensity (a.u.)", fontsize=14)

#last 6 months
ax2.set_xlim(ts_day.index[-180], ts_day.index[-1])
#ax2.set_xlim(ts_day.index[0], ts_day.index[-1])

ax2.legend(loc='upper right',fontsize=10)
ax2.tick_params(axis='both', which='major', labelsize=14)

# %%
ax1.set_title('(a)',fontsize=14)
ax2.set_title('(b)',fontsize=14)
# Out:
# Text(0.5, 1.0, '(b)')

# %%
plt.gcf().text(0.09, 0.9, "(a)", fontsize=12)
plt.gcf().text(0.5, 0.9, "(b)", fontsize=12)
plt.gcf().text(0.09,0.9,'MOD-00682',fontsize=12)

plt.tight_layout()

# %%
# fig.savefig('time_barchart_MOD-00682_3_factor.png')

# %%
fig

# %% [markdown]
# ## Setting Up Diurnal Figure

# %%
ts.head()
# Out:
#       timestamp_local      bin0      bin1      bin2      bin3      bin4  \
# 0 2025-03-31 20:00:00  0.283419  0.085351  0.082972  0.121762  0.251880
# 1 2025-03-31 21:00:00  0.385293  0.163320  0.118266  0.152850  0.312030
# 2 2025-03-31 22:00:00  0.408949  0.287064  0.160372  0.165803  0.304511
# 3 2025-03-31 23:00:00  0.247155  0.168340  0.090402  0.085492  0.135338
# 4 2025-04-01 00:00:00  0.195380  0.105434  0.058824  0.054404  0.090226
#
#        bin5        co        o3        no       no2  Factor 1  Factor 2  \
# 0  0.327778  0.465949  0.142622  0.045652  0.625486  0.052428  0.022757
# 1  0.422222  0.487476  0.119254  0.057749  0.667399  0.052253  0.017063
# 2  0.383333  0.571831  0.129457  0.064597  0.698327  0.055833  0.018701
# 3  0.150000  0.444234  0.277016  0.063456  0.534392  0.046327  0.044164
# 4  0.094444  0.384054  0.342951  0.057293  0.501437  0.044237  0.054822
#
#    Factor 3
# 0  0.060371
# 1  0.084240
# 2  0.104139
# 3  0.059636
# 4  0.039559

# %%
#prepping data
ts = ts.set_index('timestamp_local')
ts['Hour'] = ts.index.hour
ts.head()
# Out:
#                          bin0      bin1      bin2      bin3      bin4  \
# timestamp_local
# 2025-03-31 20:00:00  0.283419  0.085351  0.082972  0.121762  0.251880
# 2025-03-31 21:00:00  0.385293  0.163320  0.118266  0.152850  0.312030
# 2025-03-31 22:00:00  0.408949  0.287064  0.160372  0.165803  0.304511
# 2025-03-31 23:00:00  0.247155  0.168340  0.090402  0.085492  0.135338
# 2025-04-01 00:00:00  0.195380  0.105434  0.058824  0.054404  0.090226
#
#                          bin5        co        o3        no       no2  \
# timestamp_local
# 2025-03-31 20:00:00  0.327778  0.465949  0.142622  0.045652  0.625486
# 2025-03-31 21:00:00  0.422222  0.487476  0.119254  0.057749  0.667399
# 2025-03-31 22:00:00  0.383333  0.571831  0.129457  0.064597  0.698327
# 2025-03-31 23:00:00  0.150000  0.444234  0.277016  0.063456  0.534392
# 2025-04-01 00:00:00  0.094444  0.384054  0.342951  0.057293  0.501437
#
#                      Factor 1  Factor 2  Factor 3  Hour
# timestamp_local
# 2025-03-31 20:00:00  0.052428  0.022757  0.060371    20
# 2025-03-31 21:00:00  0.052253  0.017063  0.084240    21
# 2025-03-31 22:00:00  0.055833  0.018701  0.104139    22
# 2025-03-31 23:00:00  0.046327  0.044164  0.059636    23
# 2025-04-01 00:00:00  0.044237  0.054822  0.039559     0

# %%
#grouping by hour and calculate the mean
diurnal_data = ts.groupby('Hour')[['Factor 1','Factor 2','Factor 3']].mean()
diurnal_data.index = diurnal_data.index.map(lambda x: "{:02d}:00".format(x))
diurnal_data
# Out:
#        Factor 1  Factor 2  Factor 3
# Hour
# 00:00  0.052423  0.028313  0.033583
# 01:00  0.052069  0.026937  0.032753
# 02:00  0.051183  0.024897  0.033321
# 03:00  0.050748  0.023104  0.032569
# 04:00  0.051325  0.021673  0.033464
# 05:00  0.051758  0.020388  0.035699
# 06:00  0.052244  0.020410  0.038036
# 07:00  0.047934  0.024568  0.039875
# 08:00  0.044297  0.030296  0.037380
# 09:00  0.039875  0.037666  0.034255
# 10:00  0.036562  0.045097  0.030716
# 11:00  0.036770  0.051506  0.027342
# 12:00  0.037932  0.055857  0.024709
# 13:00  0.040930  0.057579  0.023148
# 14:00  0.042598  0.059329  0.022466
# 15:00  0.042946  0.059437  0.022807
# 16:00  0.044981  0.058311  0.021973
# 17:00  0.049241  0.054327  0.022258
# 18:00  0.053711  0.048488  0.022651
# 19:00  0.057780  0.042451  0.024674
# 20:00  0.057060  0.037591  0.029161
# 21:00  0.055506  0.034598  0.032495
# 22:00  0.054348  0.031334  0.034769
# 23:00  0.052924  0.029842  0.034212

# %%
# set up the figure
plt.figure(figsize=(10, 6))

plt.plot(diurnal_data.index, diurnal_data['Factor 1'], label='Factor 1', lw = 2, color=sns.xkcd_rgb['slate blue'])
plt.plot(diurnal_data.index, diurnal_data['Factor 2'], label='Factor 2', lw = 2, color=sns.xkcd_rgb['dull green'])
plt.plot(diurnal_data.index, diurnal_data['Factor 3'], label='Factor 3', lw = 2, color=sns.xkcd_rgb['dark lavender'])

plt.ylabel('Factor Intensity (a.u.)', fontsize = 14)
plt.legend(loc='upper right',fontsize=14)
plt.xticks(range(0, 24))
plt.xticks(rotation=45)

plt.tick_params(labelsize=14)

# plt.savefig('diurnal_MOD-00682_3_factor.png')
plt.show()
