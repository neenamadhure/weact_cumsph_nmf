# %% [markdown]
# # NMF on ModulAir Ocean Roof

# %%
from sklearn.decomposition import NMF
import numpy as np
import pandas as pd

# %% [markdown]
# ## Cleaning Data

# %%
#importing data from Modulair MOD-00068
data = pd.read_csv('/home/pmg2147/ModulAir NMF/OceanRoof/MOD-00068-raw.csv').set_index('timestamp')
data.head()
# Out:
#                              id       timestamp_local         sn    rh  temp  \
# timestamp
# 2025-06-02T23:59:38Z  404246550  2025-06-02T19:59:38Z  MOD-00068  40.8  22.3
# 2025-06-02T23:58:38Z  404246548  2025-06-02T19:58:38Z  MOD-00068  40.7  22.3
# 2025-06-02T23:57:38Z  404246547  2025-06-02T19:57:38Z  MOD-00068  40.7  22.3
# 2025-06-02T23:56:38Z  404244206  2025-06-02T19:56:38Z  MOD-00068  40.6  22.4
# 2025-06-02T23:55:38Z  404244207  2025-06-02T19:55:38Z  MOD-00068  40.6  22.4
#
#                        bin0   bin1   bin2   bin3   bin4  ...      o3      co2  \
# timestamp                                                ...
# 2025-06-02T23:59:38Z  3.029  0.201  0.077  0.034  0.047  ...  41.858  418.720
# 2025-06-02T23:58:38Z  3.078  0.240  0.067  0.009  0.018  ...  43.013  417.756
# 2025-06-02T23:57:38Z  3.182  0.204  0.079  0.026  0.040  ...  42.160  416.792
# 2025-06-02T23:56:38Z  2.921  0.279  0.100  0.008  0.046  ...  42.746  416.913
# 2025-06-02T23:55:38Z  2.925  0.274  0.087  0.013  0.018  ...  42.462  417.154
#
#                       pm1_model_id  pm25_model_id  pm10_model_id  co_model_id  \
# timestamp
# 2025-06-02T23:59:38Z        4881.0         4882.0         4883.0       4114.0
# 2025-06-02T23:58:38Z        4881.0         4882.0         4883.0       4114.0
# 2025-06-02T23:57:38Z        4881.0         4882.0         4883.0       4114.0
# 2025-06-02T23:56:38Z        4881.0         4882.0         4883.0       4114.0
# 2025-06-02T23:55:38Z        4881.0         4882.0         4883.0       4114.0
#
#                       no_model_id  no2_model_id  o3_model_id  co2_model_id
# timestamp
# 2025-06-02T23:59:38Z       4115.0        4116.0      15075.0          4118
# 2025-06-02T23:58:38Z       4115.0        4116.0      15075.0          4118
# 2025-06-02T23:57:38Z       4115.0        4116.0      15075.0          4118
# 2025-06-02T23:56:38Z       4115.0        4116.0      15075.0          4118
# 2025-06-02T23:55:38Z       4115.0        4116.0      15075.0          4118
#
# [5 rows x 69 columns]

# %%
#only columns of interest
COLS_TO_INCLUDE = ['timestamp_local','co','no','no2','o3','bin0','bin1','bin2','bin3','bin4','bin5']
data = data[COLS_TO_INCLUDE]

data.head()
# Out:
#                            timestamp_local       co     no     no2      o3  \
# timestamp
# 2025-06-02T23:59:38Z  2025-06-02T19:59:38Z  265.418  4.566  38.885  41.858
# 2025-06-02T23:58:38Z  2025-06-02T19:58:38Z  265.489  4.529  40.073  43.013
# 2025-06-02T23:57:38Z  2025-06-02T19:57:38Z  270.415  4.550  38.178  42.160
# 2025-06-02T23:56:38Z  2025-06-02T19:56:38Z  271.826  4.541  38.900  42.746
# 2025-06-02T23:55:38Z  2025-06-02T19:55:38Z  266.900  4.544  38.190  42.462
#
#                        bin0   bin1   bin2   bin3   bin4   bin5
# timestamp
# 2025-06-02T23:59:38Z  3.029  0.201  0.077  0.034  0.047  0.030
# 2025-06-02T23:58:38Z  3.078  0.240  0.067  0.009  0.018  0.035
# 2025-06-02T23:57:38Z  3.182  0.204  0.079  0.026  0.040  0.013
# 2025-06-02T23:56:38Z  2.921  0.279  0.100  0.008  0.046  0.017
# 2025-06-02T23:55:38Z  2.925  0.274  0.087  0.013  0.018  0.026

# %%
#removing the UTC time
data = data.reset_index(drop = True)
data.head()
# Out:
#         timestamp_local       co     no     no2      o3   bin0   bin1   bin2  \
# 0  2025-06-02T19:59:38Z  265.418  4.566  38.885  41.858  3.029  0.201  0.077
# 1  2025-06-02T19:58:38Z  265.489  4.529  40.073  43.013  3.078  0.240  0.067
# 2  2025-06-02T19:57:38Z  270.415  4.550  38.178  42.160  3.182  0.204  0.079
# 3  2025-06-02T19:56:38Z  271.826  4.541  38.900  42.746  2.921  0.279  0.100
# 4  2025-06-02T19:55:38Z  266.900  4.544  38.190  42.462  2.925  0.274  0.087
#
#     bin3   bin4   bin5
# 0  0.034  0.047  0.030
# 1  0.009  0.018  0.035
# 2  0.026  0.040  0.013
# 3  0.008  0.046  0.017
# 4  0.013  0.018  0.026

# %%
#converting to datetime
data['timestamp_local'] = pd.to_datetime(data['timestamp_local'], 
                                       format='%Y-%m-%dT%H:%M:%SZ',
                                       exact=False)
data.head()
# Out:
#       timestamp_local       co     no     no2      o3   bin0   bin1   bin2  \
# 0 2025-06-02 19:59:38  265.418  4.566  38.885  41.858  3.029  0.201  0.077
# 1 2025-06-02 19:58:38  265.489  4.529  40.073  43.013  3.078  0.240  0.067
# 2 2025-06-02 19:57:38  270.415  4.550  38.178  42.160  3.182  0.204  0.079
# 3 2025-06-02 19:56:38  271.826  4.541  38.900  42.746  2.921  0.279  0.100
# 4 2025-06-02 19:55:38  266.900  4.544  38.190  42.462  2.925  0.274  0.087
#
#     bin3   bin4   bin5
# 0  0.034  0.047  0.030
# 1  0.009  0.018  0.035
# 2  0.026  0.040  0.013
# 3  0.008  0.046  0.017
# 4  0.013  0.018  0.026

# %%
#taking hourly average of df. round to floor of the hour
data = data.groupby(data['timestamp_local'].dt.floor('h')).agg(co = ('co','mean'),
                                                         no2 = ('no2','mean'),
                                                         o3 = ('o3','mean'),
                                                         no = ('no','mean'),
                                                         bin0 = ('bin0','mean'),
                                                         bin1 = ('bin1','mean'),
                                                         bin2 = ('bin2','mean'),
                                                         bin3 = ('bin3','mean'),
                                                         bin4 = ('bin4','mean'),
                                                         bin5 = ('bin5','mean')).reset_index()

data = data.round(decimals = 2)
data = data.dropna()
data
# Out:
#          timestamp_local      co    no2     o3     no  bin0  bin1  bin2  bin3  \
# 6    2024-05-14 21:00:00  480.98  10.42  16.23  88.57  7.68  0.83  0.41  0.13
# 7    2024-05-14 22:00:00  474.06   9.65  11.91  67.56  7.21  0.75  0.37  0.12
# 8    2024-05-14 23:00:00  422.78   8.83   8.47  45.19  5.28  0.61  0.31  0.10
# 9    2024-05-15 00:00:00  274.73  11.20   9.15  32.63  3.86  0.33  0.16  0.05
# 10   2024-05-15 01:00:00  473.89  22.35   2.34  24.12  7.46  0.93  0.45  0.14
# ...                  ...     ...    ...    ...    ...   ...   ...   ...   ...
# 9215 2025-06-02 15:00:00  126.50  20.10  42.42   3.08  1.76  0.10  0.03  0.01
# 9216 2025-06-02 16:00:00  156.38  20.30  43.08   2.62  1.81  0.11  0.03  0.01
# 9217 2025-06-02 17:00:00  180.38  32.70  44.03   2.27  1.99  0.12  0.04  0.01
# 9218 2025-06-02 18:00:00  194.86  34.17  43.88   3.08  2.23  0.13  0.04  0.01
# 9219 2025-06-02 19:00:00  255.31  38.62  43.36   4.01  2.88  0.23  0.08  0.02
#
#       bin4  bin5
# 6     0.17  0.13
# 7     0.16  0.12
# 8     0.13  0.10
# 9     0.07  0.05
# 10    0.17  0.14
# ...    ...   ...
# 9215  0.01  0.01
# 9216  0.01  0.01
# 9217  0.01  0.01
# 9218  0.02  0.01
# 9219  0.03  0.02
#
# [9202 rows x 11 columns]

# %%
#setting local time as index
data = data.set_index('timestamp_local')
data.head()
# Out:
#                          co    no2     o3     no  bin0  bin1  bin2  bin3  \
# timestamp_local
# 2024-05-14 21:00:00  480.98  10.42  16.23  88.57  7.68  0.83  0.41  0.13
# 2024-05-14 22:00:00  474.06   9.65  11.91  67.56  7.21  0.75  0.37  0.12
# 2024-05-14 23:00:00  422.78   8.83   8.47  45.19  5.28  0.61  0.31  0.10
# 2024-05-15 00:00:00  274.73  11.20   9.15  32.63  3.86  0.33  0.16  0.05
# 2024-05-15 01:00:00  473.89  22.35   2.34  24.12  7.46  0.93  0.45  0.14
#
#                      bin4  bin5
# timestamp_local
# 2024-05-14 21:00:00  0.17  0.13
# 2024-05-14 22:00:00  0.16  0.12
# 2024-05-14 23:00:00  0.13  0.10
# 2024-05-15 00:00:00  0.07  0.05
# 2024-05-15 01:00:00  0.17  0.14

# %%
#subsetting for only positive and non NA values
data = data.where(data>0)
data = data.dropna()

# %%
#scaling
def maximum_absolute_scaling(df):
    # copy the dataframe
    df_scaled = df.copy()
    # apply maximum absolute scaling
    for column in df_scaled.columns:
        df_scaled[column] = df_scaled[column]  / df_scaled[column].abs().max()
    return df_scaled
   
# call the maximum_absolute_scaling function
data = maximum_absolute_scaling(data)

# %%
#subsetting for only positive and non NA values
data = data.where(data>0)
data = data.dropna()
data.head()
# Out:
#                            co       no2        o3        no      bin0  \
# timestamp_local
# 2024-05-14 21:00:00  0.706939  0.209911  0.169309  0.995728  0.065395
# 2024-05-14 22:00:00  0.696768  0.194400  0.124244  0.759528  0.061393
# 2024-05-14 23:00:00  0.621397  0.177881  0.088358  0.508038  0.044959
# 2024-05-15 00:00:00  0.403795  0.225624  0.095452  0.366835  0.032868
# 2024-05-15 01:00:00  0.696518  0.450242  0.024411  0.271164  0.063522
#
#                          bin1      bin2      bin3      bin4      bin5
# timestamp_local
# 2024-05-14 21:00:00  0.023049  0.046750  0.071038  0.073593  0.040123
# 2024-05-14 22:00:00  0.020828  0.042189  0.065574  0.069264  0.037037
# 2024-05-14 23:00:00  0.016940  0.035348  0.054645  0.056277  0.030864
# 2024-05-15 00:00:00  0.009164  0.018244  0.027322  0.030303  0.015432
# 2024-05-15 01:00:00  0.025826  0.051311  0.076503  0.073593  0.043210

# %%
data.to_csv('/home/pmg2147/ModulAir NMF/OceanRoof/MOD-00068_timeseries_hourly_scaled.csv')

# %% [markdown]
# ## Implementing NMF

# %%
#setting up the NMF
nmf = NMF(n_components = 4, max_iter = 8000)

# %%
W = nmf.fit_transform(data) 
H = nmf.components_   
V = pd.DataFrame(np.dot(W,H), columns=data.columns)
V.index = data.index
V
# Out:
#                            co       no2        o3        no      bin0  \
# timestamp_local
# 2024-05-14 21:00:00  0.641749  0.232799  0.240590  0.069356  0.313243
# 2024-05-14 22:00:00  0.613940  0.220323  0.185023  0.064091  0.302114
# 2024-05-14 23:00:00  0.532187  0.203838  0.135514  0.053877  0.259956
# 2024-05-15 00:00:00  0.359001  0.239351  0.125443  0.035770  0.156108
# 2024-05-15 01:00:00  0.590585  0.478973  0.060488  0.052410  0.270036
# ...                       ...       ...       ...       ...       ...
# 2025-06-02 15:00:00  0.209443  0.397743  0.437914  0.031376  0.013078
# 2025-06-02 16:00:00  0.227300  0.409566  0.449509  0.033334  0.019913
# 2025-06-02 17:00:00  0.290999  0.650507  0.453407  0.035204  0.020973
# 2025-06-02 18:00:00  0.301333  0.683627  0.454589  0.035709  0.022434
# 2025-06-02 19:00:00  0.364855  0.780665  0.454668  0.040093  0.044652
#
#                          bin1      bin2      bin3      bin4      bin5
# timestamp_local
# 2024-05-14 21:00:00  0.097140  0.069545  0.037300  0.023130  0.015025
# 2024-05-14 22:00:00  0.091791  0.063269  0.029746  0.014385  0.008799
# 2024-05-14 23:00:00  0.077033  0.050770  0.019989  0.005488  0.002332
# 2024-05-15 00:00:00  0.044736  0.028985  0.011348  0.002919  0.000443
# 2024-05-15 01:00:00  0.082626  0.061338  0.035480  0.020773  0.016723
# ...                       ...       ...       ...       ...       ...
# 2025-06-02 15:00:00  0.000299  0.000483  0.006099  0.011864  0.002323
# 2025-06-02 16:00:00  0.002028  0.001314  0.006014  0.011411  0.001753
# 2025-06-02 17:00:00  0.000033  0.000054  0.006294  0.011089  0.001749
# 2025-06-02 18:00:00  0.000467  0.000753  0.007347  0.012130  0.002634
# 2025-06-02 19:00:00  0.006242  0.004521  0.008865  0.011993  0.002654
#
# [8295 rows x 10 columns]

# %%
W_df = pd.DataFrame(W, columns =[f'Feature {i+1}' for i in range(0,4)]) #array-like of shape (n_samples, n_components)
W_df
# Out:
#       Feature 1  Feature 2  Feature 3  Feature 4
# 0      0.017150   0.038207   0.134333   0.007507
# 1      0.016456   0.028775   0.130712   0.004313
# 2      0.015469   0.020458   0.113285   0.000977
# 3      0.018256   0.018183   0.066560   0.000000
# 4      0.035816   0.003190   0.110893   0.008865
# ...         ...        ...        ...        ...
# 8290   0.030311   0.070075   0.000000   0.000328
# 8291   0.031239   0.071914   0.003017   0.000000
# 8292   0.049614   0.068957   0.000000   0.000037
# 8293   0.052101   0.068657   0.000000   0.000512
# 8294   0.059501   0.067207   0.008553   0.000541
#
# [8295 rows x 4 columns]

# %%
COLS_TO_INCLUDE.pop(0)
COLS_TO_INCLUDE
# Out:
# ['co', 'no', 'no2', 'o3', 'bin0', 'bin1', 'bin2', 'bin3', 'bin4', 'bin5']

# %%
H_df = pd.DataFrame(H, index = [f'Feature {i+1}' for i in range(0,4)], columns = COLS_TO_INCLUDE) #array-like of shape (n_components, n_features)
H_df
# Out:
#                  co         no       no2        o3      bin0      bin1  \
# Feature 1  4.290673  13.110643  1.138398  0.220650  0.422089  0.000000
# Feature 2  1.132916   0.000000  5.756106  0.351696  0.000000  0.000000
# Feature 3  3.907308   0.000000  0.000000  0.380822  2.229607  0.672119
# Feature 4  0.000000   1.060043  0.152658  0.130270  0.865146  0.912786
#
#                bin2      bin3      bin4      bin5
# Feature 1  0.000000  0.044010  0.003235  0.000000
# Feature 2  0.000000  0.058536  0.157270  0.024371
# Feature 3  0.435472  0.142437  0.000000  0.000000
# Feature 4  1.471659  2.021545  2.273466  1.877507

# %%
#converting the results to a dataframe
results = pd.DataFrame(W,index=data.index) #H is time series data of the factors, W is the comp (coeff matrix)
results.columns = ["Factor {}".format(i+1) for i in range(H.T.shape[1])]
results
# Out:
#                      Factor 1  Factor 2  Factor 3  Factor 4
# timestamp_local
# 2024-05-14 21:00:00  0.017150  0.038207  0.134333  0.007507
# 2024-05-14 22:00:00  0.016456  0.028775  0.130712  0.004313
# 2024-05-14 23:00:00  0.015469  0.020458  0.113285  0.000977
# 2024-05-15 00:00:00  0.018256  0.018183  0.066560  0.000000
# 2024-05-15 01:00:00  0.035816  0.003190  0.110893  0.008865
# ...                       ...       ...       ...       ...
# 2025-06-02 15:00:00  0.030311  0.070075  0.000000  0.000328
# 2025-06-02 16:00:00  0.031239  0.071914  0.003017  0.000000
# 2025-06-02 17:00:00  0.049614  0.068957  0.000000  0.000037
# 2025-06-02 18:00:00  0.052101  0.068657  0.000000  0.000512
# 2025-06-02 19:00:00  0.059501  0.067207  0.008553  0.000541
#
# [8295 rows x 4 columns]

# %%
COLS_TO_INCLUDE = ['co','no','no2','o3','bin0','bin1','bin2','bin3','bin4','bin5']
comp = pd.DataFrame(H, index = results.columns, columns = COLS_TO_INCLUDE)
comp
# Out:
#                 co         no       no2        o3      bin0      bin1  \
# Factor 1  4.290673  13.110643  1.138398  0.220650  0.422089  0.000000
# Factor 2  1.132916   0.000000  5.756106  0.351696  0.000000  0.000000
# Factor 3  3.907308   0.000000  0.000000  0.380822  2.229607  0.672119
# Factor 4  0.000000   1.060043  0.152658  0.130270  0.865146  0.912786
#
#               bin2      bin3      bin4      bin5
# Factor 1  0.000000  0.044010  0.003235  0.000000
# Factor 2  0.000000  0.058536  0.157270  0.024371
# Factor 3  0.435472  0.142437  0.000000  0.000000
# Factor 4  1.471659  2.021545  2.273466  1.877507

# %%
res = []

for col in comp.columns:
    #for each factor, compute its contribution to the species in V
    by_factor = pd.Series(dtype=float)
    for i, factor in enumerate(results.columns):
        contrib = H[i, data.columns.get_loc(col)] * W[:, i].sum()
        by_factor.at[factor] = contrib

    #normalizing by the total amount of that species in the original data
    by_factor /= data[col].sum()

    #adding as a row to the resulting dataframe
    res.append(pd.DataFrame(by_factor).T.rename(index={0: col}))

res = pd.concat(res)
res.columns = results.columns
res['Residual'] = 1 - res.sum(axis=1)

res
# Out:
#       Factor 1  Factor 2  Factor 3  Factor 4  Residual
# co    0.463150  0.171086  0.366547  0.000000 -0.000783
# no    0.189588  0.422762  0.284371  0.044776  0.058502
# no2   0.968659  0.000000  0.000000  0.031331  0.000011
# o3    0.123114  0.870887  0.000000  0.006604 -0.000605
# bin0  0.155901  0.000000  0.715696  0.127830  0.000573
# bin1  0.000000  0.000000  0.729353  0.455936 -0.185289
# bin2  0.000000  0.000000  0.413801  0.643696 -0.057497
# bin3  0.041866  0.077903  0.117758  0.769296 -0.006822
# bin4  0.002856  0.194279  0.000000  0.803056 -0.000191
# bin5  0.000000  0.043491  0.000000  0.958044 -0.001536

# %%
results.to_csv('/home/pmg2147/ModulAir NMF/OceanRoof/4_factor_results.csv')
comp.to_csv('/home/pmg2147/ModulAir NMF/OceanRoof/4_factor_comp.csv')
res.to_csv('/home/pmg2147/ModulAir NMF/OceanRoof/4_factor_resid.csv')
