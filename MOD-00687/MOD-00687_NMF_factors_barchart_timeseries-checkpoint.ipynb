# %% [markdown]
# # Factor Bar Chart and Timeseries Figures

# %%
import numpy as np
import seaborn as sns
import joblib
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.dates as mdates
import matplotlib.ticker as mticker
from matplotlib.ticker import FuncFormatter

# %%
# force the math text to look normal
mpl.rcParams['mathtext.default'] = 'regular'

def major_ticks(x, pos=None):
    """Set the major ticks according
    to this custom style
    """
    x = mdates.num2date(x)
    if pos == 0:
        fmt = "%-d\n%b %Y\n%I %p"
    else:
        fmt = "%-d"
    return x.strftime(fmt)

# set the default seaborn params
sns.set("paper", "ticks", color_codes=True, palette='colorblind')

# %% [markdown]
# ## Loading Data

# %%
#load in the comp data
comp = pd.read_csv('MOD-00687_4_factor_resid.csv')
comp.rename(columns={'Unnamed: 0':'species'},inplace=True)
comp
# Out:
#   species  Factor 1  Factor 2  Factor 3  Factor 4  Residual
# 0      co  0.477346  0.147076  0.034650  0.341110 -0.000182
# 1      no  0.525642  0.186476  0.000000  0.282812  0.005070
# 2     no2  0.947273  0.000000  0.033367  0.019438 -0.000077
# 3      o3  0.241984  0.757804  0.000000  0.000000  0.000212
# 4    bin0  0.000000  0.323750  0.621186  0.079156 -0.024092
# 5    bin1  0.000000  0.000000  1.039005  0.000000 -0.039005
# 6    bin2  0.000000  0.000000  1.060219  0.000000 -0.060219
# 7    bin3  0.000000  0.000000  0.945756  0.066720 -0.012476
# 8    bin4  0.062246  0.000000  0.602226  0.331761  0.003766
# 9    bin5  0.133044  0.000000  0.281592  0.578007  0.007357

# %%
comp2 = pd.melt(comp,id_vars='species', value_vars=['Factor 1','Factor 2','Factor 3','Residual'])
comp2
# Out:
#    species  variable     value
# 0       co  Factor 1  0.477346
# 1       no  Factor 1  0.525642
# 2      no2  Factor 1  0.947273
# 3       o3  Factor 1  0.241984
# 4     bin0  Factor 1  0.000000
# 5     bin1  Factor 1  0.000000
# 6     bin2  Factor 1  0.000000
# 7     bin3  Factor 1  0.000000
# 8     bin4  Factor 1  0.062246
# 9     bin5  Factor 1  0.133044
# 10      co  Factor 2  0.147076
# 11      no  Factor 2  0.186476
# 12     no2  Factor 2  0.000000
# 13      o3  Factor 2  0.757804
# 14    bin0  Factor 2  0.323750
# 15    bin1  Factor 2  0.000000
# 16    bin2  Factor 2  0.000000
# 17    bin3  Factor 2  0.000000
# 18    bin4  Factor 2  0.000000
# 19    bin5  Factor 2  0.000000
# 20      co  Factor 3  0.034650
# 21      no  Factor 3  0.000000
# 22     no2  Factor 3  0.033367
# 23      o3  Factor 3  0.000000
# 24    bin0  Factor 3  0.621186
# 25    bin1  Factor 3  1.039005
# 26    bin2  Factor 3  1.060219
# 27    bin3  Factor 3  0.945756
# 28    bin4  Factor 3  0.602226
# 29    bin5  Factor 3  0.281592
# 30      co  Residual -0.000182
# 31      no  Residual  0.005070
# 32     no2  Residual -0.000077
# 33      o3  Residual  0.000212
# 34    bin0  Residual -0.024092
# 35    bin1  Residual -0.039005
# 36    bin2  Residual -0.060219
# 37    bin3  Residual -0.012476
# 38    bin4  Residual  0.003766
# 39    bin5  Residual  0.007357

# %%
#load in the timeseries data
ts = pd.read_csv('MOD-00687_timeseries_hourly_scaled.csv').reset_index()
results = pd.read_csv('MOD-00687_4_factor_results.csv')

ts = pd.concat([ts,results['Factor 1'],results['Factor 2'], results['Factor 3']], axis = 1)
cols_reordered = ['timestamp_local','bin0','bin1','bin2','bin3','bin4','bin5','co','o3','no','no2','Factor 1','Factor 2','Factor 3']
ts = ts[cols_reordered]
ts.head()
# Out:
#        timestamp_local      bin0      bin1      bin2      bin3      bin4  \
# 0  2025-05-15 08:00:00  0.628679  0.276908  0.145973  0.123314  0.136161
# 1  2025-05-15 09:00:00  0.298863  0.144952  0.093960  0.063584  0.051339
# 2  2025-05-15 10:00:00  0.184899  0.117627  0.087248  0.046243  0.029018
# 3  2025-05-15 11:00:00  0.171298  0.121293  0.078300  0.042389  0.031250
# 4  2025-05-15 12:00:00  0.197327  0.178940  0.128635  0.075145  0.051339
#
#        bin5        co        o3        no       no2  Factor 1  Factor 2  \
# 0  0.148571  0.428372  0.247356  0.072391  0.253256  0.010584  0.052630
# 1  0.057143  0.415207  0.269095  0.066218  0.253456  0.016548  0.053908
# 2  0.034286  0.393316  0.290952  0.053030  0.317171  0.024234  0.054756
# 3  0.040000  0.400834  0.303878  0.045455  0.276698  0.020721  0.058655
# 4  0.051429  0.514519  0.298237  0.049102  0.330996  0.024131  0.055137
#
#    Factor 3
# 0  0.221070
# 1  0.099664
# 2  0.063943
# 3  0.059281
# 4  0.081881

# %%
ts['timestamp_local'] = pd.to_datetime(ts['timestamp_local']) #convert timestamp column to pandas timestamp format
ts = ts.set_index('timestamp_local',append=False) #setindex as local time
ts
# Out:
#                          bin0      bin1      bin2      bin3      bin4  \
# timestamp_local
# 2025-05-15 08:00:00  0.628679  0.276908  0.145973  0.123314  0.136161
# 2025-05-15 09:00:00  0.298863  0.144952  0.093960  0.063584  0.051339
# 2025-05-15 10:00:00  0.184899  0.117627  0.087248  0.046243  0.029018
# 2025-05-15 11:00:00  0.171298  0.121293  0.078300  0.042389  0.031250
# 2025-05-15 12:00:00  0.197327  0.178940  0.128635  0.075145  0.051339
# ...                       ...       ...       ...       ...       ...
# 2025-12-27 05:00:00  0.039747  0.018994  0.011186  0.011561  0.013393
# 2025-12-27 06:00:00  0.043147  0.019327  0.011745  0.011561  0.011161
# 2025-12-27 07:00:00  0.053582  0.025658  0.015660  0.013487  0.017857
# 2025-12-27 08:00:00  0.044906  0.021659  0.012304  0.011561  0.013393
# 2025-12-27 09:00:00  0.049947  0.024325  0.013423  0.011561  0.013393
#
#                          bin5        co        o3        no       no2  \
# timestamp_local
# 2025-05-15 08:00:00  0.148571  0.428372  0.247356  0.072391  0.253256
# 2025-05-15 09:00:00  0.057143  0.415207  0.269095  0.066218  0.253456
# 2025-05-15 10:00:00  0.034286  0.393316  0.290952  0.053030  0.317171
# 2025-05-15 11:00:00  0.040000  0.400834  0.303878  0.045455  0.276698
# 2025-05-15 12:00:00  0.051429  0.514519  0.298237  0.049102  0.330996
# ...                       ...       ...       ...       ...       ...
# 2025-12-27 05:00:00  0.028571  0.427122  0.139600  0.076599  0.668002
# 2025-12-27 06:00:00  0.022857  0.419029  0.143126  0.070146  0.665798
# 2025-12-27 07:00:00  0.040000  0.419296  0.141011  0.063692  0.655580
# 2025-12-27 08:00:00  0.028571  0.398158  0.161457  0.055836  0.653576
# 2025-12-27 09:00:00  0.034286  0.427907  0.157814  0.054994  0.666800
#
#                      Factor 1  Factor 2  Factor 3
# timestamp_local
# 2025-05-15 08:00:00  0.010584  0.052630  0.221070
# 2025-05-15 09:00:00  0.016548  0.053908  0.099664
# 2025-05-15 10:00:00  0.024234  0.054756  0.063943
# 2025-05-15 11:00:00  0.020721  0.058655  0.059281
# 2025-05-15 12:00:00  0.024131  0.055137  0.081881
# ...                       ...       ...       ...
# 2025-12-27 05:00:00  0.057812  0.008551  0.009970
# 2025-12-27 06:00:00  0.057656  0.009476  0.010786
# 2025-12-27 07:00:00  0.056412  0.009263  0.015785
# 2025-12-27 08:00:00  0.056614  0.013719  0.011831
# 2025-12-27 09:00:00  0.057540  0.012550  0.013407
#
# [5033 rows x 13 columns]

# %%
#taking daily average of ts. round to floor of the day
ts = ts.reset_index()

ts_day = ts.groupby(ts['timestamp_local'].dt.floor('d')).agg(bin0 = ('bin0','mean'),
                                                  bin1 = ('bin1','mean'),
                                                  bin2 = ('bin2','mean'),
                                                  bin3 = ('bin3','mean'),
                                                  bin4 = ('bin4','mean'),
                                                  bin5 = ('bin5','mean'),
                                                  co = ('co','mean'),
                                                  o3 = ('o3','mean'),
                                                  no = ('no','mean'),
                                                  no2 = ('no2','mean'),
                                                  factor1 = ('Factor 1','mean'),
                                                  factor2 = ('Factor 2','mean'),
                                                  factor3 = ('Factor 3','mean')).reset_index()

ts_day = ts_day.set_index('timestamp_local')
ts_day.head()
# Out:
#                      bin0      bin1      bin2      bin3      bin4      bin5  \
# timestamp_local
# 2025-05-15       0.313907  0.248459  0.157578  0.105612  0.081055  0.083571
# 2025-05-16       0.435260  0.502680  0.321728  0.252569  0.222377  0.168095
# 2025-05-17       0.240552  0.206973  0.096220  0.059811  0.066034  0.130000
# 2025-05-18       0.017284  0.005637  0.003985  0.003854  0.007347  0.017381
# 2025-05-19       0.018452  0.006137  0.003985  0.003292  0.004836  0.009762
#
#                        co        o3        no       no2   factor1   factor2  \
# timestamp_local
# 2025-05-15       0.453802  0.282844  0.053416  0.373936  0.026000  0.050993
# 2025-05-16       0.471179  0.235909  0.053393  0.542744  0.036332  0.033619
# 2025-05-17       0.443800  0.355459  0.060466  0.425650  0.031939  0.064284
# 2025-05-18       0.371217  0.425553  0.072309  0.492378  0.043305  0.075959
# 2025-05-19       0.358536  0.411305  0.059168  0.406665  0.035628  0.075861
#
#                   factor3
# timestamp_local
# 2025-05-15       0.133202
# 2025-05-16       0.245526
# 2025-05-17       0.100312
# 2025-05-18       0.000000
# 2025-05-19       0.000000

# %% [markdown]
# ## Setting Up Barchart and 6-month Figures

# %%
# set up the figure
fig = plt.figure(figsize=(9, 8))

ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

# %%
cols = ['bin0', 'bin1', 'bin2','bin3','bin4','bin5','co', 'o3','no', 'no2']

pal = sns.color_palette()

colors = [pal[3], pal[2], pal[4], pal[5]]
colors += sns.color_palette("Blues", 6)
colors.reverse()

# %%
ax1 = sns.barplot(x='variable',y='value',
        data=comp2,
        ax=ax1, hue='species',hue_order=cols,
        palette=colors, saturation=1, edgecolor='black', linewidth=0.25,
        errwidth=.75)
# Out:
# /tmp/ipython-input-269/2976516543.py:1: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 0.75}` instead.
#
#   ax1 = sns.barplot(x='variable',y='value',

# %%
ax1.set_ylim(-0.2, 1)
ax1.set_xlabel("")
ax1.set_ylabel("Percent of Species Signal\nDescribed by Factor", fontsize=14)
ax1.set(yticks=np.linspace(-0.2, 1, 13), yticklabels=["","","0","","","","","50","","","","","100"])
ax1.tick_params(axis='both', which='major', labelsize=14)
ax1.axhline(y=0, color='black', linestyle='-', lw =0.5)

# %%
handles, _ = ax1.get_legend_handles_labels()
labels = ["Bin 0", "Bin 1", "Bin 2", "Bin 3","Bin 4","Bin 5","CO","$O_3$","$NO$", "$NO_2$"]
ax1.legend(handles, labels)

# %%
ax2.plot(ts_day.index, ts_day["factor1"], label="Factor 1 ", lw=1, color=sns.xkcd_rgb['slate blue'])
ax2.plot(ts_day.index, ts_day["factor2"], label="Factor 2", lw=1, color=sns.xkcd_rgb['dull green'])
ax2.plot(ts_day.index, ts_day["factor3"], label="Factor 3", lw=1, color=sns.xkcd_rgb['dark lavender'])

ax2.set_ylabel("Factor Intensity (a.u.)", fontsize=14)

#last 6 months
ax2.set_xlim(ts_day.index[-180], ts_day.index[-1])
#ax2.set_xlim(ts_day.index[0], ts_day.index[-1])

ax2.legend(loc='upper right',fontsize=10)
ax2.tick_params(axis='both', which='major', labelsize=14)

# %%
ax1.set_title('(a)',fontsize=14)
ax2.set_title('(b)',fontsize=14)
# Out:
# Text(0.5, 1.0, '(b)')

# %%
plt.gcf().text(0.09, 0.9, "(a)", fontsize=12)
plt.gcf().text(0.5, 0.9, "(b)", fontsize=12)
plt.gcf().text(0.09,0.9,'MOD-00687',fontsize=12)

plt.tight_layout()

# %%
# fig.savefig('time_barchart_MOD-00687_4_factor.png')

# %%
fig

# %% [markdown]
# ## Setting Up Diurnal Figure

# %%
ts.head()
# Out:
#       timestamp_local      bin0      bin1      bin2      bin3      bin4  \
# 0 2025-05-15 08:00:00  0.628679  0.276908  0.145973  0.123314  0.136161
# 1 2025-05-15 09:00:00  0.298863  0.144952  0.093960  0.063584  0.051339
# 2 2025-05-15 10:00:00  0.184899  0.117627  0.087248  0.046243  0.029018
# 3 2025-05-15 11:00:00  0.171298  0.121293  0.078300  0.042389  0.031250
# 4 2025-05-15 12:00:00  0.197327  0.178940  0.128635  0.075145  0.051339
#
#        bin5        co        o3        no       no2  Factor 1  Factor 2  \
# 0  0.148571  0.428372  0.247356  0.072391  0.253256  0.010584  0.052630
# 1  0.057143  0.415207  0.269095  0.066218  0.253456  0.016548  0.053908
# 2  0.034286  0.393316  0.290952  0.053030  0.317171  0.024234  0.054756
# 3  0.040000  0.400834  0.303878  0.045455  0.276698  0.020721  0.058655
# 4  0.051429  0.514519  0.298237  0.049102  0.330996  0.024131  0.055137
#
#    Factor 3
# 0  0.221070
# 1  0.099664
# 2  0.063943
# 3  0.059281
# 4  0.081881

# %%
#prepping data
ts = ts.set_index('timestamp_local')
ts['Hour'] = ts.index.hour
ts.head()
# Out:
#                          bin0      bin1      bin2      bin3      bin4  \
# timestamp_local
# 2025-05-15 08:00:00  0.628679  0.276908  0.145973  0.123314  0.136161
# 2025-05-15 09:00:00  0.298863  0.144952  0.093960  0.063584  0.051339
# 2025-05-15 10:00:00  0.184899  0.117627  0.087248  0.046243  0.029018
# 2025-05-15 11:00:00  0.171298  0.121293  0.078300  0.042389  0.031250
# 2025-05-15 12:00:00  0.197327  0.178940  0.128635  0.075145  0.051339
#
#                          bin5        co        o3        no       no2  \
# timestamp_local
# 2025-05-15 08:00:00  0.148571  0.428372  0.247356  0.072391  0.253256
# 2025-05-15 09:00:00  0.057143  0.415207  0.269095  0.066218  0.253456
# 2025-05-15 10:00:00  0.034286  0.393316  0.290952  0.053030  0.317171
# 2025-05-15 11:00:00  0.040000  0.400834  0.303878  0.045455  0.276698
# 2025-05-15 12:00:00  0.051429  0.514519  0.298237  0.049102  0.330996
#
#                      Factor 1  Factor 2  Factor 3  Hour
# timestamp_local
# 2025-05-15 08:00:00  0.010584  0.052630  0.221070     8
# 2025-05-15 09:00:00  0.016548  0.053908  0.099664     9
# 2025-05-15 10:00:00  0.024234  0.054756  0.063943    10
# 2025-05-15 11:00:00  0.020721  0.058655  0.059281    11
# 2025-05-15 12:00:00  0.024131  0.055137  0.081881    12

# %%
#grouping by hour and calculate the mean
diurnal_data = ts.groupby('Hour')[['Factor 1','Factor 2','Factor 3']].mean()
diurnal_data.index = diurnal_data.index.map(lambda x: "{:02d}:00".format(x))
diurnal_data
# Out:
#        Factor 1  Factor 2  Factor 3
# Hour
# 00:00  0.047517  0.045107  0.041753
# 01:00  0.047915  0.042836  0.041236
# 02:00  0.047489  0.040342  0.042778
# 03:00  0.047693  0.037675  0.042223
# 04:00  0.047188  0.035200  0.045614
# 05:00  0.047875  0.031282  0.048664
# 06:00  0.047498  0.029075  0.046165
# 07:00  0.043620  0.031523  0.042356
# 08:00  0.036894  0.039259  0.039980
# 09:00  0.034750  0.049012  0.034667
# 10:00  0.034028  0.059915  0.032705
# 11:00  0.035374  0.070277  0.031377
# 12:00  0.037704  0.076897  0.030645
# 13:00  0.041463  0.080460  0.029312
# 14:00  0.043266  0.083056  0.028793
# 15:00  0.046794  0.082183  0.029309
# 16:00  0.049581  0.078909  0.028218
# 17:00  0.051236  0.073737  0.028130
# 18:00  0.051595  0.067506  0.029329
# 19:00  0.052568  0.061827  0.030898
# 20:00  0.051877  0.056730  0.034266
# 21:00  0.050694  0.052469  0.036654
# 22:00  0.049182  0.049366  0.038587
# 23:00  0.048173  0.047335  0.039115

# %%
# set up the figure
plt.figure(figsize=(10, 6))

plt.plot(diurnal_data.index, diurnal_data['Factor 1'], label='Factor 1', lw = 2, color=sns.xkcd_rgb['slate blue'])
plt.plot(diurnal_data.index, diurnal_data['Factor 2'], label='Factor 2', lw = 2, color=sns.xkcd_rgb['dull green'])
plt.plot(diurnal_data.index, diurnal_data['Factor 3'], label='Factor 3', lw = 2, color=sns.xkcd_rgb['dark lavender'])

plt.ylabel('Factor Intensity (a.u.)', fontsize = 14)
plt.legend(loc='upper right',fontsize=14)
plt.xticks(range(0, 24))
plt.xticks(rotation=45)

plt.tick_params(labelsize=14)

# plt.savefig('diurnal_MOD-00687_3_factor.png')
plt.show()
