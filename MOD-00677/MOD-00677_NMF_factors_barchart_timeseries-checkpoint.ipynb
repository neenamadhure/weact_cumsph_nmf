# %% [markdown]
# # Factor Bar Chart and Timeseries Figures

# %%
import numpy as np
import seaborn as sns
import joblib
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.dates as mdates
import matplotlib.ticker as mticker
from matplotlib.ticker import FuncFormatter

# %%
# force the math text to look normal
mpl.rcParams['mathtext.default'] = 'regular'

def major_ticks(x, pos=None):
    """Set the major ticks according
    to this custom style
    """
    x = mdates.num2date(x)
    if pos == 0:
        fmt = "%-d\n%b %Y\n%I %p"
    else:
        fmt = "%-d"
    return x.strftime(fmt)

# set the default seaborn params
sns.set("paper", "ticks", color_codes=True, palette='colorblind')

# %% [markdown]
# ## Loading Data

# %%
#load in the comp data
comp = pd.read_csv('4_factor_resid.csv')
comp.rename(columns={'Unnamed: 0':'species'},inplace=True)
comp
# Out:
#   species  Factor 1  Factor 2  Factor 3  Factor 4  Residual
# 0      co  0.550414  0.104036  0.013048  0.315761  0.016742
# 1      no  0.590652  0.075993  0.043148  0.274570  0.015636
# 2     no2  0.966221  0.021792  0.013972  0.000000 -0.001984
# 3      o3  0.346019  0.008131  0.004015  0.645001 -0.003165
# 4    bin0  0.000000  0.770112  0.000000  0.238547 -0.008659
# 5    bin1  0.000000  0.816053  0.307109  0.000000 -0.123162
# 6    bin2  0.000000  0.501216  0.571752  0.000000 -0.072968
# 7    bin3  0.038961  0.228743  0.727432  0.004530  0.000334
# 8    bin4  0.077229  0.023493  0.695447  0.203370  0.000461
# 9    bin5  0.141565  0.000000  0.574510  0.285507 -0.001582

# %%
comp2 = pd.melt(comp,id_vars='species', value_vars=['Factor 1','Factor 2','Factor 3','Residual'])
comp2
# Out:
#    species  variable     value
# 0       co  Factor 1  0.550414
# 1       no  Factor 1  0.590652
# 2      no2  Factor 1  0.966221
# 3       o3  Factor 1  0.346019
# 4     bin0  Factor 1  0.000000
# 5     bin1  Factor 1  0.000000
# 6     bin2  Factor 1  0.000000
# 7     bin3  Factor 1  0.038961
# 8     bin4  Factor 1  0.077229
# 9     bin5  Factor 1  0.141565
# 10      co  Factor 2  0.104036
# 11      no  Factor 2  0.075993
# 12     no2  Factor 2  0.021792
# 13      o3  Factor 2  0.008131
# 14    bin0  Factor 2  0.770112
# 15    bin1  Factor 2  0.816053
# 16    bin2  Factor 2  0.501216
# 17    bin3  Factor 2  0.228743
# 18    bin4  Factor 2  0.023493
# 19    bin5  Factor 2  0.000000
# 20      co  Factor 3  0.013048
# 21      no  Factor 3  0.043148
# 22     no2  Factor 3  0.013972
# 23      o3  Factor 3  0.004015
# 24    bin0  Factor 3  0.000000
# 25    bin1  Factor 3  0.307109
# 26    bin2  Factor 3  0.571752
# 27    bin3  Factor 3  0.727432
# 28    bin4  Factor 3  0.695447
# 29    bin5  Factor 3  0.574510
# 30      co  Residual  0.016742
# 31      no  Residual  0.015636
# 32     no2  Residual -0.001984
# 33      o3  Residual -0.003165
# 34    bin0  Residual -0.008659
# 35    bin1  Residual -0.123162
# 36    bin2  Residual -0.072968
# 37    bin3  Residual  0.000334
# 38    bin4  Residual  0.000461
# 39    bin5  Residual -0.001582

# %%
#load in the timeseries data
ts = pd.read_csv('MOD-00677_timeseries_hourly_scaled.csv').reset_index()
results = pd.read_csv('4_factor_results.csv')

ts = pd.concat([ts,results['Factor 1'],results['Factor 2'], results['Factor 3']], axis = 1)
cols_reordered = ['timestamp_local','bin0','bin1','bin2','bin3','bin4','bin5','co','o3','no','no2','Factor 1','Factor 2', 'Factor 3']
ts = ts[cols_reordered]
ts.head()
# Out:
#        timestamp_local      bin0      bin1      bin2      bin3      bin4  \
# 0  2025-03-31 20:00:00  0.219139  0.073937  0.080121  0.125683  0.223684
# 1  2025-03-31 21:00:00  0.347591  0.148983  0.120181  0.155738  0.266447
# 2  2025-03-31 22:00:00  0.382377  0.301664  0.185185  0.193989  0.279605
# 3  2025-03-31 23:00:00  0.223606  0.153420  0.098262  0.092896  0.118421
# 4  2025-04-01 00:00:00  0.175284  0.101294  0.059713  0.054645  0.072368
#
#        bin5        co        o3        no       no2  Factor 1  Factor 2  \
# 0  0.294479  0.287833  0.413291  0.032938  0.622463  0.048177  0.031943
# 1  0.368098  0.337951  0.366707  0.045157  0.749468  0.056879  0.062532
# 2  0.361963  0.390250  0.375980  0.052063  0.813648  0.061109  0.082187
# 3  0.134969  0.296212  0.557015  0.049407  0.477093  0.036943  0.041698
# 4  0.085890  0.253517  0.622033  0.048344  0.539146  0.043129  0.026992
#
#    Factor 3
# 0  0.106832
# 1  0.134271
# 2  0.157334
# 3  0.062236
# 4  0.034541

# %%
ts['timestamp_local'] = pd.to_datetime(ts['timestamp_local']) #convert timestamp column to pandas timestamp format
ts = ts.set_index('timestamp_local',append=False) #setindex as local time
ts
# Out:
#                          bin0      bin1      bin2      bin3      bin4  \
# timestamp_local
# 2025-03-31 20:00:00  0.219139  0.073937  0.080121  0.125683  0.223684
# 2025-03-31 21:00:00  0.347591  0.148983  0.120181  0.155738  0.266447
# 2025-03-31 22:00:00  0.382377  0.301664  0.185185  0.193989  0.279605
# 2025-03-31 23:00:00  0.223606  0.153420  0.098262  0.092896  0.118421
# 2025-04-01 00:00:00  0.175284  0.101294  0.059713  0.054645  0.072368
# ...                       ...       ...       ...       ...       ...
# 2025-12-29 17:00:00  0.018544  0.009982  0.008314  0.005464  0.006579
# 2025-12-29 18:00:00  0.020980  0.010721  0.008314  0.005464  0.006579
# 2025-12-29 19:00:00  0.018002  0.009982  0.007559  0.005464  0.006579
# 2025-12-29 20:00:00  0.016784  0.008872  0.006803  0.005464  0.006579
# 2025-12-29 21:00:00  0.019762  0.008872  0.006047  0.005464  0.003289
#
#                          bin5        co        o3        no       no2  \
# timestamp_local
# 2025-03-31 20:00:00  0.294479  0.287833  0.413291  0.032938  0.622463
# 2025-03-31 21:00:00  0.368098  0.337951  0.366707  0.045157  0.749468
# 2025-03-31 22:00:00  0.361963  0.390250  0.375980  0.052063  0.813648
# 2025-03-31 23:00:00  0.134969  0.296212  0.557015  0.049407  0.477093
# 2025-04-01 00:00:00  0.085890  0.253517  0.622033  0.048344  0.539146
# ...                       ...       ...       ...       ...       ...
# 2025-12-29 17:00:00  0.006135  0.231261  0.349266  0.038959  0.587280
# 2025-12-29 18:00:00  0.006135  0.235597  0.336792  0.035594  0.607384
# 2025-12-29 19:00:00  0.006135  0.232238  0.333922  0.034177  0.600619
# 2025-12-29 20:00:00  0.006135  0.234853  0.343305  0.033469  0.620143
# 2025-12-29 21:00:00  0.006135  0.238080  0.340325  0.032761  0.639474
#
#                      Factor 1  Factor 2  Factor 3
# timestamp_local
# 2025-03-31 20:00:00  0.048177  0.031943  0.106832
# 2025-03-31 21:00:00  0.056879  0.062532  0.134271
# 2025-03-31 22:00:00  0.061109  0.082187  0.157334
# 2025-03-31 23:00:00  0.036943  0.041698  0.062236
# 2025-04-01 00:00:00  0.043129  0.026992  0.034541
# ...                       ...       ...       ...
# 2025-12-29 17:00:00  0.051192  0.001097  0.000055
# 2025-12-29 18:00:00  0.052939  0.002119  0.000000
# 2025-12-29 19:00:00  0.052368  0.001457  0.000040
# 2025-12-29 20:00:00  0.054029  0.000887  0.000000
# 2025-12-29 21:00:00  0.055669  0.001585  0.000000
#
# [6449 rows x 13 columns]

# %%
#taking daily average of ts. round to floor of the day
ts = ts.reset_index()

ts_day = ts.groupby(ts['timestamp_local'].dt.floor('d')).agg(bin0 = ('bin0','mean'),
                                                  bin1 = ('bin1','mean'),
                                                  bin2 = ('bin2','mean'),
                                                  bin3 = ('bin3','mean'),
                                                  bin4 = ('bin4','mean'),
                                                  bin5 = ('bin5','mean'),
                                                  co = ('co','mean'),
                                                  o3 = ('o3','mean'),
                                                  no = ('no','mean'),
                                                  no2 = ('no2','mean'),
                                                  factor1 = ('Factor 1','mean'),
                                                  factor2 = ('Factor 2','mean'),
                                                  factor3 = ('Factor 3', 'mean')).reset_index()

ts_day = ts_day.set_index('timestamp_local')
ts_day.head()
# Out:
#                      bin0      bin1      bin2      bin3      bin4      bin5  \
# timestamp_local
# 2025-03-31       0.293178  0.169501  0.120937  0.142077  0.222039  0.289877
# 2025-04-01       0.059878  0.029159  0.018235  0.015483  0.018366  0.018661
# 2025-04-02       0.036845  0.020317  0.026077  0.041553  0.070861  0.094325
# 2025-04-03       0.235094  0.104128  0.079239  0.113502  0.209430  0.303937
# 2025-04-04       0.057977  0.021211  0.017794  0.019695  0.027823  0.035020
#
#                        co        o3        no       no2   factor1   factor2  \
# timestamp_local
# 2025-03-31       0.328061  0.428248  0.044891  0.665668  0.050777  0.054590
# 2025-04-01       0.246670  0.525113  0.040361  0.468031  0.040004  0.006592
# 2025-04-02       0.258595  0.585523  0.036826  0.558195  0.046764  0.000000
# 2025-04-03       0.309464  0.423989  0.040766  0.579314  0.044556  0.039400
# 2025-04-04       0.270427  0.486137  0.035432  0.395942  0.034354  0.007116
#
#                   factor3
# timestamp_local
# 2025-03-31       0.115168
# 2025-04-01       0.006109
# 2025-04-02       0.031400
# 2025-04-03       0.105118
# 2025-04-04       0.009583

# %% [markdown]
# ## Setting Up Barchart and 6-month Figures

# %%
# set up the figure
fig = plt.figure(figsize=(9,8))

ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

# %%
cols = ['bin0', 'bin1', 'bin2','bin3','bin4','bin5','co', 'o3','no', 'no2']

pal = sns.color_palette()

colors = [pal[3], pal[2], pal[4], pal[5]]
colors += sns.color_palette("Blues", 6)
colors.reverse()

# %%
ax1 = sns.barplot(x='variable',y='value',
        data=comp2,
        ax=ax1, hue='species',hue_order=cols,
        palette=colors, saturation=1, edgecolor='black', linewidth=0.25,
        errwidth=.75)
# Out:
# /tmp/ipykernel_9131/2976516543.py:1: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 0.75}` instead.
#
#   ax1 = sns.barplot(x='variable',y='value',

# %%
ax1.set_ylim(-0.2, 1)
ax1.set_xlabel("")
ax1.set_ylabel("Percent of Species Signal\nDescribed by Factor", fontsize=14)
ax1.set(yticks=np.linspace(-0.2, 1, 13), yticklabels=["","","0","","","","","50","","","","","100"])
ax1.tick_params(axis='both', which='major', labelsize=14)
ax1.axhline(y=0, color='black', linestyle='-', lw =0.5)

# %%
handles, _ = ax1.get_legend_handles_labels()
labels = ["Bin 0", "Bin 1", "Bin 2", "Bin 3","Bin 4","Bin 5","CO","$O_3$","$NO$", "$NO_2$"]
ax1.legend(handles, labels)

# %%
ax2.plot(ts_day.index, ts_day["factor1"], label="Factor 1 ", lw=1, color=sns.xkcd_rgb['slate blue'])
ax2.plot(ts_day.index, ts_day["factor2"], label="Factor 2", lw=1, color=sns.xkcd_rgb['dull green'])
ax2.plot(ts_day.index, ts_day["factor3"], label="Factor 3", lw=1, color=sns.xkcd_rgb['deep purple'])

ax2.set_ylabel("Factor Intensity (a.u.)", fontsize=14)

#last 6 months
ax2.set_xlim(ts_day.index[-180], ts_day.index[-1])
#ax2.set_xlim(ts_day.index[0], ts_day.index[-1])

ax2.legend(loc='upper right',fontsize=10)
ax2.tick_params(axis='both', which='major', labelsize=14)

# %%
ax1.set_title('(a)',fontsize=14)
ax2.set_title('(b)',fontsize=14)
# Out:
# Text(0.5, 1.0, '(b)')

# %%
plt.gcf().text(0.09, 0.9, "(a)", fontsize=12)
plt.gcf().text(0.5, 0.9, "(b)", fontsize=12)
plt.gcf().text(0.09,0.9,'MOD-00677',fontsize=12)

plt.tight_layout()

# %%
 fig.savefig('time_barchart_MOD-00677_4_factor.png')

# %%
fig

# %% [markdown]
# ## Setting Up Diurnal Figure

# %%
ts.head()
# Out:
#       timestamp_local      bin0      bin1      bin2      bin3      bin4  \
# 0 2025-03-31 20:00:00  0.219139  0.073937  0.080121  0.125683  0.223684
# 1 2025-03-31 21:00:00  0.347591  0.148983  0.120181  0.155738  0.266447
# 2 2025-03-31 22:00:00  0.382377  0.301664  0.185185  0.193989  0.279605
# 3 2025-03-31 23:00:00  0.223606  0.153420  0.098262  0.092896  0.118421
# 4 2025-04-01 00:00:00  0.175284  0.101294  0.059713  0.054645  0.072368
#
#        bin5        co        o3        no       no2  Factor 1  Factor 2  \
# 0  0.294479  0.287833  0.413291  0.032938  0.622463  0.048177  0.031943
# 1  0.368098  0.337951  0.366707  0.045157  0.749468  0.056879  0.062532
# 2  0.361963  0.390250  0.375980  0.052063  0.813648  0.061109  0.082187
# 3  0.134969  0.296212  0.557015  0.049407  0.477093  0.036943  0.041698
# 4  0.085890  0.253517  0.622033  0.048344  0.539146  0.043129  0.026992
#
#    Factor 3
# 0  0.106832
# 1  0.134271
# 2  0.157334
# 3  0.062236
# 4  0.034541

# %%
#prepping data
ts = ts.set_index('timestamp_local')
ts['Hour'] = ts.index.hour
ts.head()
# Out:
#                          bin0      bin1      bin2      bin3      bin4  \
# timestamp_local
# 2025-03-31 20:00:00  0.219139  0.073937  0.080121  0.125683  0.223684
# 2025-03-31 21:00:00  0.347591  0.148983  0.120181  0.155738  0.266447
# 2025-03-31 22:00:00  0.382377  0.301664  0.185185  0.193989  0.279605
# 2025-03-31 23:00:00  0.223606  0.153420  0.098262  0.092896  0.118421
# 2025-04-01 00:00:00  0.175284  0.101294  0.059713  0.054645  0.072368
#
#                          bin5        co        o3        no       no2  \
# timestamp_local
# 2025-03-31 20:00:00  0.294479  0.287833  0.413291  0.032938  0.622463
# 2025-03-31 21:00:00  0.368098  0.337951  0.366707  0.045157  0.749468
# 2025-03-31 22:00:00  0.361963  0.390250  0.375980  0.052063  0.813648
# 2025-03-31 23:00:00  0.134969  0.296212  0.557015  0.049407  0.477093
# 2025-04-01 00:00:00  0.085890  0.253517  0.622033  0.048344  0.539146
#
#                      Factor 1  Factor 2  Factor 3  Hour
# timestamp_local
# 2025-03-31 20:00:00  0.048177  0.031943  0.106832    20
# 2025-03-31 21:00:00  0.056879  0.062532  0.134271    21
# 2025-03-31 22:00:00  0.061109  0.082187  0.157334    22
# 2025-03-31 23:00:00  0.036943  0.041698  0.062236    23
# 2025-04-01 00:00:00  0.043129  0.026992  0.034541     0

# %%
#grouping by hour and calculate the mean
diurnal_data = ts.groupby('Hour')[['Factor 1','Factor 2','Factor 3']].mean()
diurnal_data.index = diurnal_data.index.map(lambda x: "{:02d}:00".format(x))
diurnal_data
# Out:
#        Factor 1  Factor 2  Factor 3
# Hour
# 00:00  0.047268  0.025805  0.021806
# 01:00  0.047709  0.025927  0.019844
# 02:00  0.046959  0.026042  0.019599
# 03:00  0.046572  0.026871  0.020332
# 04:00  0.046461  0.027656  0.022139
# 05:00  0.047785  0.028672  0.023143
# 06:00  0.048802  0.029514  0.022237
# 07:00  0.045575  0.028357  0.021659
# 08:00  0.040582  0.026474  0.018730
# 09:00  0.036946  0.024442  0.016944
# 10:00  0.034627  0.022887  0.014522
# 11:00  0.034986  0.021410  0.011577
# 12:00  0.036512  0.019537  0.010186
# 13:00  0.038542  0.018694  0.009741
# 14:00  0.039071  0.018202  0.009260
# 15:00  0.039557  0.018167  0.009316
# 16:00  0.041787  0.017271  0.009080
# 17:00  0.045214  0.017457  0.009727
# 18:00  0.048040  0.019214  0.011661
# 19:00  0.050550  0.020024  0.014844
# 20:00  0.050354  0.022457  0.016074
# 21:00  0.049272  0.024615  0.017836
# 22:00  0.047964  0.025979  0.018491
# 23:00  0.047996  0.025935  0.019507

# %%
# set up the figure
plt.figure(figsize=(10, 8))

plt.plot(diurnal_data.index, diurnal_data['Factor 1'], label='Factor 1', lw = 2, color=sns.xkcd_rgb['slate blue'])
plt.plot(diurnal_data.index, diurnal_data['Factor 2'], label='Factor 2', lw = 2, color=sns.xkcd_rgb['dull green'])
plt.plot(diurnal_data.index, diurnal_data['Factor 3'], label='Factor 3', lw = 2, color=sns.xkcd_rgb['deep purple'])

plt.ylabel('Factor Intensity (a.u.)', fontsize = 14)
plt.legend(loc='upper right',fontsize=14)
plt.xticks(range(0, 24))
plt.xticks(rotation=45)

plt.tick_params(labelsize=14)

plt.savefig('diurnal_MOD-00677_4_factor.png')
plt.show()
