# %% [markdown]
# # Factor Bar Chart and Timeseries Figures

# %%
import numpy as np
import seaborn as sns
import joblib
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.dates as mdates
import matplotlib.ticker as mticker
from matplotlib.ticker import FuncFormatter

# %%
# force the math text to look normal
mpl.rcParams['mathtext.default'] = 'regular'

def major_ticks(x, pos=None):
    """Set the major ticks according
    to this custom style
    """
    x = mdates.num2date(x)
    if pos == 0:
        fmt = "%-d\n%b %Y\n%I %p"
    else:
        fmt = "%-d"
    return x.strftime(fmt)

# set the default seaborn params
sns.set("paper", "ticks", color_codes=True, palette='colorblind')

# %% [markdown]
# ## Loading Data

# %%
#load in the comp data
comp = pd.read_csv('MOD-00690_4_factor_resid.csv')
comp.rename(columns={'Unnamed: 0':'species'},inplace=True)
comp
# Out:
#   species  Factor 1  Factor 2  Factor 3  Factor 4  Residual
# 0      co  0.533995  0.330102  0.119470  0.006776  0.009657
# 1      no  0.606135  0.291234  0.093742  0.001512  0.007377
# 2     no2  0.086036  0.918248  0.000000  0.000217 -0.004502
# 3      o3  0.892617  0.043769  0.069114  0.000000 -0.005500
# 4    bin0  0.252886  0.000000  0.764329  0.000000 -0.017215
# 5    bin1  0.000000  0.000000  0.806514  0.290045 -0.096558
# 6    bin2  0.000000  0.000000  0.505159  0.549086 -0.054245
# 7    bin3  0.026775  0.014274  0.236813  0.721326  0.000814
# 8    bin4  0.284084  0.000000  0.048463  0.674092 -0.006639
# 9    bin5  0.410011  0.000000  0.000000  0.604345 -0.014356

# %%
comp2 = pd.melt(comp,id_vars='species', value_vars=['Factor 1','Factor 2','Factor 3', 'Factor 4', 'Residual'])
comp2
# Out:
#    species  variable     value
# 0       co  Factor 1  0.533995
# 1       no  Factor 1  0.606135
# 2      no2  Factor 1  0.086036
# 3       o3  Factor 1  0.892617
# 4     bin0  Factor 1  0.252886
# 5     bin1  Factor 1  0.000000
# 6     bin2  Factor 1  0.000000
# 7     bin3  Factor 1  0.026775
# 8     bin4  Factor 1  0.284084
# 9     bin5  Factor 1  0.410011
# 10      co  Factor 2  0.330102
# 11      no  Factor 2  0.291234
# 12     no2  Factor 2  0.918248
# 13      o3  Factor 2  0.043769
# 14    bin0  Factor 2  0.000000
# 15    bin1  Factor 2  0.000000
# 16    bin2  Factor 2  0.000000
# 17    bin3  Factor 2  0.014274
# 18    bin4  Factor 2  0.000000
# 19    bin5  Factor 2  0.000000
# 20      co  Factor 3  0.119470
# 21      no  Factor 3  0.093742
# 22     no2  Factor 3  0.000000
# 23      o3  Factor 3  0.069114
# 24    bin0  Factor 3  0.764329
# 25    bin1  Factor 3  0.806514
# 26    bin2  Factor 3  0.505159
# 27    bin3  Factor 3  0.236813
# 28    bin4  Factor 3  0.048463
# 29    bin5  Factor 3  0.000000
# 30      co  Factor 4  0.006776
# 31      no  Factor 4  0.001512
# 32     no2  Factor 4  0.000217
# 33      o3  Factor 4  0.000000
# 34    bin0  Factor 4  0.000000
# 35    bin1  Factor 4  0.290045
# 36    bin2  Factor 4  0.549086
# 37    bin3  Factor 4  0.721326
# 38    bin4  Factor 4  0.674092
# 39    bin5  Factor 4  0.604345
# 40      co  Residual  0.009657
# 41      no  Residual  0.007377
# 42     no2  Residual -0.004502
# 43      o3  Residual -0.005500
# 44    bin0  Residual -0.017215
# 45    bin1  Residual -0.096558
# 46    bin2  Residual -0.054245
# 47    bin3  Residual  0.000814
# 48    bin4  Residual -0.006639
# 49    bin5  Residual -0.014356

# %%
#load in the timeseries data
ts = pd.read_csv('MOD-00690_timeseries_hourly_scaled.csv').reset_index()
results = pd.read_csv('MOD-00690_4_factor_results.csv')

ts = pd.concat([ts,results['Factor 1'],results['Factor 2'], results['Factor 3'], results['Factor 4']], axis = 1)
cols_reordered = ['timestamp_local','bin0','bin1','bin2','bin3','bin4','bin5','co','o3','no','no2','Factor 1','Factor 2','Factor 3', 'Factor 4']
ts = ts[cols_reordered]
ts.head()
# Out:
#        timestamp_local      bin0      bin1      bin2      bin3      bin4  \
# 0  2025-03-31 20:00:00  0.266144  0.095946  0.095090  0.133333  0.246154
# 1  2025-03-31 21:00:00  0.374899  0.191893  0.138737  0.162319  0.284615
# 2  2025-03-31 22:00:00  0.316671  0.199331  0.131723  0.133333  0.207692
# 3  2025-03-31 23:00:00  0.202243  0.140945  0.086516  0.078261  0.111538
# 4  2025-04-01 00:00:00  0.190219  0.121235  0.070148  0.060870  0.088462
#
#        bin5        co        o3        no       no2  Factor 1  Factor 2  \
# 0  0.335484  0.554752  0.393187  0.024664  0.601199  0.036225  0.108895
# 1  0.412903  0.623529  0.396331  0.035127  0.626909  0.032180  0.114561
# 2  0.264516  0.597435  0.468134  0.035625  0.442876  0.042934  0.079396
# 3  0.122581  0.505352  0.574423  0.035376  0.312585  0.058074  0.050257
# 4  0.090323  0.459051  0.625052  0.034629  0.287261  0.062910  0.042124
#
#    Factor 3  Factor 4
# 0  0.049708  0.107585
# 1  0.082250  0.134477
# 2  0.076313  0.096565
# 3  0.045558  0.048922
# 4  0.038397  0.035620

# %%
ts['timestamp_local'] = pd.to_datetime(ts['timestamp_local']) #convert timestamp column to pandas timestamp format
ts = ts.set_index('timestamp_local',append=False) #setindex as local time
ts
# Out:
#                          bin0      bin1      bin2      bin3      bin4  \
# timestamp_local
# 2025-03-31 20:00:00  0.266144  0.095946  0.095090  0.133333  0.246154
# 2025-03-31 21:00:00  0.374899  0.191893  0.138737  0.162319  0.284615
# 2025-03-31 22:00:00  0.316671  0.199331  0.131723  0.133333  0.207692
# 2025-03-31 23:00:00  0.202243  0.140945  0.086516  0.078261  0.111538
# 2025-04-01 00:00:00  0.190219  0.121235  0.070148  0.060870  0.088462
# ...                       ...       ...       ...       ...       ...
# 2025-12-31 14:00:00  0.073764  0.020082  0.012471  0.008696  0.007692
# 2025-12-31 15:00:00  0.065928  0.020454  0.012471  0.008696  0.007692
# 2025-12-31 16:00:00  0.070927  0.023801  0.014030  0.008696  0.011538
# 2025-12-31 17:00:00  0.085517  0.031238  0.019486  0.014493  0.015385
# 2025-12-31 18:00:00  0.079303  0.030123  0.019486  0.014493  0.015385
#
#                          bin5        co        o3        no       no2  \
# timestamp_local
# 2025-03-31 20:00:00  0.335484  0.554752  0.393187  0.024664  0.601199
# 2025-03-31 21:00:00  0.412903  0.623529  0.396331  0.035127  0.626909
# 2025-03-31 22:00:00  0.264516  0.597435  0.468134  0.035625  0.442876
# 2025-03-31 23:00:00  0.122581  0.505352  0.574423  0.035376  0.312585
# 2025-04-01 00:00:00  0.090323  0.459051  0.625052  0.034629  0.287261
# ...                       ...       ...       ...       ...       ...
# 2025-12-31 14:00:00  0.006452  0.486246  0.381132  0.025037  0.559443
# 2025-12-31 15:00:00  0.006452  0.502214  0.383543  0.024165  0.568722
# 2025-12-31 16:00:00  0.006452  0.510013  0.365199  0.031141  0.580514
# 2025-12-31 17:00:00  0.012903  0.510168  0.345807  0.030892  0.591340
# 2025-12-31 18:00:00  0.012903  0.523880  0.348742  0.034131  0.585154
#
#                      Factor 1  Factor 2  Factor 3  Factor 4
# timestamp_local
# 2025-03-31 20:00:00  0.036225  0.108895  0.049708  0.107585
# 2025-03-31 21:00:00  0.032180  0.114561  0.082250  0.134477
# 2025-03-31 22:00:00  0.042934  0.079396  0.076313  0.096565
# 2025-03-31 23:00:00  0.058074  0.050257  0.045558  0.048922
# 2025-04-01 00:00:00  0.062910  0.042124  0.038397  0.035620
# ...                       ...       ...       ...       ...
# 2025-12-31 14:00:00  0.040135  0.102427  0.014963  0.000000
# 2025-12-31 15:00:00  0.041023  0.104710  0.013868  0.000000
# 2025-12-31 16:00:00  0.038915  0.107782  0.016385  0.000000
# 2025-12-31 17:00:00  0.035997  0.110260  0.020716  0.002718
# 2025-12-31 18:00:00  0.037144  0.109719  0.019961  0.002868
#
# [6419 rows x 14 columns]

# %%
#taking daily average of ts. round to floor of the day
ts = ts.reset_index()

ts_day = ts.groupby(ts['timestamp_local'].dt.floor('d')).agg(bin0 = ('bin0','mean'),
                                                  bin1 = ('bin1','mean'),
                                                  bin2 = ('bin2','mean'),
                                                  bin3 = ('bin3','mean'),
                                                  bin4 = ('bin4','mean'),
                                                  bin5 = ('bin5','mean'),
                                                  co = ('co','mean'),
                                                  o3 = ('o3','mean'),
                                                  no = ('no','mean'),
                                                  no2 = ('no2','mean'),
                                                  factor1 = ('Factor 1','mean'),
                                                  factor2 = ('Factor 2','mean'),
                                                  factor3 = ('Factor 3','mean'),
                                                  factor4 = ('Factor 4','mean')).reset_index()

ts_day = ts_day.set_index('timestamp_local')
ts_day.head()
# Out:
#                      bin0      bin1      bin2      bin3      bin4      bin5  \
# timestamp_local
# 2025-03-31       0.289989  0.157029  0.113016  0.126812  0.212500  0.283871
# 2025-04-01       0.057811  0.028620  0.017862  0.014614  0.018910  0.017742
# 2025-04-02       0.048129  0.023150  0.026273  0.038889  0.070353  0.094086
# 2025-04-03       0.231542  0.105461  0.077488  0.104831  0.205929  0.288172
# 2025-04-04       0.060085  0.023382  0.018414  0.018720  0.030288  0.035215
#
#                        co        o3        no       no2   factor1   factor2  \
# timestamp_local
# 2025-03-31       0.570267  0.458019  0.032698  0.495892  0.042353  0.088277
# 2025-04-01       0.431546  0.544986  0.028831  0.279609  0.060676  0.044691
# 2025-04-02       0.461048  0.571200  0.026127  0.467749  0.061498  0.077602
# 2025-04-03       0.534055  0.449009  0.029044  0.457528  0.044367  0.081115
# 2025-04-04       0.480050  0.507827  0.027015  0.328388  0.057881  0.056731
#
#                   factor3   factor4
# timestamp_local
# 2025-03-31       0.063457  0.096887
# 2025-04-01       0.008167  0.005005
# 2025-04-02       0.000412  0.027667
# 2025-04-03       0.046680  0.090034
# 2025-04-04       0.009945  0.008833

# %% [markdown]
# ## Setting Up Barchart and 6-month Figures

# %%
# set up the figure
fig = plt.figure(figsize=(9, 8))

ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

# %%
cols = ['bin0', 'bin1', 'bin2','bin3','bin4','bin5','co', 'o3','no', 'no2']

pal = sns.color_palette()

colors = [pal[3], pal[2], pal[4], pal[5]]
colors += sns.color_palette("Blues", 6)
colors.reverse()

# %%
ax1 = sns.barplot(x='variable',y='value',
        data=comp2,
        ax=ax1, hue='species',hue_order=cols,
        palette=colors, saturation=1, edgecolor='black', linewidth=0.25,
        errwidth=.75)
# Out:
# /tmp/ipython-input-2976516543.py:1: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 0.75}` instead.
#
#   ax1 = sns.barplot(x='variable',y='value',

# %%
ax1.set_ylim(-0.2, 1)
ax1.set_xlabel("")
ax1.set_ylabel("Percent of Species Signal\nDescribed by Factor", fontsize=14)
ax1.set(yticks=np.linspace(-0.2, 1, 13), yticklabels=["","","0","","","","","50","","","","","100"])
ax1.tick_params(axis='both', which='major', labelsize=14)
ax1.axhline(y=0, color='black', linestyle='-', lw =0.5)

# %%
handles, _ = ax1.get_legend_handles_labels()
labels = ["Bin 0", "Bin 1", "Bin 2", "Bin 3","Bin 4","Bin 5","CO","$O_3$","$NO$", "$NO_2$"]
ax1.legend(handles, labels)

# %%
ax2.plot(ts_day.index, ts_day["factor1"], label="Factor 1 ", lw=1, color=sns.xkcd_rgb['slate blue'])
ax2.plot(ts_day.index, ts_day["factor2"], label="Factor 2", lw=1, color=sns.xkcd_rgb['dull green'])
ax2.plot(ts_day.index, ts_day["factor3"], label="Factor 3", lw=1, color=sns.xkcd_rgb['dark lavender'])
ax2.plot(ts_day.index, ts_day["factor4"], label="Factor 4", lw=1, color=sns.xkcd_rgb['faded red'])

ax2.set_ylabel("Factor Intensity (a.u.)", fontsize=14)

#last 6 months
ax2.set_xlim(ts_day.index[-180], ts_day.index[-1])
#ax2.set_xlim(ts_day.index[0], ts_day.index[-1])

ax2.legend(loc='upper right',fontsize=10)
ax2.tick_params(axis='both', which='major', labelsize=14)

# %%
ax1.set_title('(a)',fontsize=14)
ax2.set_title('(b)',fontsize=14)
# Out:
# Text(0.5, 1.0, '(b)')

# %%
plt.gcf().text(0.09, 0.9, "(a)", fontsize=12)
plt.gcf().text(0.5, 0.9, "(b)", fontsize=12)
plt.gcf().text(0.09,0.9,'MOD-00690',fontsize=12)

plt.tight_layout()

# %%
# fig.savefig('C:/Users/alexa/Jupyter Notebook/MOD-00683/time_barchart_MOD-00068_4_factor.png')

# %%
fig

# %% [markdown]
# ## Setting Up Diurnal Figure

# %%
ts.head()
# Out:
#       timestamp_local      bin0      bin1      bin2      bin3      bin4  \
# 0 2025-03-31 20:00:00  0.266144  0.095946  0.095090  0.133333  0.246154
# 1 2025-03-31 21:00:00  0.374899  0.191893  0.138737  0.162319  0.284615
# 2 2025-03-31 22:00:00  0.316671  0.199331  0.131723  0.133333  0.207692
# 3 2025-03-31 23:00:00  0.202243  0.140945  0.086516  0.078261  0.111538
# 4 2025-04-01 00:00:00  0.190219  0.121235  0.070148  0.060870  0.088462
#
#        bin5        co        o3        no       no2  Factor 1  Factor 2  \
# 0  0.335484  0.554752  0.393187  0.024664  0.601199  0.036225  0.108895
# 1  0.412903  0.623529  0.396331  0.035127  0.626909  0.032180  0.114561
# 2  0.264516  0.597435  0.468134  0.035625  0.442876  0.042934  0.079396
# 3  0.122581  0.505352  0.574423  0.035376  0.312585  0.058074  0.050257
# 4  0.090323  0.459051  0.625052  0.034629  0.287261  0.062910  0.042124
#
#    Factor 3  Factor 4
# 0  0.049708  0.107585
# 1  0.082250  0.134477
# 2  0.076313  0.096565
# 3  0.045558  0.048922
# 4  0.038397  0.035620

# %%
#prepping data
ts = ts.set_index('timestamp_local')
ts['Hour'] = ts.index.hour
ts.head()
# Out:
#                          bin0      bin1      bin2      bin3      bin4  \
# timestamp_local
# 2025-03-31 20:00:00  0.266144  0.095946  0.095090  0.133333  0.246154
# 2025-03-31 21:00:00  0.374899  0.191893  0.138737  0.162319  0.284615
# 2025-03-31 22:00:00  0.316671  0.199331  0.131723  0.133333  0.207692
# 2025-03-31 23:00:00  0.202243  0.140945  0.086516  0.078261  0.111538
# 2025-04-01 00:00:00  0.190219  0.121235  0.070148  0.060870  0.088462
#
#                          bin5        co        o3        no       no2  \
# timestamp_local
# 2025-03-31 20:00:00  0.335484  0.554752  0.393187  0.024664  0.601199
# 2025-03-31 21:00:00  0.412903  0.623529  0.396331  0.035127  0.626909
# 2025-03-31 22:00:00  0.264516  0.597435  0.468134  0.035625  0.442876
# 2025-03-31 23:00:00  0.122581  0.505352  0.574423  0.035376  0.312585
# 2025-04-01 00:00:00  0.090323  0.459051  0.625052  0.034629  0.287261
#
#                      Factor 1  Factor 2  Factor 3  Factor 4  Hour
# timestamp_local
# 2025-03-31 20:00:00  0.036225  0.108895  0.049708  0.107585    20
# 2025-03-31 21:00:00  0.032180  0.114561  0.082250  0.134477    21
# 2025-03-31 22:00:00  0.042934  0.079396  0.076313  0.096565    22
# 2025-03-31 23:00:00  0.058074  0.050257  0.045558  0.048922    23
# 2025-04-01 00:00:00  0.062910  0.042124  0.038397  0.035620     0

# %%
#grouping by hour and calculate the mean
diurnal_data = ts.groupby('Hour')[['Factor 1','Factor 2','Factor 3', 'Factor 4']].mean()
diurnal_data.index = diurnal_data.index.map(lambda x: "{:02d}:00".format(x))
diurnal_data
# Out:
#        Factor 1  Factor 2  Factor 3  Factor 4
# Hour
# 00:00  0.044441  0.079381  0.029849  0.018915
# 01:00  0.043328  0.080437  0.030398  0.017273
# 02:00  0.042283  0.081340  0.029936  0.017025
# 03:00  0.041424  0.078607  0.030787  0.017198
# 04:00  0.040570  0.077595  0.031365  0.017785
# 05:00  0.039047  0.079516  0.032751  0.018990
# 06:00  0.038560  0.082307  0.033225  0.018702
# 07:00  0.041824  0.073756  0.032431  0.017661
# 08:00  0.045596  0.061283  0.030915  0.014835
# 09:00  0.048610  0.052256  0.028682  0.013694
# 10:00  0.051718  0.044950  0.026198  0.011145
# 11:00  0.054477  0.042896  0.024205  0.009009
# 12:00  0.056429  0.045153  0.022661  0.008604
# 13:00  0.057682  0.050566  0.020850  0.008040
# 14:00  0.058790  0.053008  0.020481  0.007985
# 15:00  0.058235  0.057481  0.020527  0.007993
# 16:00  0.057385  0.064786  0.020109  0.008325
# 17:00  0.055199  0.075082  0.020865  0.008814
# 18:00  0.052377  0.084915  0.022818  0.010214
# 19:00  0.049735  0.092017  0.025623  0.013190
# 20:00  0.048033  0.091770  0.028430  0.014387
# 21:00  0.046706  0.089210  0.030368  0.016096
# 22:00  0.045921  0.084842  0.030911  0.016430
# 23:00  0.045271  0.082141  0.030164  0.017437

# %%
# set up the figure
plt.figure(figsize=(10, 6))

plt.plot(diurnal_data.index, diurnal_data['Factor 1'], label='Factor 1', lw = 2, color=sns.xkcd_rgb['slate blue'])
plt.plot(diurnal_data.index, diurnal_data['Factor 2'], label='Factor 2', lw = 2, color=sns.xkcd_rgb['dull green'])
plt.plot(diurnal_data.index, diurnal_data['Factor 3'], label='Factor 3', lw = 2, color=sns.xkcd_rgb['dark lavender'])
plt.plot(diurnal_data.index, diurnal_data['Factor 4'], label='Factor 4', lw = 2, color=sns.xkcd_rgb['faded red'])

plt.ylabel('Factor Intensity (a.u.)', fontsize = 14)
plt.legend(loc='upper right',fontsize=14)
plt.xticks(range(0, 24))
plt.xticks(rotation=45)

plt.tick_params(labelsize=14)

# plt.savefig('C:/Users/alexa/Jupyter Notebook/MOD-00683/diurnal_MOD-00068_4_factor.png')
plt.show()
